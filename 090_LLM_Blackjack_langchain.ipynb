# %%
#https://python.langchain.com.cn/docs/use_cases/agent_simulations/gymnasium

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
from dotenv import load_dotenv  

import inspect
import tenacity

from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage,
    BaseMessage,
)
from langchain.output_parsers import RegexParser
load_dotenv('API_KEYS.env')  

llm=ChatOpenAI(temperature=0.2)

llm = ChatGroq(
    model="llama3-70b-8192",                  # Correct model name
    temperature=0.7,
    max_tokens=512
)

# %% [markdown]
# ### The Agent

# %%
class GymnasiumAgent:
    @classmethod
    def get_docs(cls, env):
        return env.unwrapped.__doc__

    def __init__(self, model, env):
        self.model = model
        self.env = env
        self.docs = self.get_docs(env)

        self.instructions = """
Your goal is to maximize your return, i.e. the sum of the rewards you receive.
You are playing blackjack in the environment gymnasium for reinforcement learning
The game starts with the dealer having one face up and one face down card, while the player has two face up cards. All cards are drawn from an infinite deck (i.e. with replacement).

The card values are:

    Face cards (Jack, Queen, King) have a point value of 10.

    Aces can either count as 11 (called a ‘usable ace’) or 1.

    Numerical cards (2-10) have a value equal to their number.

The player has the sum of cards held. The player can request additional cards (hit) until they decide to stop (stick) or exceed 21 (bust, immediate loss).

After the player sticks, the dealer reveals their facedown card, and draws cards until their sum is 17 or greater. If the dealer goes bust, the player wins.

If neither the player nor the dealer busts, the outcome (win, lose, draw) is decided by whose sum is closer to 21.

I will give you an observation, reward, terminiation flag, truncation flag, and the return so far, formatted as:

Observation: <observation>
Reward: <reward>
Termination: <termination>
Truncation: <truncation>
Return: <sum_of_rewards>

You will respond with an action, formatted as:

Action: <action>

where you replace <action> with your actual action.
Do nothing else but return the action. don't explain your reasoning
Respond a number 0 is Stick. 1 is hit 
"""
        self.action_parser = RegexParser(
            regex=r"Action: (.*)", output_keys=["action"], default_output_key="action"
        )

        self.message_history = []
        self.ret = 0

    def random_action(self):
        action = self.env.action_space.sample()
        return action

    def reset(self):
        self.message_history = [
            SystemMessage(content=self.docs),
            SystemMessage(content=self.instructions),
        ]

    def observe(self, obs, rew=0, term=False, trunc=False, info=None):
        self.ret += rew

        obs_message = f"""
Observation: {obs}
Reward: {rew}
Termination: {term}
Truncation: {trunc}
Return: {self.ret}
        """
        self.message_history.append(HumanMessage(content=obs_message))
        return obs_message

    def _act(self):

        act_message = self.model.invoke(self.message_history)
        self.message_history.append(act_message)

#        action = int(self.action_parser.parse(act_message)["action"])
        action = int(self.action_parser.parse(act_message.content)["action"]) # para ChatGPT
        return action

    def act(self):
        try:
            for attempt in tenacity.Retrying(
                stop=tenacity.stop_after_attempt(2),
                wait=tenacity.wait_none(),  # No waiting time between retries
                retry=tenacity.retry_if_exception_type(ValueError),
                before_sleep=lambda retry_state: print(
                    f"ValueError occurred: {retry_state.outcome.exception()}, retrying..."
                ),
            ):
                with attempt:
                    action = self._act()
        except tenacity.RetryError as e:
            action = self.random_action()
        return action

# %%
env = gym.make("Blackjack-v1")
#agent = GymnasiumAgent(model=ChatOpenAI(temperature=0.2), env=env)
agent = GymnasiumAgent(model=llm, env=env)

# %%
won, lost, draw = 0,0,0

for i_episode in range(100):
    agent.reset()
    obs, _ = env.reset()
    obs_message = agent.observe(obs)
    print(obs_message)
    
    while True:
        action = agent.act()
        print(f"Action: {action}")
        
        observation, reward, termination, truncation, info = env.step(action)
        obs_message = agent.observe(observation, reward, termination, truncation, info)
        
        print(obs_message)

        if termination or truncation:
            print(f"End game!  episode: {i_episode}, Reward:{reward}")
            if reward > 0:
                print('You won :)\n')
                won= won+1 
            elif reward == 0:
                print ('Draw')
                draw = draw + 1
            else:
                print('You lost :(\n')
                lost = lost + 1
            break
            
        
print(i_episode, 'total won', won, 'total lost', lost, 'total draw', draw)
# Out:
# Observation: (18, 5, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: 0
#
# Action: 0
#
# Observation: (18, 5, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: 1.0
#
# End game!  episode0, Reward:1.0
# You won :)
#
#
# Observation: (14, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: 1.0
#
# Action: 1
#
# Observation: (22, 8, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: 0.0
#
# End game!  episode1, Reward:-1.0
# You lost :(
#
#
# Observation: (8, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: 0.0
#
# Action: 1
#
# Observation: (14, 1, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: 0.0
#
# Action: 1
#
# Observation: (15, 1, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: 0.0
#
# Action: 1
#
# Observation: (25, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode2, Reward:-1.0
# You lost :(
#
#
# Observation: (17, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 0
#
# Observation: (17, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode3, Reward:-1.0
# You lost :(
#
#
# Observation: (15, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (25, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode4, Reward:-1.0
# You lost :(
#
#
# Observation: (18, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (18, 8, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode5, Reward:-1.0
# You lost :(
#
#
# Observation: (13, 10, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (12, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (22, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode6, Reward:-1.0
# You lost :(
#
#
# Observation: (14, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 1
#
# Observation: (23, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -6.0
#
# End game!  episode7, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 1
#
# Observation: (20, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 0
#
# Observation: (20, 5, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -7.0
#
# End game!  episode8, Reward:-1.0
# You lost :(
#
#
# Observation: (19, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -7.0
#
# Action: 0
#
# Observation: (19, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -8.0
#
# End game!  episode9, Reward:-1.0
# You lost :(
#
#
# Observation: (10, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -8.0
#
# Action: 1
#
# Observation: (17, 4, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -8.0
#
# Action: 0
#
# Observation: (17, 4, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode10, Reward:-1.0
# You lost :(
#
#
# Observation: (17, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (17, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode11, Reward:-1.0
# You lost :(
#
#
# Observation: (11, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 1
#
# Observation: (13, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 1
#
# Observation: (15, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (15, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -11.0
#
# End game!  episode12, Reward:-1.0
# You lost :(
#
#
# Observation: (6, 2, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 1
#
# Observation: (16, 2, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 0
#
# Observation: (16, 2, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode13, Reward:1.0
# You won :)
#
#
# Observation: (19, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (19, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -11.0
#
# End game!  episode14, Reward:-1.0
# You lost :(
#
#
# Observation: (14, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 1
#
# Observation: (15, 9, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 1
#
# Observation: (19, 9, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 0
#
# Observation: (19, 9, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode15, Reward:1.0
# You won :)
#
#
# Observation: (19, 3, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (19, 3, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode16, Reward:1.0
# You won :)
#
#
# Observation: (16, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (16, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode17, Reward:-1.0
# You lost :(
#
#
# Observation: (11, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 1
#
# Observation: (13, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 1
#
# Observation: (20, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (20, 8, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode18, Reward:1.0
# You won :)
#
#
# Observation: (15, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 1
#
# Observation: (20, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (20, 10, 0)
# Reward: 0.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode19, Reward:0.0
# Draw
#
# Observation: (20, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (20, 9, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -8.0
#
# End game!  episode20, Reward:1.0
# You won :)
#
#
# Observation: (17, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -8.0
#
# Action: 0
#
# Observation: (17, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode21, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 10, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (16, 10, 1)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode22, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (16, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -11.0
#
# End game!  episode23, Reward:-1.0
# You lost :(
#
#
# Observation: (18, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 0
#
# Observation: (18, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -12.0
#
# End game!  episode24, Reward:-1.0
# You lost :(
#
#
# Observation: (20, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -12.0
#
# Action: 0
#
# Observation: (20, 10, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -11.0
#
# End game!  episode25, Reward:1.0
# You won :)
#
#
# Observation: (16, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -11.0
#
# Action: 0
#
# Observation: (16, 10, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode26, Reward:1.0
# You won :)
#
#
# Observation: (19, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (19, 10, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode27, Reward:1.0
# You won :)
#
#
# Observation: (12, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
# Action: 1
#
# Observation: (17, 1, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (17, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode28, Reward:-1.0
# You lost :(
#
#
# Observation: (20, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (20, 4, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode29, Reward:1.0
# You won :)
#
#
# Observation: (7, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 1
#
# Observation: (10, 9, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 1
#
# Observation: (12, 9, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 1
#
# Observation: (22, 9, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -10.0
#
# End game!  episode30, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 6, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -10.0
#
# Action: 0
#
# Observation: (16, 6, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode31, Reward:1.0
# You won :)
#
#
# Observation: (20, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (20, 5, 0)
# Reward: 0.0
# Termination: True
# Truncation: False
# Return: -9.0
#
# End game!  episode32, Reward:0.0
# Draw
#
# Observation: (14, 10, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 1
#
# Observation: (18, 10, 1)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -9.0
#
# Action: 0
#
# Observation: (18, 10, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -8.0
#
# End game!  episode33, Reward:1.0
# You won :)
#
#
# Observation: (21, 10, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -8.0
#
# Action: 0
#
# Observation: (21, 10, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -7.0
#
# End game!  episode34, Reward:1.0
# You won :)
#
#
# Observation: (12, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -7.0
#
# Action: 1
#
# Observation: (22, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -8.0
#
# End game!  episode35, Reward:-1.0
# You lost :(
#
#
# Observation: (12, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -8.0
#
# Action: 1
#
# Observation: (17, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -8.0
#
# Action: 0
#
# Observation: (17, 5, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -7.0
#
# End game!  episode36, Reward:1.0
# You won :)
#
#
# Observation: (20, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -7.0
#
# Action: 0
#
# Observation: (20, 4, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -6.0
#
# End game!  episode37, Reward:1.0
# You won :)
#
#
# Observation: (20, 7, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 0
#
# Observation: (20, 7, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode38, Reward:1.0
# You won :)
#
#
# Observation: (20, 3, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (20, 3, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode39, Reward:1.0
# You won :)
#
#
# Observation: (16, 2, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (19, 2, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (19, 2, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode40, Reward:-1.0
# You lost :(
#
#
# Observation: (19, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (19, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -6.0
#
# End game!  episode41, Reward:-1.0
# You lost :(
#
#
# Observation: (12, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 1
#
# Observation: (18, 9, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 0
#
# Observation: (18, 9, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode42, Reward:1.0
# You won :)
#
#
# Observation: (16, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 1
#
# Observation: (26, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -6.0
#
# End game!  episode43, Reward:-1.0
# You lost :(
#
#
# Observation: (18, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 0
#
# Observation: (18, 5, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -7.0
#
# End game!  episode44, Reward:-1.0
# You lost :(
#
#
# Observation: (6, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -7.0
#
# Action: 1
#
# Observation: (9, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -7.0
#
# Action: 1
#
# Observation: (19, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -7.0
#
# Action: 0
#
# Observation: (19, 5, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -6.0
#
# End game!  episode45, Reward:1.0
# You won :)
#
#
# Observation: (20, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 0
#
# Observation: (20, 4, 0)
# Reward: 0.0
# Termination: True
# Truncation: False
# Return: -6.0
#
# End game!  episode46, Reward:0.0
# Draw
#
# Observation: (14, 3, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 1
#
# Observation: (14, 3, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 1
#
# Observation: (21, 3, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -6.0
#
# Action: 0
#
# Observation: (21, 3, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode47, Reward:1.0
# You won :)
#
#
# Observation: (18, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (18, 9, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode48, Reward:1.0
# You won :)
#
#
# Observation: (16, 7, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (16, 7, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode49, Reward:-1.0
# You lost :(
#
#
# Observation: (5, 6, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 1
#
# Observation: (14, 6, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 1
#
# Observation: (17, 6, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (17, 6, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode50, Reward:1.0
# You won :)
#
#
# Observation: (4, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (7, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (17, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (17, 8, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode51, Reward:-1.0
# You lost :(
#
#
# Observation: (20, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (20, 1, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode52, Reward:1.0
# You won :)
#
#
# Observation: (20, 10, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (20, 10, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode53, Reward:1.0
# You won :)
#
#
# Observation: (12, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (19, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (19, 5, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode54, Reward:1.0
# You won :)
#
#
# Observation: (15, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
# Action: 1
#
# Observation: (17, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (17, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode55, Reward:-1.0
# You lost :(
#
#
# Observation: (12, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (22, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode56, Reward:-1.0
# You lost :(
#
#
# Observation: (13, 7, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (18, 7, 1)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (18, 7, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode57, Reward:1.0
# You won :)
#
#
# Observation: (21, 10, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (21, 10, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode58, Reward:1.0
# You won :)
#
#
# Observation: (15, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (17, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (17, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode59, Reward:-1.0
# You lost :(
#
#
# Observation: (14, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (24, 8, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode60, Reward:-1.0
# You lost :(
#
#
# Observation: (19, 6, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (19, 6, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode61, Reward:1.0
# You won :)
#
#
# Observation: (11, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (21, 4, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (21, 4, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode62, Reward:1.0
# You won :)
#
#
# Observation: (20, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (20, 10, 0)
# Reward: 0.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode63, Reward:0.0
# Draw
#
# Observation: (13, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (17, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (17, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode64, Reward:-1.0
# You lost :(
#
#
# Observation: (10, 3, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (13, 3, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (21, 3, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (21, 3, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode65, Reward:1.0
# You won :)
#
#
# Observation: (20, 9, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (20, 9, 1)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode66, Reward:1.0
# You won :)
#
#
# Observation: (19, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 0
#
# Observation: (19, 9, 0)
# Reward: 0.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode67, Reward:0.0
# Draw
#
# Observation: (20, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 0
#
# Observation: (20, 5, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode68, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 5, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (16, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (24, 5, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode69, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (16, 4, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode70, Reward:1.0
# You won :)
#
#
# Observation: (12, 7, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (18, 7, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (18, 7, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode71, Reward:1.0
# You won :)
#
#
# Observation: (19, 3, 1)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 0
#
# Observation: (19, 3, 1)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode72, Reward:-1.0
# You lost :(
#
#
# Observation: (5, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (13, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (18, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (18, 10, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode73, Reward:1.0
# You won :)
#
#
# Observation: (18, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 0
#
# Observation: (18, 9, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode74, Reward:-1.0
# You lost :(
#
#
# Observation: (13, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (23, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode75, Reward:-1.0
# You lost :(
#
#
# Observation: (13, 3, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (23, 3, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode76, Reward:-1.0
# You lost :(
#
#
# Observation: (7, 5, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (17, 5, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (17, 5, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode77, Reward:1.0
# You won :)
#
#
# Observation: (9, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (16, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (16, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode78, Reward:-1.0
# You lost :(
#
#
# Observation: (15, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (21, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (21, 10, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode79, Reward:1.0
# You won :)
#
#
# Observation: (19, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (19, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode80, Reward:-1.0
# You lost :(
#
#
# Observation: (11, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (18, 9, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (18, 9, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode81, Reward:1.0
# You won :)
#
#
# Observation: (10, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
# Action: 1
#
# Observation: (19, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (19, 8, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode82, Reward:1.0
# You won :)
#
#
# Observation: (10, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (20, 4, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (20, 4, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode83, Reward:-1.0
# You lost :(
#
#
# Observation: (18, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (18, 10, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode84, Reward:1.0
# You won :)
#
#
# Observation: (19, 3, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (19, 3, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode85, Reward:1.0
# You won :)
#
#
# Observation: (12, 4, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 1
#
# Observation: (22, 4, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode86, Reward:-1.0
# You lost :(
#
#
# Observation: (17, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (17, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode87, Reward:-1.0
# You lost :(
#
#
# Observation: (14, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (15, 10, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (24, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode88, Reward:-1.0
# You lost :(
#
#
# Observation: (14, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (22, 9, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode89, Reward:-1.0
# You lost :(
#
#
# Observation: (11, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 1
#
# Observation: (21, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (21, 8, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode90, Reward:1.0
# You won :)
#
#
# Observation: (17, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (17, 9, 0)
# Reward: 0.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode91, Reward:0.0
# Draw
#
# Observation: (18, 10, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (18, 10, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -5.0
#
# End game!  episode92, Reward:-1.0
# You lost :(
#
#
# Observation: (13, 7, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 1
#
# Observation: (19, 7, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -5.0
#
# Action: 0
#
# Observation: (19, 7, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode93, Reward:1.0
# You won :)
#
#
# Observation: (8, 2, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 1
#
# Observation: (18, 2, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -4.0
#
# Action: 0
#
# Observation: (18, 2, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode94, Reward:1.0
# You won :)
#
#
# Observation: (13, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 1
#
# Observation: (20, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (20, 8, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode95, Reward:1.0
# You won :)
#
#
# Observation: (13, 8, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (21, 8, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (21, 8, 0)
# Reward: 1.0
# Termination: True
# Truncation: False
# Return: -1.0
#
# End game!  episode96, Reward:1.0
# You won :)
#
#
# Observation: (14, 6, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -1.0
#
# Action: 1
#
# Observation: (23, 6, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -2.0
#
# End game!  episode97, Reward:-1.0
# You lost :(
#
#
# Observation: (11, 1, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (15, 1, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 1
#
# Observation: (16, 1, 0)
# Reward: 0.0
# Termination: False
# Truncation: False
# Return: -2.0
#
# Action: 0
#
# Observation: (16, 1, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -3.0
#
# End game!  episode98, Reward:-1.0
# You lost :(
#
#
# Observation: (16, 9, 0)
# Reward: 0
# Termination: False
# Truncation: False
# Return: -3.0
#
# Action: 0
#
# Observation: (16, 9, 0)
# Reward: -1.0
# Termination: True
# Truncation: False
# Return: -4.0
#
# End game!  episode99, Reward:-1.0
# You lost :(
#
# 99 total won 45 total lost 49 total draw 6

# %%
print(f"Total episodes: {i_episode+1} Won: {(won/i_episode):.2%}, Lost: {(lost/i_episode):.2%}, Draw: {(draw/i_episode):.2%}")
# Out:
# Total episodes: 100 Won: 45.45%, Lost: 49.49%, Draw: 6.06%

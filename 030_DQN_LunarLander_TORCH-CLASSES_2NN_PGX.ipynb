# %% [markdown]
# ### **Lunar Lander DQN TORCH using Clases 2 Networks**
#
# This is a naive version of the Lunar Lander DQN algorithm using an Agent Class<br>
#
# There is no Gradient Clipping in this example. Would you improve with Gradient Clipping?
# <br>
# In this version the agent has been created as a class making the code more compact <br>
# This DQN Class can be used with other environments <br>
#  <br>
# Try to make it faster by doing some hyperparameter optimization  <br>
# Try to explore less. Does it accelerates convergence?  <br>
# Increasing the ```ROLLING_WINDOW``` value will gnerate slower agent convergence but the Agent behavior will be more consistent <br>
#
# An issue you may find is a lander that hovers forever. This happens because it has been programmed with infinite fuel. You can see it in this execution in the lines that are marked as ```Terminated=False```. This confuses the training because it does not reach the objective or termination. Without modifying the environment, there are a couple of things that can be done to ameliorate this behavior <br>
#
# 1. **Limit number of steps** In this case we are limiting the number of steps to 1200, if you don't limit it sometimes it goes up to thousands of steps, and this is a waste of time
# 2. **Increase gravity** The default gravity in this environment is -10.0, you can increase it up to -12.0, increasing it you'll have a faster descent and hovering becomes more difficult ```env = gym.make("LunarLander-v3", gravity=11.0)```

# %%
import os
import random
import gymnasium as gym
import time
import numpy as np
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from PIL import Image
import time

import sys
sys.stderr = open('err.txt', 'w')

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version (built):", torch.version.cuda)
print("Device count:", torch.cuda.device_count())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"  GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"    Compute capability: {torch.cuda.get_device_capability(i)}")
        print(f"    Memory: {torch.cuda.get_device_properties(i).total_memory / 1e9:.1f} GB")

    # Quick sanity check: actually run something on the GPU
    x = torch.randn(1000, 1000, device="cuda")
    y = x @ x
    print("Matmul on GPU OK, result shape:", y.shape)
else:
    print("No GPU visible to PyTorch.")
# Out:
# PyTorch version: 2.11.0+cu130
# CUDA available: True
# CUDA version (built): 13.0
# Device count: 1
#   GPU 0: NVIDIA GB10
#     Compute capability: (12, 1)
#     Memory: 130.6 GB
# Matmul on GPU OK, result shape: torch.Size([1000, 1000])

# %% [markdown]
# #### **Hyperparameters**

# %%
MAX_EPISODES = 2000
ROLLING_WINDOW = 40
MEMORY_SIZE = 100_000
MAX_STEPS = 1200

gamma = 0.99                         # discount rate
epsilon = 1.0                        # exploration rate
epsilon_min = 0.02
epsilon_decay = 0.99
learning_rate = 5e-4
batch_size = 64
solved_threshold = 200
REFRESH_TARGET_NET = 10


verb = 0                             # to see traces (verbosity)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Environment setup
env = gym.make('LunarLander-v3')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
class Q_Network(nn.Module):
    def __init__(self, state_size, action_size):
        super().__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.out = nn.Linear(32, action_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        return self.out(x)

# %%
class Agent_DQN():
    def __init__(self, states, actions, alpha, gamma, epsilon):
        self.nS = states
        self.nA = actions
        self.replay_buffer = deque([], maxlen=MEMORY_SIZE)
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        # 1. Initialize TWO networks
        self.model = self.build_NN()
        self.target_model = self.build_NN()
        
        # Sync them initially
        self.update_target_network()
        
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()
        self.loss = []
        self.step_count = 0 

    def build_NN(self):
        return Q_Network(self.nS, self.nA).to(device)

    def update_target_network(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def action(self, state):
        state_tensor = torch.as_tensor(state, dtype=torch.float32, device=device)
        self.model.eval()
        with torch.no_grad():
            action_vals = self.model(state_tensor)
        self.model.train()
        return torch.argmax(action_vals[0]).item()
    
    def random_action(self):
        return random.randrange(self.nA)
    
    def store_experience(self, state, action, reward, next_state, done):
        self.replay_buffer.append((state, action, reward, next_state, done))

    def sample_experiences(self, batch_size):
        indices = np.random.choice(len(self.replay_buffer), batch_size, replace=False)
        batch = [self.replay_buffer[i] for i in indices]
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            np.vstack(states),
            np.array(actions),
            np.array(rewards),
            np.vstack(next_states),
            np.array(dones, dtype=np.float32)
        )
    
    def experience_replay(self, batch_size, epsilon):
        if len(self.replay_buffer) < batch_size:
            return
        
        self.step_count += 1
        states, actions, rewards, next_states, dones = self.sample_experiences(batch_size)

        states_tensor = torch.as_tensor(states, dtype=torch.float32, device=device)
        actions_tensor = torch.as_tensor(actions, dtype=torch.long, device=device)
        rewards_tensor = torch.as_tensor(rewards, dtype=torch.float32, device=device)
        next_states_tensor = torch.as_tensor(next_states, dtype=torch.float32, device=device)
        dones_tensor = torch.as_tensor(dones, dtype=torch.float32, device=device)

        q_values = self.model(states_tensor)
        with torch.no_grad():
            # Calculate targets using the TARGET network
            next_qs = self.target_model(next_states_tensor) 
            target_qs = q_values.detach().clone()
            target_qs[torch.arange(batch_size, device=device), actions_tensor] = (
                rewards_tensor + self.gamma * torch.max(next_qs, dim=1).values * (1 - dones_tensor)
            )

        loss = self.loss_fn(q_values, target_qs)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.loss.append(loss.item())

        # Sync target network every REFRESH_TARGET_NET steps
        if self.step_count % REFRESH_TARGET_NET == 0:
            self.update_target_network()

# %%
# Support function
def select_action_greedy(state, agent_DQN):                                    
    if np.random.rand() <= epsilon:
        return agent_DQN.random_action()
    return agent_DQN.action(state)

# %% [markdown]
# #### **Main Loop**

# %%
env = gym.make('LunarLander-v3')
state_size = int(env.observation_space.shape[0])
action_size = int(env.action_space.n)

agent = Agent_DQN(state_size, action_size, learning_rate, gamma, epsilon)

# %%
rewards_per_episode= []
start_time = time.time()

done = False
rolling_avg = 0
rolling_avg_rewards = []



for e in range(MAX_EPISODES):                           # Should be While True, however we limit number of eps
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    for step in range(MAX_STEPS):
            
        action = select_action_greedy(state, agent)
        next_state, reward, done, truncated , _ = env.step(action)
                    
        next_state = np.reshape(next_state, [1, state_size])
        agent.store_experience(state, action, reward, next_state, done)
        state = next_state
        total_reward = total_reward + reward
        if done:
            break
            
        
        agent.experience_replay(batch_size, epsilon)
            
    epsilon = max(epsilon_min, epsilon * epsilon_decay)            # decay epsilon
    
    rewards_per_episode.append(total_reward)
    rolling_avg = np.mean(rewards_per_episode[-ROLLING_WINDOW:])   # append rewards
    rolling_avg_rewards.append(rolling_avg)
    print(f"Episode: {e+1:3}/{MAX_EPISODES}, Reward: {total_reward:+7.2f}, "
          f"Epsilon: {epsilon:.2f}, Rolling Avg: {rolling_avg:7.2f}, Steps: {step:4} Terminated: {done} ")

            
    # Check if environment is solved
    if rolling_avg >= solved_threshold:
        print(f"Environment solved in {e+1} episodes!")
        break

end_time = time.time()
print(f"Training completed in {(end_time - start_time)/60:.2f} minutes")
# Out:
# Episode:   1/2000, Reward: -353.64, Epsilon: 0.99, Rolling Avg: -353.64, Steps:  152 Terminated: True
# Episode:   2/2000, Reward:  -44.24, Epsilon: 0.98, Rolling Avg: -198.94, Steps:  109 Terminated: True
# Episode:   3/2000, Reward:  -90.46, Epsilon: 0.97, Rolling Avg: -162.78, Steps:   66 Terminated: True
# Episode:   4/2000, Reward: -116.41, Epsilon: 0.96, Rolling Avg: -151.19, Steps:   72 Terminated: True
# Episode:   5/2000, Reward:  -94.43, Epsilon: 0.95, Rolling Avg: -139.83, Steps:   72 Terminated: True
# Episode:   6/2000, Reward: -242.78, Epsilon: 0.94, Rolling Avg: -156.99, Steps:   92 Terminated: True
# Episode:   7/2000, Reward:  -65.55, Epsilon: 0.93, Rolling Avg: -143.93, Steps:  112 Terminated: True
# Episode:   8/2000, Reward: -351.92, Epsilon: 0.92, Rolling Avg: -169.93, Steps:  115 Terminated: True
# Episode:   9/2000, Reward: -161.00, Epsilon: 0.91, Rolling Avg: -168.94, Steps:   89 Terminated: True
# Episode:  10/2000, Reward: -110.70, Epsilon: 0.90, Rolling Avg: -163.11, Steps:   83 Terminated: True
# Episode:  11/2000, Reward:  -80.21, Epsilon: 0.90, Rolling Avg: -155.58, Steps:   72 Terminated: True
# Episode:  12/2000, Reward: -227.57, Epsilon: 0.89, Rolling Avg: -161.58, Steps:   72 Terminated: True
# Episode:  13/2000, Reward: -262.89, Epsilon: 0.88, Rolling Avg: -169.37, Steps:  102 Terminated: True
# Episode:  14/2000, Reward: -502.85, Epsilon: 0.87, Rolling Avg: -193.19, Steps:  131 Terminated: True
# Episode:  15/2000, Reward: -143.36, Epsilon: 0.86, Rolling Avg: -189.87, Steps:   79 Terminated: True
# Episode:  16/2000, Reward:  -89.23, Epsilon: 0.85, Rolling Avg: -183.58, Steps:   87 Terminated: True
# Episode:  17/2000, Reward: -126.48, Epsilon: 0.84, Rolling Avg: -180.22, Steps:  139 Terminated: True
# Episode:  18/2000, Reward: -195.40, Epsilon: 0.83, Rolling Avg: -181.06, Steps:   80 Terminated: True
# Episode:  19/2000, Reward:  -41.63, Epsilon: 0.83, Rolling Avg: -173.72, Steps:   75 Terminated: True
# Episode:  20/2000, Reward: -113.47, Epsilon: 0.82, Rolling Avg: -170.71, Steps:  110 Terminated: True
# Episode:  21/2000, Reward: -137.50, Epsilon: 0.81, Rolling Avg: -169.13, Steps:   72 Terminated: True
# Episode:  22/2000, Reward: -210.84, Epsilon: 0.80, Rolling Avg: -171.03, Steps:  112 Terminated: True
# Episode:  23/2000, Reward: -214.64, Epsilon: 0.79, Rolling Avg: -172.92, Steps:   85 Terminated: True
# Episode:  24/2000, Reward: -356.77, Epsilon: 0.79, Rolling Avg: -180.58, Steps:  101 Terminated: True
# Episode:  25/2000, Reward: -340.62, Epsilon: 0.78, Rolling Avg: -186.98, Steps:   63 Terminated: True
# Episode:  26/2000, Reward: -101.31, Epsilon: 0.77, Rolling Avg: -183.69, Steps:   84 Terminated: True
# Episode:  27/2000, Reward: -112.61, Epsilon: 0.76, Rolling Avg: -181.06, Steps:  169 Terminated: True
# Episode:  28/2000, Reward:  -92.38, Epsilon: 0.75, Rolling Avg: -177.89, Steps:   70 Terminated: True
# Episode:  29/2000, Reward:  -82.94, Epsilon: 0.75, Rolling Avg: -174.61, Steps:  115 Terminated: True
# Episode:  30/2000, Reward: -169.63, Epsilon: 0.74, Rolling Avg: -174.45, Steps:  130 Terminated: True
# Episode:  31/2000, Reward: -213.22, Epsilon: 0.73, Rolling Avg: -175.70, Steps:  112 Terminated: True
# Episode:  32/2000, Reward: -391.37, Epsilon: 0.72, Rolling Avg: -182.44, Steps:  145 Terminated: True
# Episode:  33/2000, Reward:  -89.41, Epsilon: 0.72, Rolling Avg: -179.62, Steps:   90 Terminated: True
# Episode:  34/2000, Reward: -237.03, Epsilon: 0.71, Rolling Avg: -181.31, Steps:  182 Terminated: True
# Episode:  35/2000, Reward:   +1.52, Epsilon: 0.70, Rolling Avg: -176.09, Steps:  146 Terminated: True
# Episode:  36/2000, Reward:  -80.30, Epsilon: 0.70, Rolling Avg: -173.42, Steps:   79 Terminated: True
# Episode:  37/2000, Reward: -138.41, Epsilon: 0.69, Rolling Avg: -172.48, Steps:  124 Terminated: True
# Episode:  38/2000, Reward: -349.14, Epsilon: 0.68, Rolling Avg: -177.13, Steps:   86 Terminated: True
# Episode:  39/2000, Reward: -302.25, Epsilon: 0.68, Rolling Avg: -180.34, Steps:   99 Terminated: True
# Episode:  40/2000, Reward: -117.51, Epsilon: 0.67, Rolling Avg: -178.76, Steps:  117 Terminated: True
# Episode:  41/2000, Reward: -311.72, Epsilon: 0.66, Rolling Avg: -177.72, Steps:   94 Terminated: True
# Episode:  42/2000, Reward: -137.09, Epsilon: 0.66, Rolling Avg: -180.04, Steps:  132 Terminated: True
# Episode:  43/2000, Reward:  -98.41, Epsilon: 0.65, Rolling Avg: -180.24, Steps:  128 Terminated: True
# Episode:  44/2000, Reward: -183.54, Epsilon: 0.64, Rolling Avg: -181.91, Steps:  111 Terminated: True
# Episode:  45/2000, Reward: -128.66, Epsilon: 0.64, Rolling Avg: -182.77, Steps:  134 Terminated: True
# Episode:  46/2000, Reward:  +28.40, Epsilon: 0.63, Rolling Avg: -175.99, Steps:  110 Terminated: True
# Episode:  47/2000, Reward: -280.67, Epsilon: 0.62, Rolling Avg: -181.37, Steps:  187 Terminated: True
# Episode:  48/2000, Reward:  -70.18, Epsilon: 0.62, Rolling Avg: -174.33, Steps:  136 Terminated: True
# Episode:  49/2000, Reward: -231.74, Epsilon: 0.61, Rolling Avg: -176.09, Steps:  106 Terminated: True
# Episode:  50/2000, Reward:  -88.14, Epsilon: 0.61, Rolling Avg: -175.53, Steps:   96 Terminated: True
# Episode:  51/2000, Reward: -156.37, Epsilon: 0.60, Rolling Avg: -177.43, Steps:  146 Terminated: True
# Episode:  52/2000, Reward:  -29.64, Epsilon: 0.59, Rolling Avg: -172.49, Steps:   75 Terminated: True
# Episode:  53/2000, Reward: -243.37, Epsilon: 0.59, Rolling Avg: -172.00, Steps:  267 Terminated: True
# Episode:  54/2000, Reward:   +4.99, Epsilon: 0.58, Rolling Avg: -159.30, Steps:  102 Terminated: True
# Episode:  55/2000, Reward: -199.46, Epsilon: 0.58, Rolling Avg: -160.70, Steps:  122 Terminated: True
# Episode:  56/2000, Reward: -137.37, Epsilon: 0.57, Rolling Avg: -161.91, Steps:  153 Terminated: True
# Episode:  57/2000, Reward: -206.14, Epsilon: 0.56, Rolling Avg: -163.90, Steps:  184 Terminated: True
# Episode:  58/2000, Reward:  -86.19, Epsilon: 0.56, Rolling Avg: -161.17, Steps:   88 Terminated: True
# Episode:  59/2000, Reward: -120.87, Epsilon: 0.55, Rolling Avg: -163.15, Steps:  139 Terminated: True
# Episode:  60/2000, Reward: -146.12, Epsilon: 0.55, Rolling Avg: -163.97, Steps:  145 Terminated: True
# Episode:  61/2000, Reward:  -91.23, Epsilon: 0.54, Rolling Avg: -162.81, Steps:  142 Terminated: True
# Episode:  62/2000, Reward: -140.11, Epsilon: 0.54, Rolling Avg: -161.04, Steps:  214 Terminated: True
# Episode:  63/2000, Reward: -122.39, Epsilon: 0.53, Rolling Avg: -158.74, Steps:  179 Terminated: True
# Episode:  64/2000, Reward:   -4.38, Epsilon: 0.53, Rolling Avg: -149.93, Steps:  125 Terminated: True
# Episode:  65/2000, Reward: -136.21, Epsilon: 0.52, Rolling Avg: -144.82, Steps:  141 Terminated: True
# Episode:  66/2000, Reward:  -62.38, Epsilon: 0.52, Rolling Avg: -143.84, Steps:  154 Terminated: True
# Episode:  67/2000, Reward:  -43.89, Epsilon: 0.51, Rolling Avg: -142.12, Steps:  126 Terminated: True
# Episode:  68/2000, Reward:  -70.11, Epsilon: 0.50, Rolling Avg: -141.57, Steps:  186 Terminated: True
# Episode:  69/2000, Reward:   -7.87, Epsilon: 0.50, Rolling Avg: -139.69, Steps:  196 Terminated: True
# Episode:  70/2000, Reward:  -51.32, Epsilon: 0.49, Rolling Avg: -136.73, Steps:  187 Terminated: True
# Episode:  71/2000, Reward: -124.04, Epsilon: 0.49, Rolling Avg: -134.50, Steps:  572 Terminated: True
# Episode:  72/2000, Reward:  -97.14, Epsilon: 0.48, Rolling Avg: -127.15, Steps:  115 Terminated: True
# Episode:  73/2000, Reward: -210.30, Epsilon: 0.48, Rolling Avg: -130.17, Steps:  148 Terminated: True
# Episode:  74/2000, Reward: -158.97, Epsilon: 0.48, Rolling Avg: -128.22, Steps:  203 Terminated: True
# Episode:  75/2000, Reward: -188.29, Epsilon: 0.47, Rolling Avg: -132.96, Steps:  328 Terminated: True
# Episode:  76/2000, Reward: -250.30, Epsilon: 0.47, Rolling Avg: -137.21, Steps:  198 Terminated: True
# Episode:  77/2000, Reward:  -33.98, Epsilon: 0.46, Rolling Avg: -134.60, Steps:  134 Terminated: True
# Episode:  78/2000, Reward:  -69.53, Epsilon: 0.46, Rolling Avg: -127.61, Steps:  105 Terminated: True
# Episode:  79/2000, Reward:  +16.47, Epsilon: 0.45, Rolling Avg: -119.64, Steps:  238 Terminated: True
# Episode:  80/2000, Reward:  -66.55, Epsilon: 0.45, Rolling Avg: -118.37, Steps:  113 Terminated: True
# Episode:  81/2000, Reward:  -24.68, Epsilon: 0.44, Rolling Avg: -111.19, Steps:  180 Terminated: True
# Episode:  82/2000, Reward: -192.26, Epsilon: 0.44, Rolling Avg: -112.57, Steps:  222 Terminated: True
# Episode:  83/2000, Reward:  -87.68, Epsilon: 0.43, Rolling Avg: -112.31, Steps:  209 Terminated: True
# Episode:  84/2000, Reward:  -62.27, Epsilon: 0.43, Rolling Avg: -109.27, Steps:  179 Terminated: True
# Episode:  85/2000, Reward:   -7.90, Epsilon: 0.43, Rolling Avg: -106.25, Steps:  157 Terminated: True
# Episode:  86/2000, Reward:  +15.84, Epsilon: 0.42, Rolling Avg: -106.57, Steps:  145 Terminated: True
# Episode:  87/2000, Reward:  -51.47, Epsilon: 0.42, Rolling Avg: -100.84, Steps:  344 Terminated: True
# Episode:  88/2000, Reward:  +11.44, Epsilon: 0.41, Rolling Avg:  -98.80, Steps:  193 Terminated: True
# Episode:  89/2000, Reward: -214.65, Epsilon: 0.41, Rolling Avg:  -98.37, Steps:  401 Terminated: True
# Episode:  90/2000, Reward: -157.96, Epsilon: 0.40, Rolling Avg: -100.12, Steps: 1199 Terminated: False
# Episode:  91/2000, Reward:  -53.63, Epsilon: 0.40, Rolling Avg:  -97.55, Steps:  179 Terminated: True
# Episode:  92/2000, Reward:  +30.70, Epsilon: 0.40, Rolling Avg:  -96.04, Steps:  113 Terminated: True
# Episode:  93/2000, Reward:  -96.44, Epsilon: 0.39, Rolling Avg:  -92.37, Steps: 1199 Terminated: False
# Episode:  94/2000, Reward:  -85.70, Epsilon: 0.39, Rolling Avg:  -94.63, Steps: 1199 Terminated: False
# Episode:  95/2000, Reward:  -76.85, Epsilon: 0.38, Rolling Avg:  -91.57, Steps: 1199 Terminated: False
# Episode:  96/2000, Reward:  -77.72, Epsilon: 0.38, Rolling Avg:  -90.08, Steps: 1199 Terminated: False
# Episode:  97/2000, Reward:  -37.16, Epsilon: 0.38, Rolling Avg:  -85.85, Steps: 1199 Terminated: False
# Episode:  98/2000, Reward:   -4.00, Epsilon: 0.37, Rolling Avg:  -83.80, Steps:  134 Terminated: True
# Episode:  99/2000, Reward:  -29.80, Epsilon: 0.37, Rolling Avg:  -81.52, Steps:  382 Terminated: True
# Episode: 100/2000, Reward:   -1.73, Epsilon: 0.37, Rolling Avg:  -77.91, Steps:   88 Terminated: True
# Episode: 101/2000, Reward: -266.52, Epsilon: 0.36, Rolling Avg:  -82.29, Steps: 1032 Terminated: True
# Episode: 102/2000, Reward:  -23.91, Epsilon: 0.36, Rolling Avg:  -79.39, Steps:  170 Terminated: True
# Episode: 103/2000, Reward:  -68.30, Epsilon: 0.36, Rolling Avg:  -78.04, Steps: 1199 Terminated: False
# Episode: 104/2000, Reward:  -30.92, Epsilon: 0.35, Rolling Avg:  -78.70, Steps:  115 Terminated: True
# Episode: 105/2000, Reward: -119.43, Epsilon: 0.35, Rolling Avg:  -78.28, Steps: 1199 Terminated: False
# Episode: 106/2000, Reward:  -26.14, Epsilon: 0.34, Rolling Avg:  -77.37, Steps:  139 Terminated: True
# Episode: 107/2000, Reward:  -56.41, Epsilon: 0.34, Rolling Avg:  -77.69, Steps:   72 Terminated: True
# Episode: 108/2000, Reward: -329.98, Epsilon: 0.34, Rolling Avg:  -84.18, Steps:  932 Terminated: True
# Episode: 109/2000, Reward:  -71.34, Epsilon: 0.33, Rolling Avg:  -85.77, Steps:  150 Terminated: True
# Episode: 110/2000, Reward:  -31.40, Epsilon: 0.33, Rolling Avg:  -85.27, Steps: 1199 Terminated: False
# Episode: 111/2000, Reward:  -20.99, Epsilon: 0.33, Rolling Avg:  -82.70, Steps: 1199 Terminated: False
# Episode: 112/2000, Reward:  -67.75, Epsilon: 0.32, Rolling Avg:  -81.96, Steps: 1199 Terminated: False
# Episode: 113/2000, Reward:  -46.89, Epsilon: 0.32, Rolling Avg:  -77.88, Steps: 1199 Terminated: False
# Episode: 114/2000, Reward:  -28.68, Epsilon: 0.32, Rolling Avg:  -74.62, Steps: 1199 Terminated: False
# Episode: 115/2000, Reward:   +5.73, Epsilon: 0.31, Rolling Avg:  -69.77, Steps: 1199 Terminated: False
# Episode: 116/2000, Reward: -226.99, Epsilon: 0.31, Rolling Avg:  -69.19, Steps: 1199 Terminated: False
# Episode: 117/2000, Reward: -117.54, Epsilon: 0.31, Rolling Avg:  -71.27, Steps: 1199 Terminated: False
# Episode: 118/2000, Reward:  -15.05, Epsilon: 0.31, Rolling Avg:  -69.91, Steps: 1199 Terminated: False
# Episode: 119/2000, Reward:  -85.31, Epsilon: 0.30, Rolling Avg:  -72.46, Steps: 1199 Terminated: False
# Episode: 120/2000, Reward: -227.40, Epsilon: 0.30, Rolling Avg:  -76.48, Steps:  411 Terminated: True
# Episode: 121/2000, Reward: -323.49, Epsilon: 0.30, Rolling Avg:  -83.95, Steps:  923 Terminated: True
# Episode: 122/2000, Reward:  +22.15, Epsilon: 0.29, Rolling Avg:  -78.59, Steps: 1199 Terminated: False
# Episode: 123/2000, Reward: -239.59, Epsilon: 0.29, Rolling Avg:  -82.39, Steps:  989 Terminated: True
# Episode: 124/2000, Reward: -209.44, Epsilon: 0.29, Rolling Avg:  -86.07, Steps:  305 Terminated: True
# Episode: 125/2000, Reward:  -19.28, Epsilon: 0.28, Rolling Avg:  -86.35, Steps: 1199 Terminated: False
# Episode: 126/2000, Reward:   -3.82, Epsilon: 0.28, Rolling Avg:  -86.84, Steps: 1199 Terminated: False
# Episode: 127/2000, Reward:  -31.21, Epsilon: 0.28, Rolling Avg:  -86.33, Steps: 1199 Terminated: False
# Episode: 128/2000, Reward:  -93.91, Epsilon: 0.28, Rolling Avg:  -88.97, Steps: 1199 Terminated: False
# Episode: 129/2000, Reward: -279.17, Epsilon: 0.27, Rolling Avg:  -90.58, Steps:  482 Terminated: True
# Episode: 130/2000, Reward: -230.87, Epsilon: 0.27, Rolling Avg:  -92.40, Steps:  488 Terminated: True
# Episode: 131/2000, Reward: -311.62, Epsilon: 0.27, Rolling Avg:  -98.85, Steps:   71 Terminated: True
# Episode: 132/2000, Reward: -150.13, Epsilon: 0.27, Rolling Avg: -103.37, Steps:  106 Terminated: True
# Episode: 133/2000, Reward:  -17.64, Epsilon: 0.26, Rolling Avg: -101.40, Steps: 1199 Terminated: False
# Episode: 134/2000, Reward: +165.61, Epsilon: 0.26, Rolling Avg:  -95.12, Steps:  994 Terminated: True
# Episode: 135/2000, Reward:   +1.66, Epsilon: 0.26, Rolling Avg:  -93.16, Steps:   90 Terminated: True
# Episode: 136/2000, Reward: +154.61, Epsilon: 0.25, Rolling Avg:  -87.35, Steps:  802 Terminated: True
# Episode: 137/2000, Reward:  +45.30, Epsilon: 0.25, Rolling Avg:  -85.29, Steps: 1199 Terminated: False
# Episode: 138/2000, Reward: -103.40, Epsilon: 0.25, Rolling Avg:  -87.77, Steps: 1199 Terminated: False
# Episode: 139/2000, Reward:  +74.09, Epsilon: 0.25, Rolling Avg:  -85.18, Steps: 1199 Terminated: False
# Episode: 140/2000, Reward: +105.18, Epsilon: 0.24, Rolling Avg:  -82.50, Steps: 1199 Terminated: False
# Episode: 141/2000, Reward: +227.49, Epsilon: 0.24, Rolling Avg:  -70.15, Steps:  555 Terminated: True
# Episode: 142/2000, Reward:  +62.98, Epsilon: 0.24, Rolling Avg:  -67.98, Steps: 1199 Terminated: False
# Episode: 143/2000, Reward: -110.26, Epsilon: 0.24, Rolling Avg:  -69.03, Steps: 1199 Terminated: False
# Episode: 144/2000, Reward: +104.22, Epsilon: 0.24, Rolling Avg:  -65.65, Steps: 1199 Terminated: False
# Episode: 145/2000, Reward:  +25.05, Epsilon: 0.23, Rolling Avg:  -62.04, Steps: 1199 Terminated: False
# Episode: 146/2000, Reward: +219.27, Epsilon: 0.23, Rolling Avg:  -55.91, Steps:  442 Terminated: True
# Episode: 147/2000, Reward:  +65.20, Epsilon: 0.23, Rolling Avg:  -52.86, Steps: 1199 Terminated: False
# Episode: 148/2000, Reward:  -57.57, Epsilon: 0.23, Rolling Avg:  -46.05, Steps: 1199 Terminated: False
# Episode: 149/2000, Reward:  +71.27, Epsilon: 0.22, Rolling Avg:  -42.49, Steps: 1199 Terminated: False
# Episode: 150/2000, Reward: +142.70, Epsilon: 0.22, Rolling Avg:  -38.14, Steps: 1199 Terminated: False
# Episode: 151/2000, Reward: +108.48, Epsilon: 0.22, Rolling Avg:  -34.90, Steps: 1199 Terminated: False
# Episode: 152/2000, Reward: +118.30, Epsilon: 0.22, Rolling Avg:  -30.25, Steps: 1199 Terminated: False
# Episode: 153/2000, Reward: +115.97, Epsilon: 0.21, Rolling Avg:  -26.18, Steps: 1199 Terminated: False
# Episode: 154/2000, Reward: +232.87, Epsilon: 0.21, Rolling Avg:  -19.64, Steps:  628 Terminated: True
# Episode: 155/2000, Reward: +154.26, Epsilon: 0.21, Rolling Avg:  -15.93, Steps: 1199 Terminated: False
# Episode: 156/2000, Reward: +110.85, Epsilon: 0.21, Rolling Avg:   -7.48, Steps: 1199 Terminated: False
# Episode: 157/2000, Reward: +235.28, Epsilon: 0.21, Rolling Avg:    1.34, Steps:  606 Terminated: True
# Episode: 158/2000, Reward: +206.21, Epsilon: 0.20, Rolling Avg:    6.87, Steps:  761 Terminated: True
# Episode: 159/2000, Reward:  +88.28, Epsilon: 0.20, Rolling Avg:   11.21, Steps: 1199 Terminated: False
# Episode: 160/2000, Reward: +238.19, Epsilon: 0.20, Rolling Avg:   22.85, Steps: 1085 Terminated: True
# Episode: 161/2000, Reward: -131.82, Epsilon: 0.20, Rolling Avg:   27.64, Steps:  717 Terminated: True
# Episode: 162/2000, Reward: +209.82, Epsilon: 0.20, Rolling Avg:   32.34, Steps:  717 Terminated: True
# Episode: 163/2000, Reward: +231.57, Epsilon: 0.19, Rolling Avg:   44.11, Steps: 1105 Terminated: True
# Episode: 164/2000, Reward:  +80.33, Epsilon: 0.19, Rolling Avg:   51.36, Steps: 1199 Terminated: False
# Episode: 165/2000, Reward:  +75.43, Epsilon: 0.19, Rolling Avg:   53.73, Steps: 1199 Terminated: False
# Episode: 166/2000, Reward:  -67.64, Epsilon: 0.19, Rolling Avg:   52.13, Steps: 1199 Terminated: False
# Episode: 167/2000, Reward: +166.79, Epsilon: 0.19, Rolling Avg:   57.08, Steps:  996 Terminated: True
# Episode: 168/2000, Reward: +248.28, Epsilon: 0.18, Rolling Avg:   65.64, Steps:  620 Terminated: True
# Episode: 169/2000, Reward: +234.01, Epsilon: 0.18, Rolling Avg:   78.47, Steps: 1182 Terminated: True
# Episode: 170/2000, Reward: +258.09, Epsilon: 0.18, Rolling Avg:   90.69, Steps: 1096 Terminated: True
# Episode: 171/2000, Reward: +242.38, Epsilon: 0.18, Rolling Avg:  104.54, Steps:  634 Terminated: True
# Episode: 172/2000, Reward:  +87.05, Epsilon: 0.18, Rolling Avg:  110.47, Steps: 1199 Terminated: False
# Episode: 173/2000, Reward: +141.48, Epsilon: 0.18, Rolling Avg:  114.45, Steps: 1199 Terminated: False
# Episode: 174/2000, Reward: +245.09, Epsilon: 0.17, Rolling Avg:  116.43, Steps:  590 Terminated: True
# Episode: 175/2000, Reward: +220.89, Epsilon: 0.17, Rolling Avg:  121.91, Steps:  273 Terminated: True
# Episode: 176/2000, Reward: +226.46, Epsilon: 0.17, Rolling Avg:  123.71, Steps:  636 Terminated: True
# Episode: 177/2000, Reward: +229.88, Epsilon: 0.17, Rolling Avg:  128.33, Steps:  432 Terminated: True
# Episode: 178/2000, Reward: +217.11, Epsilon: 0.17, Rolling Avg:  136.34, Steps:  926 Terminated: True
# Episode: 179/2000, Reward: +261.27, Epsilon: 0.17, Rolling Avg:  141.02, Steps:  406 Terminated: True
# Episode: 180/2000, Reward: +220.51, Epsilon: 0.16, Rolling Avg:  143.90, Steps: 1114 Terminated: True
# Episode: 181/2000, Reward: +251.04, Epsilon: 0.16, Rolling Avg:  144.49, Steps:  481 Terminated: True
# Episode: 182/2000, Reward: +142.30, Epsilon: 0.16, Rolling Avg:  146.47, Steps: 1199 Terminated: False
# Episode: 183/2000, Reward: +245.68, Epsilon: 0.16, Rolling Avg:  155.37, Steps:  305 Terminated: True
# Episode: 184/2000, Reward: +288.90, Epsilon: 0.16, Rolling Avg:  159.99, Steps:  591 Terminated: True
# Episode: 185/2000, Reward: +256.71, Epsilon: 0.16, Rolling Avg:  165.78, Steps:  414 Terminated: True
# Episode: 186/2000, Reward: +282.42, Epsilon: 0.15, Rolling Avg:  167.36, Steps:  411 Terminated: True
# Episode: 187/2000, Reward: +267.94, Epsilon: 0.15, Rolling Avg:  172.43, Steps:  522 Terminated: True
# Episode: 188/2000, Reward: +241.41, Epsilon: 0.15, Rolling Avg:  179.90, Steps:  652 Terminated: True
# Episode: 189/2000, Reward: +245.79, Epsilon: 0.15, Rolling Avg:  184.26, Steps:  482 Terminated: True
# Episode: 190/2000, Reward: +281.84, Epsilon: 0.15, Rolling Avg:  187.74, Steps:  321 Terminated: True
# Episode: 191/2000, Reward: +275.89, Epsilon: 0.15, Rolling Avg:  191.93, Steps:  329 Terminated: True
# Episode: 192/2000, Reward: +253.37, Epsilon: 0.15, Rolling Avg:  195.30, Steps:  434 Terminated: True
# Episode: 193/2000, Reward: +217.65, Epsilon: 0.14, Rolling Avg:  197.85, Steps:  495 Terminated: True
# Episode: 194/2000, Reward: +248.80, Epsilon: 0.14, Rolling Avg:  198.24, Steps:  661 Terminated: True
# Episode: 195/2000, Reward: +249.43, Epsilon: 0.14, Rolling Avg:  200.62, Steps:  783 Terminated: True
# Environment solved in 195 episodes!
# Training completed in 3.34 minutes

# %% [markdown]
# #### **Learning Plot and Episode Rewards**

# %%
# Plot rewards with rolling average

plt.figure(figsize=(10, 6))
plt.plot(rewards_per_episode, label='Rewards', color='blue')
plt.plot(rolling_avg_rewards, label='Rolling Avg (Last '+str(ROLLING_WINDOW) +' Episodes)', color='orange')
plt.axhline(y=solved_threshold, color='red', linestyle='--', label='Solved Threshold')
plt.title('DQN Training Performance LUNARLANDER')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### **Simulation - Testing 10 episodes with the DQN Network**

# %%
# Testing for 10 episodes
start_time = time.time()

for e_test in range(10):  # Run 10 test episodes
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    steps = 0
    while True:
        # Use the trained model for testing
        action = agent.action(state)  # Estimate action values


        next_state, reward, done, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward
        state = next_state
        steps = steps + 1
        if done or truncated:
            print(f"Test Episode: {e_test + 1:2}/10, Reward: {total_reward:.2f}, Steps: {steps:3}")
            break

end_time = time.time()
testing_duration = (end_time - start_time) / 60  # Convert to minutes
print(f"Testing completed in {testing_duration:.2f} minutes")
# Out:
# Test Episode:  1/10, Reward: 234.11, Steps: 295
# Test Episode:  2/10, Reward: 304.69, Steps: 273
# Test Episode:  3/10, Reward: 237.33, Steps: 333
# Test Episode:  4/10, Reward: 281.94, Steps: 259
# Test Episode:  5/10, Reward: 249.42, Steps: 252
# Test Episode:  6/10, Reward: 284.28, Steps: 216
# Test Episode:  7/10, Reward: 226.42, Steps: 262
# Test Episode:  8/10, Reward: 238.88, Steps: 359
# Test Episode:  9/10, Reward: 272.86, Steps: 266
# Test Episode: 10/10, Reward: 290.57, Steps: 260
# Testing completed in 0.00 minutes

# %% [markdown]
# #### **Rendering 1 episode**

# %%
# Test the trained agent with video rendering
# This code is useful if you are using colab otherwise use render_mode='human'
env = gym.make(('LunarLander-v3'), render_mode='rgb_array')  # Enable RGB rendering
frames = []  # Store frames for visualization

# Render a single test episode
state, _ = env.reset()
state = np.reshape(state, [1, state_size])
tot_rewards = 0

while True:
    # Use the trained model for action
    action = agent.action(state)            # Estimate action value

    next_state, reward, done, truncated, _ = env.step(action)
    frames.append(env.render())                  # Save frame for rendering later
    next_state = np.reshape(next_state, [1, state_size])
    tot_rewards += reward
    state = next_state

    if done or truncated:
        print(f"Rendered Test Episode Reward: {tot_rewards:.2f}")
        break

env.close()

# Save the rendered episode as a GIF
def save_frames_as_gif(frames, path='./', filename='LUNARLANDER_Agent_DQN.gif'):
    images = [Image.fromarray(frame) for frame in frames]
    gif_path = os.path.join(path, filename)
    images[0].save(gif_path, save_all=True, append_images=images[1:], duration=50, loop=0)
    print(f"Saved GIF to: {gif_path}")

save_frames_as_gif(frames, filename='LUNARLANDER_Agent_DQN.gif')
# Out:
# Rendered Test Episode Reward: 262.02
# Saved GIF to: ./LUNARLANDER_Agent_DQN.gif

# %%
import session_info
session_info.show(html=False)
# Out:
# -----
# PIL                 12.1.0
# gymnasium           1.2.2
# matplotlib          3.10.8
# numpy               2.4.2
# session_info        v1.0.1
# torch               2.11.0+cu130
# -----
# IPython             9.10.0
# jupyter_client      8.8.0
# jupyter_core        5.9.1
# -----
# Python 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]
# Linux-6.17.0-1014-nvidia-aarch64-with-glibc2.39
# -----
# Session information updated at 2026-05-14 11:51

# %% [markdown]
# ### **Lunar Lander DDQN TORCH**
#
# This is a naive version of the Lunar Lander DDQN algorithm using an Agent Class<br>
#
# There is no Gradient Clipping in this example. Would you improve with Gradient Clipping?
# <br>
# In this version the agent has been created as a class making the code more compact <br>
# This DDQN Class can be used with other environments <br>
#  <br>
# Try to make it faster by doing some hyperparameter optimization  <br>
# Try to explore less. Does it accelerates convergence?  <br>
# Increasing the ```ROLLING_WINDOW``` value will gnerate slower agent convergence but the Agent behavior will be more consistent <br>
#
# An issue you may find is a lander that hovers forever. This happens because it has been programmed with infinite fuel. You can see it in this execution in the lines that are marked as ```Terminated=False```. This confuses the training because it does not reach the objective or termination. Without modifying the environment, there are a couple of things that can be done to ameliorate this behavior <br>
#
# 1. **Limit number of steps** In this case we are limiting the number of steps to 1200, if you don't limit it sometimes it goes up to thousands of steps, and this is a waste of time
# 2. **Increase gravity** The default gravity in this environment is -10.0, you can increase it up to -12.0, increasing it you'll have a faster descent and hovering becomes more difficult ```env = gym.make("LunarLander-v3", gravity=11.0)```

# %%
import os
import random
import gymnasium as gym
import time
import numpy as np
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from PIL import Image
import time

import sys
sys.stderr = open('err.txt', 'w')
# Out:
# /home/jaumemanero/RL/lib/python3.10/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version (built):", torch.version.cuda)
print("Device count:", torch.cuda.device_count())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"  GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"    Compute capability: {torch.cuda.get_device_capability(i)}")
        print(f"    Memory: {torch.cuda.get_device_properties(i).total_memory / 1e9:.1f} GB")

    # Quick sanity check: actually run something on the GPU
    x = torch.randn(1000, 1000, device="cuda")
    y = x @ x
    print("Matmul on GPU OK, result shape:", y.shape)
else:
    print("No GPU visible to PyTorch.")
# Out:
# PyTorch version: 2.9.0+cu128
# CUDA available: False
# CUDA version (built): 12.8
# Device count: 0
# No GPU visible to PyTorch.

# %% [markdown]
# #### **Hyperparameters**

# %%
MAX_EPISODES = 2000
ROLLING_WINDOW = 40
MEMORY_SIZE = 100_000
MAX_STEPS = 1200

gamma = 0.99                         # discount rate
epsilon = 1.0                        # exploration rate
epsilon_min = 0.02
epsilon_decay = 0.99
learning_rate = 5e-4
batch_size = 64
solved_threshold = 200
REFRESH_TARGET_NET = 10
TAU = 0.005
UPDATE_WEIGHTS = 'soft'       # choose 'soft' or 'hard'


verb = 0                             # to see traces (verbosity)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Environment setup
env = gym.make('LunarLander-v3')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
class Q_Network(nn.Module):
    def __init__(self, state_size, action_size):
        super().__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.out = nn.Linear(32, action_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        return self.out(x)

# %%
class Agent_DDQN():
    def __init__(self, states, actions, alpha, gamma, epsilon):
        self.nS = states
        self.nA = actions
        self.replay_buffer = deque([], maxlen=MEMORY_SIZE)
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        # 1. Initialize TWO networks
        self.model = self.build_NN()
        self.target_model = self.build_NN()
        
        # Sync them initially
        self.update_target_network(update_type='hard')
        
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()
        self.loss = []
        self.step_count = 0 

    def build_NN(self):
        return Q_Network(self.nS, self.nA).to(device)

    def update_target_network(self, update_type=UPDATE_WEIGHTS, tau=TAU):
        if update_type == 'hard':
            self.target_model.load_state_dict(self.model.state_dict())
        elif update_type == 'soft':
            for target_param, model_param in zip(self.target_model.parameters(), self.model.parameters()):
                target_param.data.copy_(tau * model_param.data + (1.0 - tau) * target_param.data)
        else:
            raise ValueError("UPDATE_WEIGHTS must be 'soft' or 'hard'")

    def action(self, state):
        state_tensor = torch.as_tensor(state, dtype=torch.float32, device=device)
        self.model.eval()
        with torch.no_grad():
            action_vals = self.model(state_tensor)
        self.model.train()
        return torch.argmax(action_vals[0]).item()
    
    def random_action(self):
        return random.randrange(self.nA)
    
    def store_experience(self, state, action, reward, next_state, done):
        self.replay_buffer.append((state, action, reward, next_state, done))

    def sample_experiences(self, batch_size):
        indices = np.random.choice(len(self.replay_buffer), batch_size, replace=False)
        batch = [self.replay_buffer[i] for i in indices]
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            np.vstack(states),
            np.array(actions),
            np.array(rewards),
            np.vstack(next_states),
            np.array(dones, dtype=np.float32)
        )
    
    def experience_replay(self, batch_size, epsilon):
        if len(self.replay_buffer) < batch_size:
            return
        
        self.step_count += 1
        states, actions, rewards, next_states, dones = self.sample_experiences(batch_size)

        states_tensor = torch.as_tensor(states, dtype=torch.float32, device=device)
        actions_tensor = torch.as_tensor(actions, dtype=torch.long, device=device)
        rewards_tensor = torch.as_tensor(rewards, dtype=torch.float32, device=device)
        next_states_tensor = torch.as_tensor(next_states, dtype=torch.float32, device=device)
        dones_tensor = torch.as_tensor(dones, dtype=torch.float32, device=device)

        q_values = self.model(states_tensor)
        with torch.no_grad():
            # DDQN: choose next action with the online network, evaluate it with the target network
            next_actions = torch.argmax(self.model(next_states_tensor), dim=1)
            next_qs = self.target_model(next_states_tensor)
            next_q_values = next_qs[torch.arange(batch_size, device=device), next_actions]
            target_qs = q_values.detach().clone()
            target_qs[torch.arange(batch_size, device=device), actions_tensor] = (
                rewards_tensor + self.gamma * next_q_values * (1 - dones_tensor)
            )

        loss = self.loss_fn(q_values, target_qs)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.loss.append(loss.item())

        # Sync target network every REFRESH_TARGET_NET steps
        if self.step_count % REFRESH_TARGET_NET == 0:
            self.update_target_network()

# %%
# Support function
def select_action_greedy(state, agent_DDQN):                                    
    if np.random.rand() <= epsilon:
        return agent_DDQN.random_action()
    return agent_DDQN.action(state)

# %% [markdown]
# #### **Main Loop**

# %%
env = gym.make('LunarLander-v3')
state_size = int(env.observation_space.shape[0])
action_size = int(env.action_space.n)

agent = Agent_DDQN(state_size, action_size, learning_rate, gamma, epsilon)

# %%
rewards_per_episode= []
start_time = time.time()

done = False
rolling_avg = 0
rolling_avg_rewards = []



for e in range(MAX_EPISODES):                           # Should be While True, however we limit number of eps
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    for step in range(MAX_STEPS):
            
        action = select_action_greedy(state, agent)
        next_state, reward, done, truncated , _ = env.step(action)
                    
        next_state = np.reshape(next_state, [1, state_size])
        agent.store_experience(state, action, reward, next_state, done)
        state = next_state
        total_reward = total_reward + reward
        if done:
            break
            
        
        agent.experience_replay(batch_size, epsilon)
            
    epsilon = max(epsilon_min, epsilon * epsilon_decay)            # decay epsilon
    
    rewards_per_episode.append(total_reward)
    rolling_avg = np.mean(rewards_per_episode[-ROLLING_WINDOW:])   # append rewards
    rolling_avg_rewards.append(rolling_avg)
    print(f"Episode: {e+1:3}/{MAX_EPISODES}, Reward: {total_reward:+7.2f}, "
          f"Epsilon: {epsilon:.2f}, Rolling Avg: {rolling_avg:7.2f}, Steps: {step:4} Terminated: {done} ")

            
    # Check if environment is solved
    if rolling_avg >= solved_threshold:
        print(f"Environment solved in {e+1} episodes!")
        break

end_time = time.time()
print(f"Training completed in {(end_time - start_time)/60:.2f} minutes")
# Out:
# Episode:   1/2000, Reward: -279.62, Epsilon: 0.99, Rolling Avg: -279.62, Steps:   81 Terminated: True
# Episode:   2/2000, Reward: -129.72, Epsilon: 0.98, Rolling Avg: -204.67, Steps:  108 Terminated: True
# Episode:   3/2000, Reward:  -88.44, Epsilon: 0.97, Rolling Avg: -165.93, Steps:   72 Terminated: True
# Episode:   4/2000, Reward: -129.21, Epsilon: 0.96, Rolling Avg: -156.75, Steps:   68 Terminated: True
# Episode:   5/2000, Reward: -156.17, Epsilon: 0.95, Rolling Avg: -156.63, Steps:  120 Terminated: True
# Episode:   6/2000, Reward: -101.75, Epsilon: 0.94, Rolling Avg: -147.48, Steps:  101 Terminated: True
# Episode:   7/2000, Reward:  -86.79, Epsilon: 0.93, Rolling Avg: -138.81, Steps:   68 Terminated: True
# Episode:   8/2000, Reward: -173.45, Epsilon: 0.92, Rolling Avg: -143.14, Steps:   69 Terminated: True
# Episode:   9/2000, Reward: -109.21, Epsilon: 0.91, Rolling Avg: -139.37, Steps:   75 Terminated: True
# Episode:  10/2000, Reward:  -91.94, Epsilon: 0.90, Rolling Avg: -134.63, Steps:   90 Terminated: True
# Episode:  11/2000, Reward: -382.45, Epsilon: 0.90, Rolling Avg: -157.16, Steps:  114 Terminated: True
# Episode:  12/2000, Reward: -132.99, Epsilon: 0.89, Rolling Avg: -155.15, Steps:  115 Terminated: True
# Episode:  13/2000, Reward: -104.98, Epsilon: 0.88, Rolling Avg: -151.29, Steps:  104 Terminated: True
# Episode:  14/2000, Reward:  -72.57, Epsilon: 0.87, Rolling Avg: -145.66, Steps:  105 Terminated: True
# Episode:  15/2000, Reward: -147.56, Epsilon: 0.86, Rolling Avg: -145.79, Steps:   72 Terminated: True
# Episode:  16/2000, Reward:  -88.94, Epsilon: 0.85, Rolling Avg: -142.24, Steps:   65 Terminated: True
# Episode:  17/2000, Reward: -316.96, Epsilon: 0.84, Rolling Avg: -152.51, Steps:   74 Terminated: True
# Episode:  18/2000, Reward: -249.15, Epsilon: 0.83, Rolling Avg: -157.88, Steps:  121 Terminated: True
# Episode:  19/2000, Reward: -211.17, Epsilon: 0.83, Rolling Avg: -160.69, Steps:  161 Terminated: True
# Episode:  20/2000, Reward:  -74.63, Epsilon: 0.82, Rolling Avg: -156.38, Steps:   62 Terminated: True
# Episode:  21/2000, Reward: -136.96, Epsilon: 0.81, Rolling Avg: -155.46, Steps:   79 Terminated: True
# Episode:  22/2000, Reward: -156.70, Epsilon: 0.80, Rolling Avg: -155.52, Steps:  107 Terminated: True
# Episode:  23/2000, Reward: -147.04, Epsilon: 0.79, Rolling Avg: -155.15, Steps:  138 Terminated: True
# Episode:  24/2000, Reward: -350.64, Epsilon: 0.79, Rolling Avg: -163.29, Steps:   77 Terminated: True
# Episode:  25/2000, Reward: -142.46, Epsilon: 0.78, Rolling Avg: -162.46, Steps:  168 Terminated: True
# Episode:  26/2000, Reward: -112.17, Epsilon: 0.77, Rolling Avg: -160.53, Steps:   90 Terminated: True
# Episode:  27/2000, Reward: -346.99, Epsilon: 0.76, Rolling Avg: -167.43, Steps:  100 Terminated: True
# Episode:  28/2000, Reward: -212.81, Epsilon: 0.75, Rolling Avg: -169.05, Steps:   94 Terminated: True
# Episode:  29/2000, Reward:  -63.88, Epsilon: 0.75, Rolling Avg: -165.43, Steps:   90 Terminated: True
# Episode:  30/2000, Reward:  -74.62, Epsilon: 0.74, Rolling Avg: -162.40, Steps:  124 Terminated: True
# Episode:  31/2000, Reward:  -35.84, Epsilon: 0.73, Rolling Avg: -158.32, Steps:  165 Terminated: True
# Episode:  32/2000, Reward: -230.18, Epsilon: 0.72, Rolling Avg: -160.56, Steps:  166 Terminated: True
# Episode:  33/2000, Reward:  -77.85, Epsilon: 0.72, Rolling Avg: -158.06, Steps:   71 Terminated: True
# Episode:  34/2000, Reward: -462.51, Epsilon: 0.71, Rolling Avg: -167.01, Steps:   99 Terminated: True
# Episode:  35/2000, Reward: -287.00, Epsilon: 0.70, Rolling Avg: -170.44, Steps:  137 Terminated: True
# Episode:  36/2000, Reward: -164.52, Epsilon: 0.70, Rolling Avg: -170.27, Steps:  152 Terminated: True
# Episode:  37/2000, Reward: -108.80, Epsilon: 0.69, Rolling Avg: -168.61, Steps:  111 Terminated: True
# Episode:  38/2000, Reward: -127.97, Epsilon: 0.68, Rolling Avg: -167.54, Steps:  124 Terminated: True
# Episode:  39/2000, Reward:  -85.18, Epsilon: 0.68, Rolling Avg: -165.43, Steps:  116 Terminated: True
# Episode:  40/2000, Reward: -104.58, Epsilon: 0.67, Rolling Avg: -163.91, Steps:  145 Terminated: True
# Episode:  41/2000, Reward: -198.80, Epsilon: 0.66, Rolling Avg: -161.89, Steps:  200 Terminated: True
# Episode:  42/2000, Reward: -201.41, Epsilon: 0.66, Rolling Avg: -163.68, Steps:  207 Terminated: True
# Episode:  43/2000, Reward:  -44.34, Epsilon: 0.65, Rolling Avg: -162.58, Steps:  119 Terminated: True
# Episode:  44/2000, Reward: -348.03, Epsilon: 0.64, Rolling Avg: -168.05, Steps:   88 Terminated: True
# Episode:  45/2000, Reward: -377.26, Epsilon: 0.64, Rolling Avg: -173.58, Steps:  226 Terminated: True
# Episode:  46/2000, Reward: -364.29, Epsilon: 0.63, Rolling Avg: -180.14, Steps:  119 Terminated: True
# Episode:  47/2000, Reward: -136.29, Epsilon: 0.62, Rolling Avg: -181.38, Steps:  151 Terminated: True
# Episode:  48/2000, Reward: -195.72, Epsilon: 0.62, Rolling Avg: -181.93, Steps:  137 Terminated: True
# Episode:  49/2000, Reward: -109.00, Epsilon: 0.61, Rolling Avg: -181.93, Steps:  143 Terminated: True
# Episode:  50/2000, Reward: -132.59, Epsilon: 0.61, Rolling Avg: -182.95, Steps:  108 Terminated: True
# Episode:  51/2000, Reward: -105.68, Epsilon: 0.60, Rolling Avg: -176.03, Steps:   98 Terminated: True
# Episode:  52/2000, Reward: -287.17, Epsilon: 0.59, Rolling Avg: -179.88, Steps:  115 Terminated: True
# Episode:  53/2000, Reward: -198.08, Epsilon: 0.59, Rolling Avg: -182.21, Steps:  141 Terminated: True
# Episode:  54/2000, Reward: -123.27, Epsilon: 0.58, Rolling Avg: -183.48, Steps:  188 Terminated: True
# Episode:  55/2000, Reward: -101.52, Epsilon: 0.58, Rolling Avg: -182.32, Steps:  164 Terminated: True
# Episode:  56/2000, Reward: -136.71, Epsilon: 0.57, Rolling Avg: -183.52, Steps:  108 Terminated: True
# Episode:  57/2000, Reward: -268.36, Epsilon: 0.56, Rolling Avg: -182.30, Steps:  101 Terminated: True
# Episode:  58/2000, Reward:  -69.91, Epsilon: 0.56, Rolling Avg: -177.82, Steps:  184 Terminated: True
# Episode:  59/2000, Reward: -148.23, Epsilon: 0.55, Rolling Avg: -176.25, Steps:  163 Terminated: True
# Episode:  60/2000, Reward:  -57.17, Epsilon: 0.55, Rolling Avg: -175.81, Steps:  121 Terminated: True
# Episode:  61/2000, Reward: -166.01, Epsilon: 0.54, Rolling Avg: -176.54, Steps:  160 Terminated: True
# Episode:  62/2000, Reward: -181.09, Epsilon: 0.54, Rolling Avg: -177.15, Steps:  141 Terminated: True
# Episode:  63/2000, Reward: -133.48, Epsilon: 0.53, Rolling Avg: -176.81, Steps:  113 Terminated: True
# Episode:  64/2000, Reward:  -26.33, Epsilon: 0.53, Rolling Avg: -168.70, Steps:  165 Terminated: True
# Episode:  65/2000, Reward:  -97.00, Epsilon: 0.52, Rolling Avg: -167.57, Steps:  126 Terminated: True
# Episode:  66/2000, Reward:  -92.32, Epsilon: 0.52, Rolling Avg: -167.07, Steps:  151 Terminated: True
# Episode:  67/2000, Reward: -139.55, Epsilon: 0.51, Rolling Avg: -161.88, Steps:  110 Terminated: True
# Episode:  68/2000, Reward: -205.35, Epsilon: 0.50, Rolling Avg: -161.70, Steps:  344 Terminated: True
# Episode:  69/2000, Reward: -101.73, Epsilon: 0.50, Rolling Avg: -162.64, Steps:  221 Terminated: True
# Episode:  70/2000, Reward: -125.84, Epsilon: 0.49, Rolling Avg: -163.92, Steps:  187 Terminated: True
# Episode:  71/2000, Reward:  -37.04, Epsilon: 0.49, Rolling Avg: -163.95, Steps:  318 Terminated: True
# Episode:  72/2000, Reward: -229.34, Epsilon: 0.48, Rolling Avg: -163.93, Steps:  139 Terminated: True
# Episode:  73/2000, Reward:  -62.16, Epsilon: 0.48, Rolling Avg: -163.54, Steps:  137 Terminated: True
# Episode:  74/2000, Reward: -109.34, Epsilon: 0.48, Rolling Avg: -154.71, Steps:  215 Terminated: True
# Episode:  75/2000, Reward: -132.29, Epsilon: 0.47, Rolling Avg: -150.84, Steps:   89 Terminated: True
# Episode:  76/2000, Reward: -105.37, Epsilon: 0.47, Rolling Avg: -149.37, Steps:  135 Terminated: True
# Episode:  77/2000, Reward: -171.98, Epsilon: 0.46, Rolling Avg: -150.94, Steps:  114 Terminated: True
# Episode:  78/2000, Reward:  -63.01, Epsilon: 0.46, Rolling Avg: -149.32, Steps:  297 Terminated: True
# Episode:  79/2000, Reward:  -86.43, Epsilon: 0.45, Rolling Avg: -149.35, Steps:  247 Terminated: True
# Episode:  80/2000, Reward: -311.72, Epsilon: 0.45, Rolling Avg: -154.53, Steps:  214 Terminated: True
# Episode:  81/2000, Reward: -114.84, Epsilon: 0.44, Rolling Avg: -152.43, Steps:  144 Terminated: True
# Episode:  82/2000, Reward: -116.58, Epsilon: 0.44, Rolling Avg: -150.31, Steps:  225 Terminated: True
# Episode:  83/2000, Reward:  +61.49, Epsilon: 0.43, Rolling Avg: -147.66, Steps:  188 Terminated: True
# Episode:  84/2000, Reward:  -35.17, Epsilon: 0.43, Rolling Avg: -139.84, Steps:  240 Terminated: True
# Episode:  85/2000, Reward:  -58.18, Epsilon: 0.43, Rolling Avg: -131.87, Steps:  251 Terminated: True
# Episode:  86/2000, Reward:  -41.76, Epsilon: 0.42, Rolling Avg: -123.80, Steps:  115 Terminated: True
# Episode:  87/2000, Reward:  -86.13, Epsilon: 0.42, Rolling Avg: -122.55, Steps:  454 Terminated: True
# Episode:  88/2000, Reward:  -39.51, Epsilon: 0.41, Rolling Avg: -118.64, Steps:  109 Terminated: True
# Episode:  89/2000, Reward: -140.15, Epsilon: 0.41, Rolling Avg: -119.42, Steps:  985 Terminated: True
# Episode:  90/2000, Reward:  -26.52, Epsilon: 0.40, Rolling Avg: -116.77, Steps:  352 Terminated: True
# Episode:  91/2000, Reward: -208.94, Epsilon: 0.40, Rolling Avg: -119.35, Steps:  206 Terminated: True
# Episode:  92/2000, Reward:  -45.14, Epsilon: 0.40, Rolling Avg: -113.30, Steps:  241 Terminated: True
# Episode:  93/2000, Reward:  -62.18, Epsilon: 0.39, Rolling Avg: -109.90, Steps:  131 Terminated: True
# Episode:  94/2000, Reward:  -65.63, Epsilon: 0.39, Rolling Avg: -108.46, Steps:  187 Terminated: True
# Episode:  95/2000, Reward:  -57.34, Epsilon: 0.38, Rolling Avg: -107.36, Steps:  160 Terminated: True
# Episode:  96/2000, Reward:  -33.48, Epsilon: 0.38, Rolling Avg: -104.78, Steps: 1199 Terminated: False
# Episode:  97/2000, Reward:  -58.79, Epsilon: 0.38, Rolling Avg:  -99.54, Steps:  195 Terminated: True
# Episode:  98/2000, Reward: -295.85, Epsilon: 0.37, Rolling Avg: -105.19, Steps:  263 Terminated: True
# Episode:  99/2000, Reward:  -46.02, Epsilon: 0.37, Rolling Avg: -102.63, Steps:  329 Terminated: True
# Episode: 100/2000, Reward: -227.09, Epsilon: 0.37, Rolling Avg: -106.88, Steps:  167 Terminated: True
# Episode: 101/2000, Reward: -220.40, Epsilon: 0.36, Rolling Avg: -108.24, Steps:  449 Terminated: True
# Episode: 102/2000, Reward: -146.68, Epsilon: 0.36, Rolling Avg: -107.38, Steps:  890 Terminated: True
# Episode: 103/2000, Reward: -250.31, Epsilon: 0.36, Rolling Avg: -110.30, Steps:  506 Terminated: True
# Episode: 104/2000, Reward: -291.26, Epsilon: 0.35, Rolling Avg: -116.92, Steps:  538 Terminated: True
# Episode: 105/2000, Reward: -174.36, Epsilon: 0.35, Rolling Avg: -118.86, Steps:  311 Terminated: True
# Episode: 106/2000, Reward:  +18.91, Epsilon: 0.34, Rolling Avg: -116.08, Steps:  205 Terminated: True
# Episode: 107/2000, Reward:  -54.63, Epsilon: 0.34, Rolling Avg: -113.95, Steps:  274 Terminated: True
# Episode: 108/2000, Reward: -120.73, Epsilon: 0.34, Rolling Avg: -111.84, Steps:  644 Terminated: True
# Episode: 109/2000, Reward: -332.80, Epsilon: 0.33, Rolling Avg: -117.61, Steps:  335 Terminated: True
# Episode: 110/2000, Reward:  -53.86, Epsilon: 0.33, Rolling Avg: -115.81, Steps:  206 Terminated: True
# Episode: 111/2000, Reward: -114.32, Epsilon: 0.33, Rolling Avg: -117.75, Steps:  646 Terminated: True
# Episode: 112/2000, Reward: -102.39, Epsilon: 0.32, Rolling Avg: -114.57, Steps:  183 Terminated: True
# Episode: 113/2000, Reward: -268.84, Epsilon: 0.32, Rolling Avg: -119.74, Steps:  351 Terminated: True
# Episode: 114/2000, Reward:   -4.99, Epsilon: 0.32, Rolling Avg: -117.13, Steps: 1199 Terminated: False
# Episode: 115/2000, Reward: -261.44, Epsilon: 0.31, Rolling Avg: -120.36, Steps:  255 Terminated: True
# Episode: 116/2000, Reward: -114.19, Epsilon: 0.31, Rolling Avg: -120.58, Steps: 1199 Terminated: False
# Episode: 117/2000, Reward: -281.18, Epsilon: 0.31, Rolling Avg: -123.31, Steps:  631 Terminated: True
# Episode: 118/2000, Reward: -137.09, Epsilon: 0.31, Rolling Avg: -125.16, Steps: 1199 Terminated: False
# Episode: 119/2000, Reward: -115.17, Epsilon: 0.30, Rolling Avg: -125.88, Steps: 1199 Terminated: False
# Episode: 120/2000, Reward: -135.96, Epsilon: 0.30, Rolling Avg: -121.49, Steps: 1127 Terminated: True
# Episode: 121/2000, Reward: -271.12, Epsilon: 0.30, Rolling Avg: -125.39, Steps:  330 Terminated: True
# Episode: 122/2000, Reward: -141.34, Epsilon: 0.29, Rolling Avg: -126.01, Steps: 1199 Terminated: False
# Episode: 123/2000, Reward:  -83.96, Epsilon: 0.29, Rolling Avg: -129.65, Steps: 1199 Terminated: False
# Episode: 124/2000, Reward: -116.31, Epsilon: 0.29, Rolling Avg: -131.68, Steps:  767 Terminated: True
# Episode: 125/2000, Reward:  -90.46, Epsilon: 0.28, Rolling Avg: -132.48, Steps: 1199 Terminated: False
# Episode: 126/2000, Reward:  -93.58, Epsilon: 0.28, Rolling Avg: -133.78, Steps: 1199 Terminated: False
# Episode: 127/2000, Reward:  -66.46, Epsilon: 0.28, Rolling Avg: -133.29, Steps: 1199 Terminated: False
# Episode: 128/2000, Reward:  -72.16, Epsilon: 0.28, Rolling Avg: -134.10, Steps: 1199 Terminated: False
# Episode: 129/2000, Reward:  -52.91, Epsilon: 0.27, Rolling Avg: -131.92, Steps: 1199 Terminated: False
# Episode: 130/2000, Reward: -113.74, Epsilon: 0.27, Rolling Avg: -134.10, Steps: 1199 Terminated: False
# Episode: 131/2000, Reward:  -67.40, Epsilon: 0.27, Rolling Avg: -130.57, Steps: 1199 Terminated: False
# Episode: 132/2000, Reward:  -65.56, Epsilon: 0.27, Rolling Avg: -131.08, Steps: 1199 Terminated: False
# Episode: 133/2000, Reward:  -97.98, Epsilon: 0.26, Rolling Avg: -131.97, Steps: 1199 Terminated: False
# Episode: 134/2000, Reward:  -69.30, Epsilon: 0.26, Rolling Avg: -132.06, Steps: 1199 Terminated: False
# Episode: 135/2000, Reward:   -3.67, Epsilon: 0.26, Rolling Avg: -130.72, Steps: 1199 Terminated: False
# Episode: 136/2000, Reward: -118.25, Epsilon: 0.25, Rolling Avg: -132.84, Steps: 1199 Terminated: False
# Episode: 137/2000, Reward: -112.90, Epsilon: 0.25, Rolling Avg: -134.19, Steps: 1199 Terminated: False
# Episode: 138/2000, Reward:  -77.87, Epsilon: 0.25, Rolling Avg: -128.74, Steps: 1199 Terminated: False
# Episode: 139/2000, Reward: -141.64, Epsilon: 0.25, Rolling Avg: -131.13, Steps: 1199 Terminated: False
# Episode: 140/2000, Reward:  -61.34, Epsilon: 0.24, Rolling Avg: -126.99, Steps: 1199 Terminated: False
# Episode: 141/2000, Reward:  -46.49, Epsilon: 0.24, Rolling Avg: -122.64, Steps: 1199 Terminated: False
# Episode: 142/2000, Reward:  -28.18, Epsilon: 0.24, Rolling Avg: -119.68, Steps: 1199 Terminated: False
# Episode: 143/2000, Reward:  -65.95, Epsilon: 0.24, Rolling Avg: -115.07, Steps: 1199 Terminated: False
# Episode: 144/2000, Reward:  -26.97, Epsilon: 0.24, Rolling Avg: -108.46, Steps: 1199 Terminated: False
# Episode: 145/2000, Reward:  -35.51, Epsilon: 0.23, Rolling Avg: -104.99, Steps: 1199 Terminated: False
# Episode: 146/2000, Reward:  -92.98, Epsilon: 0.23, Rolling Avg: -107.79, Steps: 1199 Terminated: False
# Episode: 147/2000, Reward:  -62.98, Epsilon: 0.23, Rolling Avg: -108.00, Steps: 1199 Terminated: False
# Episode: 148/2000, Reward:  -80.72, Epsilon: 0.23, Rolling Avg: -107.00, Steps: 1199 Terminated: False
# Episode: 149/2000, Reward:  -59.88, Epsilon: 0.22, Rolling Avg: -100.18, Steps: 1199 Terminated: False
# Episode: 150/2000, Reward: -135.72, Epsilon: 0.22, Rolling Avg: -102.22, Steps: 1199 Terminated: False
# Episode: 151/2000, Reward:  -86.45, Epsilon: 0.22, Rolling Avg: -101.53, Steps: 1199 Terminated: False
# Episode: 152/2000, Reward:  -87.91, Epsilon: 0.22, Rolling Avg: -101.16, Steps: 1199 Terminated: False
# Episode: 153/2000, Reward:  -55.98, Epsilon: 0.21, Rolling Avg:  -95.84, Steps: 1199 Terminated: False
# Episode: 154/2000, Reward:  -57.65, Epsilon: 0.21, Rolling Avg:  -97.16, Steps: 1199 Terminated: False
# Episode: 155/2000, Reward:  -73.34, Epsilon: 0.21, Rolling Avg:  -92.46, Steps:  353 Terminated: True
# Episode: 156/2000, Reward:  -56.66, Epsilon: 0.21, Rolling Avg:  -91.02, Steps: 1199 Terminated: False
# Episode: 157/2000, Reward:  -98.90, Epsilon: 0.21, Rolling Avg:  -86.46, Steps: 1199 Terminated: False
# Episode: 158/2000, Reward:  -71.88, Epsilon: 0.20, Rolling Avg:  -84.83, Steps: 1199 Terminated: False
# Episode: 159/2000, Reward:  -93.81, Epsilon: 0.20, Rolling Avg:  -84.30, Steps: 1199 Terminated: False
# Episode: 160/2000, Reward:  -60.05, Epsilon: 0.20, Rolling Avg:  -82.40, Steps: 1199 Terminated: False
# Episode: 161/2000, Reward:  -92.50, Epsilon: 0.20, Rolling Avg:  -77.93, Steps: 1199 Terminated: False
# Episode: 162/2000, Reward:  -66.64, Epsilon: 0.20, Rolling Avg:  -76.07, Steps: 1199 Terminated: False
# Episode: 163/2000, Reward:  -53.15, Epsilon: 0.19, Rolling Avg:  -75.30, Steps: 1199 Terminated: False
# Episode: 164/2000, Reward:  -99.90, Epsilon: 0.19, Rolling Avg:  -74.89, Steps: 1199 Terminated: False
# Episode: 165/2000, Reward:  -13.93, Epsilon: 0.19, Rolling Avg:  -72.97, Steps: 1199 Terminated: False
# Episode: 166/2000, Reward:  -86.98, Epsilon: 0.19, Rolling Avg:  -72.81, Steps: 1199 Terminated: False
# Episode: 167/2000, Reward:  -79.82, Epsilon: 0.19, Rolling Avg:  -73.14, Steps: 1199 Terminated: False
# Episode: 168/2000, Reward:  -89.56, Epsilon: 0.18, Rolling Avg:  -73.58, Steps: 1199 Terminated: False
# Episode: 169/2000, Reward:  -52.62, Epsilon: 0.18, Rolling Avg:  -73.57, Steps: 1199 Terminated: False
# Episode: 170/2000, Reward:  -36.80, Epsilon: 0.18, Rolling Avg:  -71.65, Steps: 1199 Terminated: False
# Episode: 171/2000, Reward:  -67.16, Epsilon: 0.18, Rolling Avg:  -71.64, Steps: 1199 Terminated: False
# Episode: 172/2000, Reward:  -31.62, Epsilon: 0.18, Rolling Avg:  -70.79, Steps: 1199 Terminated: False
# Episode: 173/2000, Reward:  -70.44, Epsilon: 0.18, Rolling Avg:  -70.10, Steps: 1199 Terminated: False
# Episode: 174/2000, Reward:  -63.96, Epsilon: 0.17, Rolling Avg:  -69.97, Steps: 1199 Terminated: False
# Episode: 175/2000, Reward:  -40.26, Epsilon: 0.17, Rolling Avg:  -70.88, Steps: 1199 Terminated: False
# Episode: 176/2000, Reward:  -84.98, Epsilon: 0.17, Rolling Avg:  -70.05, Steps: 1199 Terminated: False
# Episode: 177/2000, Reward:  -55.70, Epsilon: 0.17, Rolling Avg:  -68.62, Steps: 1199 Terminated: False
# Episode: 178/2000, Reward:  -70.75, Epsilon: 0.17, Rolling Avg:  -68.44, Steps: 1199 Terminated: False
# Episode: 179/2000, Reward:  -37.20, Epsilon: 0.17, Rolling Avg:  -65.83, Steps: 1199 Terminated: False
# Episode: 180/2000, Reward:  -81.82, Epsilon: 0.16, Rolling Avg:  -66.35, Steps: 1199 Terminated: False
# Episode: 181/2000, Reward:  -14.74, Epsilon: 0.16, Rolling Avg:  -65.55, Steps: 1199 Terminated: False
# Episode: 182/2000, Reward:  -82.98, Epsilon: 0.16, Rolling Avg:  -66.92, Steps: 1199 Terminated: False
# Episode: 183/2000, Reward:  -54.02, Epsilon: 0.16, Rolling Avg:  -66.62, Steps: 1199 Terminated: False
# Episode: 184/2000, Reward:  -58.44, Epsilon: 0.16, Rolling Avg:  -67.41, Steps: 1199 Terminated: False
# Episode: 185/2000, Reward:  -94.07, Epsilon: 0.16, Rolling Avg:  -68.87, Steps: 1199 Terminated: False
# Episode: 186/2000, Reward:  -41.85, Epsilon: 0.15, Rolling Avg:  -67.60, Steps: 1199 Terminated: False
# Episode: 187/2000, Reward:  -54.78, Epsilon: 0.15, Rolling Avg:  -67.39, Steps: 1199 Terminated: False
# Episode: 188/2000, Reward:  -56.27, Epsilon: 0.15, Rolling Avg:  -66.78, Steps: 1199 Terminated: False
# Episode: 189/2000, Reward:  -47.44, Epsilon: 0.15, Rolling Avg:  -66.47, Steps: 1199 Terminated: False
# Episode: 190/2000, Reward: -430.45, Epsilon: 0.15, Rolling Avg:  -73.84, Steps:  168 Terminated: True
# Episode: 191/2000, Reward:   +0.75, Epsilon: 0.15, Rolling Avg:  -71.66, Steps:  137 Terminated: True
# Episode: 192/2000, Reward:  -32.83, Epsilon: 0.15, Rolling Avg:  -70.28, Steps: 1199 Terminated: False
# Episode: 193/2000, Reward:  -29.12, Epsilon: 0.14, Rolling Avg:  -69.61, Steps: 1199 Terminated: False
# Episode: 194/2000, Reward: +106.36, Epsilon: 0.14, Rolling Avg:  -65.51, Steps:  893 Terminated: True
# Episode: 195/2000, Reward:  -47.74, Epsilon: 0.14, Rolling Avg:  -64.87, Steps: 1199 Terminated: False
# Episode: 196/2000, Reward: +238.26, Epsilon: 0.14, Rolling Avg:  -57.50, Steps:  407 Terminated: True
# Episode: 197/2000, Reward:  -53.16, Epsilon: 0.14, Rolling Avg:  -56.35, Steps: 1199 Terminated: False
# Episode: 198/2000, Reward:  -37.27, Epsilon: 0.14, Rolling Avg:  -55.49, Steps: 1199 Terminated: False
# Episode: 199/2000, Reward:  -95.95, Epsilon: 0.14, Rolling Avg:  -55.54, Steps: 1199 Terminated: False
# Episode: 200/2000, Reward: -195.99, Epsilon: 0.13, Rolling Avg:  -58.94, Steps:  244 Terminated: True
# Episode: 201/2000, Reward:  -85.58, Epsilon: 0.13, Rolling Avg:  -58.77, Steps: 1199 Terminated: False
# Episode: 202/2000, Reward:   +7.51, Epsilon: 0.13, Rolling Avg:  -56.91, Steps:  141 Terminated: True
# Episode: 203/2000, Reward:  +58.70, Epsilon: 0.13, Rolling Avg:  -54.12, Steps: 1199 Terminated: False
# Episode: 204/2000, Reward:  -56.44, Epsilon: 0.13, Rolling Avg:  -53.03, Steps: 1199 Terminated: False
# Episode: 205/2000, Reward:  -33.78, Epsilon: 0.13, Rolling Avg:  -53.53, Steps: 1199 Terminated: False
# Episode: 206/2000, Reward: +222.10, Epsilon: 0.13, Rolling Avg:  -45.80, Steps:  411 Terminated: True
# Episode: 207/2000, Reward:  -76.97, Epsilon: 0.12, Rolling Avg:  -45.73, Steps: 1199 Terminated: False
# Episode: 208/2000, Reward:  -38.68, Epsilon: 0.12, Rolling Avg:  -44.46, Steps: 1199 Terminated: False
# Episode: 209/2000, Reward:  -78.59, Epsilon: 0.12, Rolling Avg:  -45.10, Steps: 1199 Terminated: False
# Episode: 210/2000, Reward:  -33.17, Epsilon: 0.12, Rolling Avg:  -45.01, Steps: 1199 Terminated: False
# Episode: 211/2000, Reward:  -79.61, Epsilon: 0.12, Rolling Avg:  -45.32, Steps: 1199 Terminated: False
# Episode: 212/2000, Reward:  -66.13, Epsilon: 0.12, Rolling Avg:  -46.19, Steps: 1199 Terminated: False
# Episode: 213/2000, Reward:  -53.24, Epsilon: 0.12, Rolling Avg:  -45.76, Steps: 1199 Terminated: False
# Episode: 214/2000, Reward:  -44.28, Epsilon: 0.12, Rolling Avg:  -45.27, Steps: 1199 Terminated: False
# Episode: 215/2000, Reward: +156.08, Epsilon: 0.12, Rolling Avg:  -40.36, Steps:  827 Terminated: True
# Episode: 216/2000, Reward:  -37.76, Epsilon: 0.11, Rolling Avg:  -39.18, Steps:  203 Terminated: True
# Episode: 217/2000, Reward:  -53.86, Epsilon: 0.11, Rolling Avg:  -39.13, Steps: 1199 Terminated: False
# Episode: 218/2000, Reward: +175.39, Epsilon: 0.11, Rolling Avg:  -32.98, Steps:  366 Terminated: True
# Episode: 219/2000, Reward: +193.66, Epsilon: 0.11, Rolling Avg:  -27.21, Steps:  891 Terminated: True
# Episode: 220/2000, Reward:  -46.77, Epsilon: 0.11, Rolling Avg:  -26.33, Steps: 1199 Terminated: False
# Episode: 221/2000, Reward: +234.66, Epsilon: 0.11, Rolling Avg:  -20.09, Steps:  657 Terminated: True
# Episode: 222/2000, Reward:  -15.77, Epsilon: 0.11, Rolling Avg:  -18.41, Steps: 1199 Terminated: False
# Episode: 223/2000, Reward: +224.66, Epsilon: 0.11, Rolling Avg:  -11.45, Steps:  422 Terminated: True
# Episode: 224/2000, Reward: +213.53, Epsilon: 0.11, Rolling Avg:   -4.65, Steps:  626 Terminated: True
# Episode: 225/2000, Reward: +219.11, Epsilon: 0.10, Rolling Avg:    3.18, Steps:  336 Terminated: True
# Episode: 226/2000, Reward: +274.03, Epsilon: 0.10, Rolling Avg:   11.08, Steps:  348 Terminated: True
# Episode: 227/2000, Reward:  -83.66, Epsilon: 0.10, Rolling Avg:   10.36, Steps: 1199 Terminated: False
# Episode: 228/2000, Reward:  -65.80, Epsilon: 0.10, Rolling Avg:   10.12, Steps: 1199 Terminated: False
# Episode: 229/2000, Reward:  -53.13, Epsilon: 0.10, Rolling Avg:    9.98, Steps: 1199 Terminated: False
# Episode: 230/2000, Reward: +248.72, Epsilon: 0.10, Rolling Avg:   26.96, Steps:  504 Terminated: True
# Episode: 231/2000, Reward:  -19.23, Epsilon: 0.10, Rolling Avg:   26.46, Steps: 1199 Terminated: False
# Episode: 232/2000, Reward: +108.26, Epsilon: 0.10, Rolling Avg:   29.98, Steps:  511 Terminated: True
# Episode: 233/2000, Reward: +262.19, Epsilon: 0.10, Rolling Avg:   37.27, Steps:  446 Terminated: True
# Episode: 234/2000, Reward:  -90.91, Epsilon: 0.10, Rolling Avg:   32.33, Steps:  345 Terminated: True
# Episode: 235/2000, Reward: +250.52, Epsilon: 0.09, Rolling Avg:   39.79, Steps:  531 Terminated: True
# Episode: 236/2000, Reward: +183.83, Epsilon: 0.09, Rolling Avg:   38.43, Steps:  608 Terminated: True
# Episode: 237/2000, Reward:  -90.10, Epsilon: 0.09, Rolling Avg:   37.51, Steps: 1199 Terminated: False
# Episode: 238/2000, Reward: +254.06, Epsilon: 0.09, Rolling Avg:   44.79, Steps:  444 Terminated: True
# Episode: 239/2000, Reward:  -49.26, Epsilon: 0.09, Rolling Avg:   45.96, Steps: 1199 Terminated: False
# Episode: 240/2000, Reward: +222.89, Epsilon: 0.09, Rolling Avg:   56.43, Steps:  556 Terminated: True
# Episode: 241/2000, Reward: +220.12, Epsilon: 0.09, Rolling Avg:   64.07, Steps:  411 Terminated: True
# Episode: 242/2000, Reward:  -51.03, Epsilon: 0.09, Rolling Avg:   62.61, Steps: 1199 Terminated: False
# Episode: 243/2000, Reward: +170.33, Epsilon: 0.09, Rolling Avg:   65.40, Steps:  596 Terminated: True
# Episode: 244/2000, Reward: +194.24, Epsilon: 0.09, Rolling Avg:   71.67, Steps:  434 Terminated: True
# Episode: 245/2000, Reward: +196.28, Epsilon: 0.09, Rolling Avg:   77.42, Steps:  440 Terminated: True
# Episode: 246/2000, Reward: +214.98, Epsilon: 0.08, Rolling Avg:   77.24, Steps:  283 Terminated: True
# Episode: 247/2000, Reward: +260.68, Epsilon: 0.08, Rolling Avg:   85.68, Steps:  547 Terminated: True
# Episode: 248/2000, Reward: +120.24, Epsilon: 0.08, Rolling Avg:   89.65, Steps: 1010 Terminated: True
# Episode: 249/2000, Reward: +248.82, Epsilon: 0.08, Rolling Avg:   97.84, Steps:  458 Terminated: True
# Episode: 250/2000, Reward: +219.42, Epsilon: 0.08, Rolling Avg:  104.15, Steps:  373 Terminated: True
# Episode: 251/2000, Reward: +260.72, Epsilon: 0.08, Rolling Avg:  112.66, Steps:  317 Terminated: True
# Episode: 252/2000, Reward: +217.03, Epsilon: 0.08, Rolling Avg:  119.74, Steps:  286 Terminated: True
# Episode: 253/2000, Reward: +263.13, Epsilon: 0.08, Rolling Avg:  127.65, Steps:  374 Terminated: True
# Episode: 254/2000, Reward: +248.81, Epsilon: 0.08, Rolling Avg:  134.98, Steps:  323 Terminated: True
# Episode: 255/2000, Reward:  -96.26, Epsilon: 0.08, Rolling Avg:  128.67, Steps: 1199 Terminated: False
# Episode: 256/2000, Reward:  +81.13, Epsilon: 0.08, Rolling Avg:  131.64, Steps: 1118 Terminated: True
# Episode: 257/2000, Reward: +250.55, Epsilon: 0.08, Rolling Avg:  139.25, Steps:  567 Terminated: True
# Episode: 258/2000, Reward: +227.85, Epsilon: 0.07, Rolling Avg:  140.56, Steps:  410 Terminated: True
# Episode: 259/2000, Reward:  -66.17, Epsilon: 0.07, Rolling Avg:  134.07, Steps: 1199 Terminated: False
# Episode: 260/2000, Reward:  -10.87, Epsilon: 0.07, Rolling Avg:  134.96, Steps:  269 Terminated: True
# Episode: 261/2000, Reward: -103.52, Epsilon: 0.07, Rolling Avg:  126.51, Steps:  825 Terminated: True
# Episode: 262/2000, Reward:  +23.10, Epsilon: 0.07, Rolling Avg:  127.48, Steps:  231 Terminated: True
# Episode: 263/2000, Reward:  +32.08, Epsilon: 0.07, Rolling Avg:  122.67, Steps:  295 Terminated: True
# Episode: 264/2000, Reward: +240.19, Epsilon: 0.07, Rolling Avg:  123.33, Steps:  340 Terminated: True
# Episode: 265/2000, Reward:  -30.48, Epsilon: 0.07, Rolling Avg:  117.09, Steps: 1199 Terminated: False
# Episode: 266/2000, Reward:   +1.32, Epsilon: 0.07, Rolling Avg:  110.28, Steps:  208 Terminated: True
# Episode: 267/2000, Reward: +170.09, Epsilon: 0.07, Rolling Avg:  116.62, Steps:  740 Terminated: True
# Episode: 268/2000, Reward:  +42.35, Epsilon: 0.07, Rolling Avg:  119.32, Steps:  234 Terminated: True
# Episode: 269/2000, Reward:  +43.60, Epsilon: 0.07, Rolling Avg:  121.74, Steps:  244 Terminated: True
# Episode: 270/2000, Reward: +212.68, Epsilon: 0.07, Rolling Avg:  120.84, Steps:  495 Terminated: True
# Episode: 271/2000, Reward: +264.10, Epsilon: 0.07, Rolling Avg:  127.92, Steps:  379 Terminated: True
# Episode: 272/2000, Reward:  -25.23, Epsilon: 0.06, Rolling Avg:  124.59, Steps: 1199 Terminated: False
# Episode: 273/2000, Reward:  -43.00, Epsilon: 0.06, Rolling Avg:  116.96, Steps:  200 Terminated: True
# Episode: 274/2000, Reward: +218.60, Epsilon: 0.06, Rolling Avg:  124.69, Steps:  556 Terminated: True
# Episode: 275/2000, Reward:   +3.68, Epsilon: 0.06, Rolling Avg:  118.52, Steps:  302 Terminated: True
# Episode: 276/2000, Reward:  +45.21, Epsilon: 0.06, Rolling Avg:  115.06, Steps:  243 Terminated: True
# Episode: 277/2000, Reward:   -0.97, Epsilon: 0.06, Rolling Avg:  117.29, Steps:  454 Terminated: True
# Episode: 278/2000, Reward:  +23.99, Epsilon: 0.06, Rolling Avg:  111.53, Steps:  134 Terminated: True
# Episode: 279/2000, Reward:  +16.73, Epsilon: 0.06, Rolling Avg:  113.18, Steps:  236 Terminated: True
# Episode: 280/2000, Reward:  +30.31, Epsilon: 0.06, Rolling Avg:  108.37, Steps:  232 Terminated: True
# Episode: 281/2000, Reward: +160.76, Epsilon: 0.06, Rolling Avg:  106.89, Steps:  573 Terminated: True
# Episode: 282/2000, Reward: +234.16, Epsilon: 0.06, Rolling Avg:  114.02, Steps:  483 Terminated: True
# Episode: 283/2000, Reward:   +8.27, Epsilon: 0.06, Rolling Avg:  109.96, Steps:  258 Terminated: True
# Episode: 284/2000, Reward:  +56.20, Epsilon: 0.06, Rolling Avg:  106.51, Steps:  327 Terminated: True
# Episode: 285/2000, Reward:  -17.07, Epsilon: 0.06, Rolling Avg:  101.18, Steps:  215 Terminated: True
# Episode: 286/2000, Reward: +185.70, Epsilon: 0.06, Rolling Avg:  100.45, Steps:  551 Terminated: True
# Episode: 287/2000, Reward: +250.54, Epsilon: 0.06, Rolling Avg:  100.19, Steps:  451 Terminated: True
# Episode: 288/2000, Reward: +200.53, Epsilon: 0.06, Rolling Avg:  102.20, Steps:  493 Terminated: True
# Episode: 289/2000, Reward:  +16.08, Epsilon: 0.05, Rolling Avg:   96.38, Steps:  277 Terminated: True
# Episode: 290/2000, Reward: +243.86, Epsilon: 0.05, Rolling Avg:   96.99, Steps:  544 Terminated: True
# Episode: 291/2000, Reward:  -19.57, Epsilon: 0.05, Rolling Avg:   89.99, Steps:  212 Terminated: True
# Episode: 292/2000, Reward:  +35.32, Epsilon: 0.05, Rolling Avg:   85.44, Steps:  252 Terminated: True
# Episode: 293/2000, Reward: +247.52, Epsilon: 0.05, Rolling Avg:   85.05, Steps:  310 Terminated: True
# Episode: 294/2000, Reward: +250.06, Epsilon: 0.05, Rolling Avg:   85.08, Steps:  429 Terminated: True
# Episode: 295/2000, Reward: +246.72, Epsilon: 0.05, Rolling Avg:   93.66, Steps:  389 Terminated: True
# Episode: 296/2000, Reward:  +41.60, Epsilon: 0.05, Rolling Avg:   92.67, Steps:  209 Terminated: True
# Episode: 297/2000, Reward: +238.00, Epsilon: 0.05, Rolling Avg:   92.36, Steps:  427 Terminated: True
# Episode: 298/2000, Reward:   -6.93, Epsilon: 0.05, Rolling Avg:   86.49, Steps:  302 Terminated: True
# Episode: 299/2000, Reward: +266.31, Epsilon: 0.05, Rolling Avg:   94.80, Steps:  281 Terminated: True
# Episode: 300/2000, Reward: +210.02, Epsilon: 0.05, Rolling Avg:  100.32, Steps:  456 Terminated: True
# Episode: 301/2000, Reward: +253.09, Epsilon: 0.05, Rolling Avg:  109.24, Steps:  594 Terminated: True
# Episode: 302/2000, Reward: +171.17, Epsilon: 0.05, Rolling Avg:  112.94, Steps:  919 Terminated: True
# Episode: 303/2000, Reward: +189.70, Epsilon: 0.05, Rolling Avg:  116.88, Steps:  707 Terminated: True
# Episode: 304/2000, Reward: +260.69, Epsilon: 0.05, Rolling Avg:  117.39, Steps:  287 Terminated: True
# Episode: 305/2000, Reward: +277.16, Epsilon: 0.05, Rolling Avg:  125.08, Steps:  276 Terminated: True
# Episode: 306/2000, Reward: +249.56, Epsilon: 0.05, Rolling Avg:  131.29, Steps:  232 Terminated: True
# Episode: 307/2000, Reward: +246.71, Epsilon: 0.05, Rolling Avg:  133.20, Steps:  263 Terminated: True
# Episode: 308/2000, Reward: +269.58, Epsilon: 0.05, Rolling Avg:  138.89, Steps:  292 Terminated: True
# Episode: 309/2000, Reward: +249.06, Epsilon: 0.04, Rolling Avg:  144.02, Steps:  288 Terminated: True
# Episode: 310/2000, Reward: +254.04, Epsilon: 0.04, Rolling Avg:  145.06, Steps:  391 Terminated: True
# Episode: 311/2000, Reward: +249.43, Epsilon: 0.04, Rolling Avg:  144.69, Steps:  330 Terminated: True
# Episode: 312/2000, Reward:  -18.87, Epsilon: 0.04, Rolling Avg:  144.85, Steps:  247 Terminated: True
# Episode: 313/2000, Reward: +129.09, Epsilon: 0.04, Rolling Avg:  149.15, Steps:  957 Terminated: True
# Episode: 314/2000, Reward: +277.16, Epsilon: 0.04, Rolling Avg:  150.61, Steps:  285 Terminated: True
# Episode: 315/2000, Reward: +197.15, Epsilon: 0.04, Rolling Avg:  155.45, Steps:  411 Terminated: True
# Episode: 316/2000, Reward: +265.76, Epsilon: 0.04, Rolling Avg:  160.96, Steps:  282 Terminated: True
# Episode: 317/2000, Reward: +259.54, Epsilon: 0.04, Rolling Avg:  167.48, Steps:  250 Terminated: True
# Episode: 318/2000, Reward: +238.23, Epsilon: 0.04, Rolling Avg:  172.83, Steps:  408 Terminated: True
# Episode: 319/2000, Reward: +218.88, Epsilon: 0.04, Rolling Avg:  177.89, Steps:  282 Terminated: True
# Episode: 320/2000, Reward: +270.98, Epsilon: 0.04, Rolling Avg:  183.90, Steps:  314 Terminated: True
# Episode: 321/2000, Reward: +224.16, Epsilon: 0.04, Rolling Avg:  185.49, Steps:  632 Terminated: True
# Episode: 322/2000, Reward: +300.99, Epsilon: 0.04, Rolling Avg:  187.16, Steps:  210 Terminated: True
# Episode: 323/2000, Reward: +245.67, Epsilon: 0.04, Rolling Avg:  193.10, Steps:  280 Terminated: True
# Episode: 324/2000, Reward: +208.54, Epsilon: 0.04, Rolling Avg:  196.90, Steps:  349 Terminated: True
# Episode: 325/2000, Reward: +244.79, Epsilon: 0.04, Rolling Avg:  203.45, Steps:  338 Terminated: True
# Environment solved in 325 episodes!
# Training completed in 14.24 minutes

# %% [markdown]
# #### **Learning Plot and Episode Rewards**

# %%
# Plot rewards with rolling average

plt.figure(figsize=(10, 6))
plt.plot(rewards_per_episode, label='Rewards', color='blue')
plt.plot(rolling_avg_rewards, label='Rolling Avg (Last '+str(ROLLING_WINDOW) +' Episodes)', color='orange')
plt.axhline(y=solved_threshold, color='red', linestyle='--', label='Solved Threshold')
plt.title('DDQN Training Performance LUNARLANDER')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### **Simulation - Testing 10 episodes with the DDQN Network**

# %%
# Testing for 10 episodes
start_time = time.time()

for e_test in range(10):  # Run 10 test episodes
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    steps = 0
    while True:
        # Use the trained model for testing
        action = agent.action(state)  # Estimate action values


        next_state, reward, done, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward
        state = next_state
        steps = steps + 1
        if done or truncated:
            print(f"Test Episode: {e_test + 1:2}/10, Reward: {total_reward:.2f}, Steps: {steps:3}")
            break

end_time = time.time()
testing_duration = (end_time - start_time) / 60  # Convert to minutes
print(f"Testing completed in {testing_duration:.2f} minutes")
# Out:
# Test Episode:  1/10, Reward: 249.24, Steps: 335
# Test Episode:  2/10, Reward: 267.63, Steps: 402
# Test Episode:  3/10, Reward: 285.09, Steps: 257
# Test Episode:  4/10, Reward: 90.42, Steps: 871
# Test Episode:  5/10, Reward: 285.61, Steps: 263
# Test Episode:  6/10, Reward: 200.90, Steps: 514
# Test Episode:  7/10, Reward: 279.08, Steps: 237
# Test Episode:  8/10, Reward: 218.23, Steps: 515
# Test Episode:  9/10, Reward: 258.66, Steps: 538
# Test Episode: 10/10, Reward: 276.02, Steps: 229
# Testing completed in 0.01 minutes

# %% [markdown]
# #### **Rendering 1 episode**

# %%
# Test the trained agent with video rendering
# This code is useful if you are using colab otherwise use render_mode='human'
env = gym.make(('LunarLander-v3'), render_mode='rgb_array')  # Enable RGB rendering
frames = []  # Store frames for visualization

# Render a single test episode
state, _ = env.reset()
state = np.reshape(state, [1, state_size])
tot_rewards = 0

while True:
    # Use the trained model for action
    action = agent.action(state)            # Estimate action value

    next_state, reward, done, truncated, _ = env.step(action)
    frames.append(env.render())                  # Save frame for rendering later
    next_state = np.reshape(next_state, [1, state_size])
    tot_rewards += reward
    state = next_state

    if done or truncated:
        print(f"Rendered Test Episode Reward: {tot_rewards:.2f}")
        break

env.close()

# Save the rendered episode as a GIF
def save_frames_as_gif(frames, path='./', filename='LUNARLANDER_Agent_DDQN.gif'):
    images = [Image.fromarray(frame) for frame in frames]
    gif_path = os.path.join(path, filename)
    images[0].save(gif_path, save_all=True, append_images=images[1:], duration=50, loop=0)
    print(f"Saved GIF to: {gif_path}")

save_frames_as_gif(frames, filename='LUNARLANDER_Agent_DDQN.gif')
# Out:
# Rendered Test Episode Reward: 244.45
# Saved GIF to: ./LUNARLANDER_Agent_DDQN.gif

# %%
import session_info
session_info.show(html=False)
# Out:
# -----
# PIL                 10.4.0
# gymnasium           1.2.3
# matplotlib          3.10.7
# numpy               2.2.6
# session_info        v1.0.1
# torch               2.9.0+cu128
# -----
# IPython             8.37.0
# jupyter_client      8.6.3
# jupyter_core        5.8.1
# jupyterlab          4.4.5
# notebook            7.4.4
# -----
# Python 3.10.12 (main, Mar  3 2026, 11:56:32) [GCC 11.4.0]
# Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.35
# -----
# Session information updated at 2026-05-15 19:59

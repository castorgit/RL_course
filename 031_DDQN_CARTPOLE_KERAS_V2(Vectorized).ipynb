# %% [markdown]
# #### **CARTPOLE DDQN V2 (soft update Polyak + some improvements)**
#
# This is a naive version vectorized of the DDQN Algorithm for the CARTPOLE env <br>
# Vectorizing we obtain a version that is faster and it is 'functional' as it works <br>
# Leave training for 300 episodes
#
# The Double DQN (DDQN) uses two networks one as a target and one as the trained network <br>
#
# The target network is a copy of the online network that is updated less frequently, <br>
# and is used to generate the target values for the Q-learning update
#
# It includes a soft update of the weights, instead of substituting the weights between the networks it blends them together using a Polyak averaging This was an improvement on the pure DDQN algorithm

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import gymnasium as gym
import numpy as np
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from collections import deque
import random

# %%
# Parameters
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
episodes = 300
batch_size = 64
gamma = 0.99  # Discount factor
epsilon = 1.0  # Initial exploration rate
epsilon_min = 0.01
epsilon_decay = 0.995
learning_rate = 0.001
memory = deque(maxlen=10000)  # Replay buffer size
train_every = 4  # Train the model every 4 steps

# %%
# Support Functions

# Build the neural network model

def build_model(state_size,action_size):
    model = Sequential()
    model.add(Dense(24, input_dim=state_size, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(action_size, activation='linear'))
    model.compile(loss='mse',
                      optimizer=Adam(learning_rate=learning_rate))
    model.summary()
    return model



# Soft update function for target network
def soft_update(model, target_model, tau=0.1):
    target_weights = target_model.get_weights()
    model_weights = model.get_weights()
    new_weights = [
        tau * mw + (1 - tau) * tw for mw, tw in zip(model_weights, target_weights)
    ]
    target_model.set_weights(new_weights)

# %% [markdown]
# #### **Replay Function - DDQN This is the core of the DDQN Algorithm**

# %%
def replay(model, target_model, memory, batch_size, gamma):
    """
    Perform a replay step in Double Deep Q-Network (DDQN).

    Args:
        model (keras.Model): Main (online) model.
        target_model (keras.Model): Target model for stable Q-value estimation.
        memory (deque): Replay memory storing (state, action, reward, next_state, done) tuples.
        batch_size (int): Number of experiences to sample from memory.
        gamma (float): Discount factor for future rewards.
    """
    # Ensure there are enough samples in memory
    if len(memory) < batch_size:
        return

    # Sample a minibatch of experiences
    minibatch = random.sample(memory, batch_size)

    # Prepare batches
    states, next_states, actions, rewards, dones = [], [], [], [], []
    for state, action, reward, next_state, done in minibatch:
        states.append(state)
        next_states.append(next_state)
        actions.append(action)
        rewards.append(reward)
        dones.append(done)

    # Convert lists to numpy arrays for batch processing
    states = np.array(states)
    next_states = np.array(next_states)
    actions = np.array(actions)
    rewards = np.array(rewards)
    dones = np.array(dones)

    # Predict Q-values for current and next states
    q_values = model.predict(states, verbose=0)
    next_q_values_main = model.predict(next_states, verbose=0)  # Main model
    next_q_values_target = target_model.predict(next_states, verbose=0)  # Target model

    # Update Q-values for the sampled experiences
    for i in range(batch_size):
        if dones[i]:  # Terminal state
            q_values[i][actions[i]] = rewards[i]
        else:
            # Main model selects the best action for the next state
            best_next_action = np.argmax(next_q_values_main[i])
            # Target model evaluates the Q-value of that action
            q_values[i][actions[i]] = rewards[i] + gamma * next_q_values_target[i][best_next_action]

    # Train the main model with the updated Q-values
    model.fit(states, q_values, epochs=1, verbose=0)

# %%
# Main training loop

env = gym.make("CartPole-v1")

model = build_model()
target_model = build_model()
target_model.set_weights(model.get_weights())

for episode in range(episodes):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    done = False
    step = 0

    while not done:
        # Epsilon-greedy action selection
        if np.random.rand() <= epsilon:
            action = env.action_space.sample()
        else:
            q_values = model.predict(state, verbose=0)
            action = np.argmax(q_values[0])

        # Take action
        next_state, reward, done, _, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward

        # Store experience in memory
        memory.append((state, action, reward, next_state, done))
        state = next_state

        # Train the model every `train_every` steps
        if step % train_every == 0:
            replay(model, target_model, memory, batch_size, gamma)

        step += 1

        if done:
            print(f"Episode: {episode + 1}/{episodes}, Score: {total_reward}, Epsilon: {epsilon:.2f}")
            break

    # Decay epsilon
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

    # Update target network using soft updates
    soft_update(model, target_model)

# Close the environment
env.close()
# Out:
# 2024-11-26 09:07:01.287580: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-26 09:07:01.297151: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 09:07:01.308917: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 09:07:01.312403: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 09:07:01.320813: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 09:07:01.867207: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732608422.359527  797107 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-26 09:07:02.381811: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Episode: 1/500, Score: 20.0, Epsilon: 1.00
# Episode: 2/500, Score: 16.0, Epsilon: 0.99
# Episode: 3/500, Score: 42.0, Epsilon: 0.99
# Episode: 4/500, Score: 11.0, Epsilon: 0.99
# Episode: 5/500, Score: 17.0, Epsilon: 0.98
# Episode: 6/500, Score: 11.0, Epsilon: 0.98
# Episode: 7/500, Score: 14.0, Epsilon: 0.97
# Episode: 8/500, Score: 47.0, Epsilon: 0.97
# Episode: 9/500, Score: 20.0, Epsilon: 0.96
# Episode: 10/500, Score: 11.0, Epsilon: 0.96
# Episode: 11/500, Score: 51.0, Epsilon: 0.95
# Episode: 12/500, Score: 15.0, Epsilon: 0.95
# Episode: 13/500, Score: 17.0, Epsilon: 0.94
# Episode: 14/500, Score: 9.0, Epsilon: 0.94
# Episode: 15/500, Score: 16.0, Epsilon: 0.93
# Episode: 16/500, Score: 12.0, Epsilon: 0.93
# Episode: 17/500, Score: 13.0, Epsilon: 0.92
# Episode: 18/500, Score: 24.0, Epsilon: 0.92
# Episode: 19/500, Score: 19.0, Epsilon: 0.91
# Episode: 20/500, Score: 27.0, Epsilon: 0.91
# Episode: 21/500, Score: 21.0, Epsilon: 0.90
# Episode: 22/500, Score: 14.0, Epsilon: 0.90
# Episode: 23/500, Score: 11.0, Epsilon: 0.90
# Episode: 24/500, Score: 17.0, Epsilon: 0.89
# Episode: 25/500, Score: 21.0, Epsilon: 0.89
# Episode: 26/500, Score: 44.0, Epsilon: 0.88
# Episode: 27/500, Score: 14.0, Epsilon: 0.88
# Episode: 28/500, Score: 19.0, Epsilon: 0.87
# Episode: 29/500, Score: 20.0, Epsilon: 0.87
# Episode: 30/500, Score: 16.0, Epsilon: 0.86
# Episode: 31/500, Score: 14.0, Epsilon: 0.86
# Episode: 32/500, Score: 19.0, Epsilon: 0.86
# Episode: 33/500, Score: 15.0, Epsilon: 0.85
# Episode: 34/500, Score: 13.0, Epsilon: 0.85
# Episode: 35/500, Score: 23.0, Epsilon: 0.84
# Episode: 36/500, Score: 17.0, Epsilon: 0.84
# Episode: 37/500, Score: 11.0, Epsilon: 0.83
# Episode: 38/500, Score: 19.0, Epsilon: 0.83
# Episode: 39/500, Score: 8.0, Epsilon: 0.83
# Episode: 40/500, Score: 11.0, Epsilon: 0.82
# Episode: 41/500, Score: 22.0, Epsilon: 0.82
# Episode: 42/500, Score: 11.0, Epsilon: 0.81
# Episode: 43/500, Score: 14.0, Epsilon: 0.81
# Episode: 44/500, Score: 22.0, Epsilon: 0.81
# Episode: 45/500, Score: 11.0, Epsilon: 0.80
# Episode: 46/500, Score: 14.0, Epsilon: 0.80
# Episode: 47/500, Score: 25.0, Epsilon: 0.79
# Episode: 48/500, Score: 15.0, Epsilon: 0.79
# Episode: 49/500, Score: 21.0, Epsilon: 0.79
# Episode: 50/500, Score: 22.0, Epsilon: 0.78
# Episode: 51/500, Score: 29.0, Epsilon: 0.78
# Episode: 52/500, Score: 13.0, Epsilon: 0.77
# Episode: 53/500, Score: 14.0, Epsilon: 0.77
# Episode: 54/500, Score: 16.0, Epsilon: 0.77
# Episode: 55/500, Score: 13.0, Epsilon: 0.76
# Episode: 56/500, Score: 20.0, Epsilon: 0.76
# Episode: 57/500, Score: 23.0, Epsilon: 0.76
# Episode: 58/500, Score: 20.0, Epsilon: 0.75
# Episode: 59/500, Score: 50.0, Epsilon: 0.75
# Episode: 60/500, Score: 27.0, Epsilon: 0.74
# Episode: 61/500, Score: 24.0, Epsilon: 0.74
# Episode: 62/500, Score: 10.0, Epsilon: 0.74
# Episode: 63/500, Score: 26.0, Epsilon: 0.73
# Episode: 64/500, Score: 15.0, Epsilon: 0.73
# Episode: 65/500, Score: 11.0, Epsilon: 0.73
# Episode: 66/500, Score: 14.0, Epsilon: 0.72
# Episode: 67/500, Score: 22.0, Epsilon: 0.72
# Episode: 68/500, Score: 17.0, Epsilon: 0.71
# Episode: 69/500, Score: 11.0, Epsilon: 0.71
# Episode: 70/500, Score: 16.0, Epsilon: 0.71
# Episode: 71/500, Score: 63.0, Epsilon: 0.70
# Episode: 72/500, Score: 93.0, Epsilon: 0.70
# Episode: 73/500, Score: 22.0, Epsilon: 0.70
# Episode: 74/500, Score: 19.0, Epsilon: 0.69
# Episode: 75/500, Score: 27.0, Epsilon: 0.69
# Episode: 76/500, Score: 67.0, Epsilon: 0.69
# Episode: 77/500, Score: 33.0, Epsilon: 0.68
# Episode: 78/500, Score: 53.0, Epsilon: 0.68
# Episode: 79/500, Score: 31.0, Epsilon: 0.68
# Episode: 80/500, Score: 11.0, Epsilon: 0.67
# Episode: 81/500, Score: 43.0, Epsilon: 0.67
# Episode: 82/500, Score: 17.0, Epsilon: 0.67
# Episode: 83/500, Score: 17.0, Epsilon: 0.66
# Episode: 84/500, Score: 45.0, Epsilon: 0.66
# Episode: 85/500, Score: 52.0, Epsilon: 0.66
# Episode: 86/500, Score: 42.0, Epsilon: 0.65
# Episode: 87/500, Score: 26.0, Epsilon: 0.65
# Episode: 88/500, Score: 17.0, Epsilon: 0.65
# Episode: 89/500, Score: 72.0, Epsilon: 0.64
# Episode: 90/500, Score: 29.0, Epsilon: 0.64
# Episode: 91/500, Score: 33.0, Epsilon: 0.64
# Episode: 92/500, Score: 53.0, Epsilon: 0.63
# Episode: 93/500, Score: 28.0, Epsilon: 0.63
# Episode: 94/500, Score: 39.0, Epsilon: 0.63
# Episode: 95/500, Score: 19.0, Epsilon: 0.62
# Episode: 96/500, Score: 19.0, Epsilon: 0.62
# Episode: 97/500, Score: 114.0, Epsilon: 0.62
# Episode: 98/500, Score: 94.0, Epsilon: 0.61
# Episode: 99/500, Score: 31.0, Epsilon: 0.61
# Episode: 100/500, Score: 27.0, Epsilon: 0.61
# Episode: 101/500, Score: 24.0, Epsilon: 0.61
# Episode: 102/500, Score: 48.0, Epsilon: 0.60
# Episode: 103/500, Score: 48.0, Epsilon: 0.60
# Episode: 104/500, Score: 175.0, Epsilon: 0.60
# Episode: 105/500, Score: 35.0, Epsilon: 0.59
# Episode: 106/500, Score: 57.0, Epsilon: 0.59
# Episode: 107/500, Score: 21.0, Epsilon: 0.59
# Episode: 108/500, Score: 34.0, Epsilon: 0.58
# Episode: 109/500, Score: 20.0, Epsilon: 0.58
# Episode: 110/500, Score: 117.0, Epsilon: 0.58
# Episode: 111/500, Score: 26.0, Epsilon: 0.58
# Episode: 112/500, Score: 30.0, Epsilon: 0.57
# Episode: 113/500, Score: 76.0, Epsilon: 0.57
# Episode: 114/500, Score: 95.0, Epsilon: 0.57
# Episode: 115/500, Score: 87.0, Epsilon: 0.56
# Episode: 116/500, Score: 64.0, Epsilon: 0.56
# Episode: 117/500, Score: 114.0, Epsilon: 0.56
# Episode: 118/500, Score: 88.0, Epsilon: 0.56
# Episode: 119/500, Score: 179.0, Epsilon: 0.55
# Episode: 120/500, Score: 49.0, Epsilon: 0.55
# Episode: 121/500, Score: 169.0, Epsilon: 0.55
# Episode: 122/500, Score: 65.0, Epsilon: 0.55
# Episode: 123/500, Score: 33.0, Epsilon: 0.54
# Episode: 124/500, Score: 71.0, Epsilon: 0.54
# Episode: 125/500, Score: 81.0, Epsilon: 0.54
# Episode: 126/500, Score: 75.0, Epsilon: 0.53
# Episode: 127/500, Score: 80.0, Epsilon: 0.53
# Episode: 128/500, Score: 145.0, Epsilon: 0.53
# Episode: 129/500, Score: 21.0, Epsilon: 0.53
# Episode: 130/500, Score: 24.0, Epsilon: 0.52
# Episode: 131/500, Score: 27.0, Epsilon: 0.52
# Episode: 132/500, Score: 72.0, Epsilon: 0.52
# Episode: 133/500, Score: 37.0, Epsilon: 0.52
# Episode: 134/500, Score: 111.0, Epsilon: 0.51
# Episode: 135/500, Score: 79.0, Epsilon: 0.51
# Episode: 136/500, Score: 101.0, Epsilon: 0.51
# Episode: 137/500, Score: 81.0, Epsilon: 0.51
# Episode: 138/500, Score: 135.0, Epsilon: 0.50
# Episode: 139/500, Score: 103.0, Epsilon: 0.50
# Episode: 140/500, Score: 89.0, Epsilon: 0.50
# Episode: 141/500, Score: 95.0, Epsilon: 0.50
# Episode: 142/500, Score: 126.0, Epsilon: 0.49
# Episode: 143/500, Score: 280.0, Epsilon: 0.49
# Episode: 144/500, Score: 81.0, Epsilon: 0.49
# Episode: 145/500, Score: 225.0, Epsilon: 0.49
# Episode: 146/500, Score: 192.0, Epsilon: 0.48
# Episode: 147/500, Score: 180.0, Epsilon: 0.48
# Episode: 148/500, Score: 139.0, Epsilon: 0.48
# Episode: 149/500, Score: 202.0, Epsilon: 0.48
# Episode: 150/500, Score: 127.0, Epsilon: 0.47
# Episode: 151/500, Score: 94.0, Epsilon: 0.47
# Episode: 152/500, Score: 155.0, Epsilon: 0.47
# Episode: 153/500, Score: 179.0, Epsilon: 0.47
# Episode: 154/500, Score: 190.0, Epsilon: 0.46
# Episode: 155/500, Score: 155.0, Epsilon: 0.46
# Episode: 156/500, Score: 84.0, Epsilon: 0.46
# Episode: 157/500, Score: 130.0, Epsilon: 0.46
# Episode: 158/500, Score: 66.0, Epsilon: 0.46
# Episode: 159/500, Score: 142.0, Epsilon: 0.45
# Episode: 160/500, Score: 154.0, Epsilon: 0.45
# Episode: 161/500, Score: 44.0, Epsilon: 0.45
# Episode: 162/500, Score: 89.0, Epsilon: 0.45
# Episode: 163/500, Score: 58.0, Epsilon: 0.44
# Episode: 164/500, Score: 199.0, Epsilon: 0.44
# Episode: 165/500, Score: 227.0, Epsilon: 0.44
# Episode: 166/500, Score: 267.0, Epsilon: 0.44
# Episode: 167/500, Score: 118.0, Epsilon: 0.44
# Episode: 168/500, Score: 247.0, Epsilon: 0.43
# Episode: 169/500, Score: 214.0, Epsilon: 0.43
# Episode: 170/500, Score: 96.0, Epsilon: 0.43
# Episode: 171/500, Score: 57.0, Epsilon: 0.43
# Episode: 172/500, Score: 47.0, Epsilon: 0.42
# Episode: 173/500, Score: 35.0, Epsilon: 0.42
# Episode: 174/500, Score: 173.0, Epsilon: 0.42
# Episode: 175/500, Score: 203.0, Epsilon: 0.42
# Episode: 176/500, Score: 288.0, Epsilon: 0.42
# Episode: 177/500, Score: 220.0, Epsilon: 0.41
# Episode: 178/500, Score: 414.0, Epsilon: 0.41
# Episode: 179/500, Score: 63.0, Epsilon: 0.41
# Episode: 180/500, Score: 221.0, Epsilon: 0.41
# Episode: 181/500, Score: 103.0, Epsilon: 0.41
# Episode: 182/500, Score: 334.0, Epsilon: 0.40
# Episode: 183/500, Score: 202.0, Epsilon: 0.40
# Episode: 184/500, Score: 159.0, Epsilon: 0.40
# Episode: 185/500, Score: 108.0, Epsilon: 0.40
# Episode: 186/500, Score: 106.0, Epsilon: 0.40
# Episode: 187/500, Score: 195.0, Epsilon: 0.39
# Episode: 188/500, Score: 327.0, Epsilon: 0.39
# Episode: 189/500, Score: 55.0, Epsilon: 0.39
# Episode: 190/500, Score: 283.0, Epsilon: 0.39
# Episode: 191/500, Score: 334.0, Epsilon: 0.39
# Episode: 192/500, Score: 153.0, Epsilon: 0.38
# Episode: 193/500, Score: 283.0, Epsilon: 0.38
# Episode: 194/500, Score: 113.0, Epsilon: 0.38
# Episode: 195/500, Score: 292.0, Epsilon: 0.38
# Episode: 196/500, Score: 65.0, Epsilon: 0.38
# Episode: 197/500, Score: 287.0, Epsilon: 0.37
# Episode: 198/500, Score: 270.0, Epsilon: 0.37
# Episode: 199/500, Score: 196.0, Epsilon: 0.37
# Episode: 200/500, Score: 257.0, Epsilon: 0.37
# Episode: 201/500, Score: 204.0, Epsilon: 0.37
# Episode: 202/500, Score: 342.0, Epsilon: 0.37
# Episode: 203/500, Score: 335.0, Epsilon: 0.36
# Episode: 204/500, Score: 104.0, Epsilon: 0.36
# Episode: 205/500, Score: 12.0, Epsilon: 0.36
# Episode: 206/500, Score: 230.0, Epsilon: 0.36
# Episode: 207/500, Score: 287.0, Epsilon: 0.36
# Episode: 208/500, Score: 232.0, Epsilon: 0.35
# Episode: 209/500, Score: 227.0, Epsilon: 0.35
# Episode: 210/500, Score: 338.0, Epsilon: 0.35
# Episode: 211/500, Score: 214.0, Epsilon: 0.35
# Episode: 212/500, Score: 228.0, Epsilon: 0.35
# Episode: 213/500, Score: 441.0, Epsilon: 0.35
# Episode: 214/500, Score: 361.0, Epsilon: 0.34
# Episode: 215/500, Score: 255.0, Epsilon: 0.34
# Episode: 216/500, Score: 262.0, Epsilon: 0.34
# Episode: 217/500, Score: 329.0, Epsilon: 0.34
# Episode: 218/500, Score: 42.0, Epsilon: 0.34
# Episode: 219/500, Score: 215.0, Epsilon: 0.34
# Episode: 220/500, Score: 181.0, Epsilon: 0.33
# Episode: 221/500, Score: 316.0, Epsilon: 0.33
# Episode: 222/500, Score: 44.0, Epsilon: 0.33
# Episode: 223/500, Score: 192.0, Epsilon: 0.33
# Episode: 224/500, Score: 183.0, Epsilon: 0.33
# Episode: 225/500, Score: 106.0, Epsilon: 0.33
# Episode: 226/500, Score: 49.0, Epsilon: 0.32
# Episode: 227/500, Score: 158.0, Epsilon: 0.32
# Episode: 228/500, Score: 335.0, Epsilon: 0.32
# Episode: 229/500, Score: 232.0, Epsilon: 0.32
# Episode: 230/500, Score: 274.0, Epsilon: 0.32
# Episode: 231/500, Score: 241.0, Epsilon: 0.32
# Episode: 232/500, Score: 213.0, Epsilon: 0.31
# Episode: 233/500, Score: 160.0, Epsilon: 0.31
# Episode: 234/500, Score: 250.0, Epsilon: 0.31
# Episode: 235/500, Score: 227.0, Epsilon: 0.31
# Episode: 236/500, Score: 217.0, Epsilon: 0.31
# Episode: 237/500, Score: 260.0, Epsilon: 0.31
# Episode: 238/500, Score: 106.0, Epsilon: 0.30
# Episode: 239/500, Score: 182.0, Epsilon: 0.30
# Episode: 240/500, Score: 187.0, Epsilon: 0.30
# Episode: 241/500, Score: 286.0, Epsilon: 0.30
# Episode: 242/500, Score: 183.0, Epsilon: 0.30
# Episode: 243/500, Score: 378.0, Epsilon: 0.30
# Episode: 244/500, Score: 208.0, Epsilon: 0.30
# Episode: 245/500, Score: 198.0, Epsilon: 0.29
# Episode: 246/500, Score: 256.0, Epsilon: 0.29
# Episode: 247/500, Score: 161.0, Epsilon: 0.29
# Episode: 248/500, Score: 271.0, Epsilon: 0.29
# Episode: 249/500, Score: 240.0, Epsilon: 0.29
# Episode: 250/500, Score: 76.0, Epsilon: 0.29
# Episode: 251/500, Score: 25.0, Epsilon: 0.29
# Episode: 252/500, Score: 309.0, Epsilon: 0.28
# Episode: 253/500, Score: 175.0, Epsilon: 0.28
# Episode: 254/500, Score: 256.0, Epsilon: 0.28
# Episode: 255/500, Score: 187.0, Epsilon: 0.28
# Episode: 256/500, Score: 218.0, Epsilon: 0.28
# Episode: 257/500, Score: 239.0, Epsilon: 0.28
# Episode: 258/500, Score: 202.0, Epsilon: 0.28
# Episode: 259/500, Score: 226.0, Epsilon: 0.27
# Episode: 260/500, Score: 233.0, Epsilon: 0.27
# Episode: 261/500, Score: 163.0, Epsilon: 0.27
# Episode: 262/500, Score: 196.0, Epsilon: 0.27
# Episode: 263/500, Score: 201.0, Epsilon: 0.27
# Episode: 264/500, Score: 373.0, Epsilon: 0.27
# Episode: 265/500, Score: 290.0, Epsilon: 0.27
# Episode: 266/500, Score: 196.0, Epsilon: 0.26
# Episode: 267/500, Score: 189.0, Epsilon: 0.26
# Episode: 268/500, Score: 188.0, Epsilon: 0.26
# Episode: 269/500, Score: 213.0, Epsilon: 0.26
# Episode: 270/500, Score: 199.0, Epsilon: 0.26
# Episode: 271/500, Score: 243.0, Epsilon: 0.26
# Episode: 272/500, Score: 269.0, Epsilon: 0.26
# Episode: 273/500, Score: 194.0, Epsilon: 0.26
# Episode: 274/500, Score: 259.0, Epsilon: 0.25
# Episode: 275/500, Score: 253.0, Epsilon: 0.25
# Episode: 276/500, Score: 175.0, Epsilon: 0.25
# Episode: 277/500, Score: 88.0, Epsilon: 0.25
# Episode: 278/500, Score: 241.0, Epsilon: 0.25
# Episode: 279/500, Score: 225.0, Epsilon: 0.25
# Episode: 280/500, Score: 422.0, Epsilon: 0.25
# Episode: 281/500, Score: 211.0, Epsilon: 0.25
# Episode: 282/500, Score: 195.0, Epsilon: 0.24
# Episode: 283/500, Score: 343.0, Epsilon: 0.24
# Episode: 284/500, Score: 306.0, Epsilon: 0.24
# Episode: 285/500, Score: 314.0, Epsilon: 0.24
# Episode: 286/500, Score: 197.0, Epsilon: 0.24
# Episode: 287/500, Score: 213.0, Epsilon: 0.24
# Episode: 288/500, Score: 254.0, Epsilon: 0.24
# Episode: 289/500, Score: 82.0, Epsilon: 0.24
# Episode: 290/500, Score: 250.0, Epsilon: 0.23
# Episode: 291/500, Score: 145.0, Epsilon: 0.23
# Episode: 292/500, Score: 254.0, Epsilon: 0.23
# Episode: 293/500, Score: 215.0, Epsilon: 0.23
# Episode: 294/500, Score: 198.0, Epsilon: 0.23
# Episode: 295/500, Score: 190.0, Epsilon: 0.23
# Episode: 296/500, Score: 187.0, Epsilon: 0.23
# Episode: 297/500, Score: 268.0, Epsilon: 0.23
# Episode: 298/500, Score: 205.0, Epsilon: 0.23
# Episode: 299/500, Score: 234.0, Epsilon: 0.22
# Episode: 300/500, Score: 322.0, Epsilon: 0.22
# Episode: 301/500, Score: 246.0, Epsilon: 0.22
# Episode: 302/500, Score: 460.0, Epsilon: 0.22
# Episode: 303/500, Score: 215.0, Epsilon: 0.22
# Episode: 304/500, Score: 204.0, Epsilon: 0.22
# Episode: 305/500, Score: 276.0, Epsilon: 0.22
# Episode: 306/500, Score: 470.0, Epsilon: 0.22
# Episode: 307/500, Score: 227.0, Epsilon: 0.22
# Episode: 308/500, Score: 287.0, Epsilon: 0.21
# Episode: 309/500, Score: 198.0, Epsilon: 0.21
# Episode: 310/500, Score: 272.0, Epsilon: 0.21
# Episode: 311/500, Score: 221.0, Epsilon: 0.21
# Episode: 312/500, Score: 261.0, Epsilon: 0.21
# Episode: 313/500, Score: 280.0, Epsilon: 0.21
# Episode: 314/500, Score: 253.0, Epsilon: 0.21
# Episode: 315/500, Score: 220.0, Epsilon: 0.21
# Episode: 316/500, Score: 206.0, Epsilon: 0.21
# Episode: 317/500, Score: 207.0, Epsilon: 0.21
# Episode: 318/500, Score: 270.0, Epsilon: 0.20
# Episode: 319/500, Score: 230.0, Epsilon: 0.20
# Episode: 320/500, Score: 261.0, Epsilon: 0.20
# Episode: 321/500, Score: 348.0, Epsilon: 0.20
# Episode: 322/500, Score: 203.0, Epsilon: 0.20
# Episode: 323/500, Score: 238.0, Epsilon: 0.20
# Episode: 324/500, Score: 264.0, Epsilon: 0.20
# Episode: 325/500, Score: 200.0, Epsilon: 0.20
# Episode: 326/500, Score: 182.0, Epsilon: 0.20
# Episode: 327/500, Score: 276.0, Epsilon: 0.20
# Episode: 328/500, Score: 325.0, Epsilon: 0.19
# Episode: 329/500, Score: 378.0, Epsilon: 0.19
# Episode: 330/500, Score: 236.0, Epsilon: 0.19
# Episode: 331/500, Score: 205.0, Epsilon: 0.19
# Episode: 332/500, Score: 204.0, Epsilon: 0.19
# Episode: 333/500, Score: 239.0, Epsilon: 0.19
# Episode: 334/500, Score: 172.0, Epsilon: 0.19
# Episode: 335/500, Score: 298.0, Epsilon: 0.19
# Episode: 336/500, Score: 265.0, Epsilon: 0.19
# Episode: 337/500, Score: 366.0, Epsilon: 0.19
# Episode: 338/500, Score: 353.0, Epsilon: 0.18
# Episode: 339/500, Score: 238.0, Epsilon: 0.18
# Episode: 340/500, Score: 164.0, Epsilon: 0.18
# Episode: 341/500, Score: 216.0, Epsilon: 0.18
# Episode: 342/500, Score: 287.0, Epsilon: 0.18
# Episode: 343/500, Score: 218.0, Epsilon: 0.18
# Episode: 344/500, Score: 197.0, Epsilon: 0.18
# Episode: 345/500, Score: 293.0, Epsilon: 0.18
# Episode: 346/500, Score: 247.0, Epsilon: 0.18
# Episode: 347/500, Score: 228.0, Epsilon: 0.18
# Episode: 348/500, Score: 220.0, Epsilon: 0.18
# Episode: 349/500, Score: 250.0, Epsilon: 0.17
# Episode: 350/500, Score: 188.0, Epsilon: 0.17
# Episode: 351/500, Score: 236.0, Epsilon: 0.17
# Episode: 352/500, Score: 263.0, Epsilon: 0.17
# Episode: 353/500, Score: 189.0, Epsilon: 0.17
# Episode: 354/500, Score: 224.0, Epsilon: 0.17
# Episode: 355/500, Score: 329.0, Epsilon: 0.17
# Episode: 356/500, Score: 288.0, Epsilon: 0.17
# Episode: 357/500, Score: 184.0, Epsilon: 0.17
# Episode: 358/500, Score: 247.0, Epsilon: 0.17
# Episode: 359/500, Score: 351.0, Epsilon: 0.17
# Episode: 360/500, Score: 235.0, Epsilon: 0.17
# Episode: 361/500, Score: 279.0, Epsilon: 0.16
# Episode: 362/500, Score: 255.0, Epsilon: 0.16
# Episode: 363/500, Score: 250.0, Epsilon: 0.16
# Episode: 364/500, Score: 318.0, Epsilon: 0.16
# Episode: 365/500, Score: 251.0, Epsilon: 0.16
# Episode: 366/500, Score: 182.0, Epsilon: 0.16
# Episode: 367/500, Score: 264.0, Epsilon: 0.16
# Episode: 368/500, Score: 183.0, Epsilon: 0.16
# Episode: 369/500, Score: 250.0, Epsilon: 0.16
# Episode: 370/500, Score: 324.0, Epsilon: 0.16
# Episode: 371/500, Score: 232.0, Epsilon: 0.16
# Episode: 372/500, Score: 468.0, Epsilon: 0.16
# Episode: 373/500, Score: 165.0, Epsilon: 0.15
# Episode: 374/500, Score: 193.0, Epsilon: 0.15
# Episode: 375/500, Score: 207.0, Epsilon: 0.15
# Episode: 376/500, Score: 206.0, Epsilon: 0.15
# Episode: 377/500, Score: 244.0, Epsilon: 0.15
# Episode: 378/500, Score: 274.0, Epsilon: 0.15
# Episode: 379/500, Score: 232.0, Epsilon: 0.15
# Episode: 380/500, Score: 203.0, Epsilon: 0.15
# Episode: 381/500, Score: 458.0, Epsilon: 0.15
# Episode: 382/500, Score: 211.0, Epsilon: 0.15
# Episode: 383/500, Score: 556.0, Epsilon: 0.15
# Episode: 384/500, Score: 316.0, Epsilon: 0.15
# Episode: 385/500, Score: 308.0, Epsilon: 0.15
# Episode: 386/500, Score: 225.0, Epsilon: 0.15
# Episode: 387/500, Score: 212.0, Epsilon: 0.14
# Episode: 388/500, Score: 272.0, Epsilon: 0.14
# Episode: 389/500, Score: 404.0, Epsilon: 0.14
# Episode: 390/500, Score: 426.0, Epsilon: 0.14
# Episode: 391/500, Score: 258.0, Epsilon: 0.14
# Episode: 392/500, Score: 237.0, Epsilon: 0.14
# Episode: 393/500, Score: 239.0, Epsilon: 0.14
# Episode: 394/500, Score: 288.0, Epsilon: 0.14
# Episode: 395/500, Score: 298.0, Epsilon: 0.14
# Episode: 396/500, Score: 201.0, Epsilon: 0.14
# Episode: 397/500, Score: 209.0, Epsilon: 0.14
# Episode: 398/500, Score: 239.0, Epsilon: 0.14
# Episode: 399/500, Score: 355.0, Epsilon: 0.14
# Episode: 400/500, Score: 248.0, Epsilon: 0.14
# Episode: 401/500, Score: 322.0, Epsilon: 0.13
# Episode: 402/500, Score: 368.0, Epsilon: 0.13
# Episode: 403/500, Score: 296.0, Epsilon: 0.13
# Episode: 404/500, Score: 333.0, Epsilon: 0.13
# Episode: 405/500, Score: 381.0, Epsilon: 0.13
# Episode: 406/500, Score: 189.0, Epsilon: 0.13
# Episode: 407/500, Score: 355.0, Epsilon: 0.13
# Episode: 408/500, Score: 285.0, Epsilon: 0.13
# Episode: 409/500, Score: 324.0, Epsilon: 0.13
# Episode: 410/500, Score: 204.0, Epsilon: 0.13
# Episode: 411/500, Score: 233.0, Epsilon: 0.13
# Episode: 412/500, Score: 159.0, Epsilon: 0.13
# Episode: 413/500, Score: 305.0, Epsilon: 0.13
# Episode: 414/500, Score: 180.0, Epsilon: 0.13
# Episode: 415/500, Score: 198.0, Epsilon: 0.13
# Episode: 416/500, Score: 335.0, Epsilon: 0.12
# Episode: 417/500, Score: 242.0, Epsilon: 0.12
# Episode: 418/500, Score: 202.0, Epsilon: 0.12
# Episode: 419/500, Score: 165.0, Epsilon: 0.12
# Episode: 420/500, Score: 180.0, Epsilon: 0.12
# Episode: 421/500, Score: 230.0, Epsilon: 0.12
# Episode: 422/500, Score: 218.0, Epsilon: 0.12
# Episode: 423/500, Score: 304.0, Epsilon: 0.12
# Episode: 424/500, Score: 195.0, Epsilon: 0.12
# Episode: 425/500, Score: 255.0, Epsilon: 0.12
# Episode: 426/500, Score: 207.0, Epsilon: 0.12
# Episode: 427/500, Score: 325.0, Epsilon: 0.12
# Episode: 428/500, Score: 244.0, Epsilon: 0.12
# Episode: 429/500, Score: 244.0, Epsilon: 0.12
# Episode: 430/500, Score: 243.0, Epsilon: 0.12
# Episode: 431/500, Score: 278.0, Epsilon: 0.12
# Episode: 432/500, Score: 220.0, Epsilon: 0.12
# Episode: 433/500, Score: 194.0, Epsilon: 0.11
# Episode: 434/500, Score: 192.0, Epsilon: 0.11
# Episode: 435/500, Score: 227.0, Epsilon: 0.11
# Episode: 436/500, Score: 192.0, Epsilon: 0.11
# Episode: 437/500, Score: 191.0, Epsilon: 0.11
# Episode: 438/500, Score: 184.0, Epsilon: 0.11
# Episode: 439/500, Score: 180.0, Epsilon: 0.11
# Episode: 440/500, Score: 252.0, Epsilon: 0.11
# Episode: 441/500, Score: 192.0, Epsilon: 0.11
# Episode: 442/500, Score: 209.0, Epsilon: 0.11
# Episode: 443/500, Score: 227.0, Epsilon: 0.11
# Episode: 444/500, Score: 163.0, Epsilon: 0.11
# Episode: 445/500, Score: 204.0, Epsilon: 0.11
# Episode: 446/500, Score: 22.0, Epsilon: 0.11
# Episode: 447/500, Score: 234.0, Epsilon: 0.11
# Episode: 448/500, Score: 186.0, Epsilon: 0.11
# Episode: 449/500, Score: 174.0, Epsilon: 0.11
# Episode: 450/500, Score: 184.0, Epsilon: 0.11
# Episode: 451/500, Score: 193.0, Epsilon: 0.10
# Episode: 452/500, Score: 167.0, Epsilon: 0.10
# Episode: 453/500, Score: 151.0, Epsilon: 0.10
# Episode: 454/500, Score: 211.0, Epsilon: 0.10
# Episode: 455/500, Score: 155.0, Epsilon: 0.10
# Episode: 456/500, Score: 170.0, Epsilon: 0.10
# Episode: 457/500, Score: 170.0, Epsilon: 0.10
# Episode: 458/500, Score: 173.0, Epsilon: 0.10
# Episode: 459/500, Score: 178.0, Epsilon: 0.10
# Episode: 460/500, Score: 181.0, Epsilon: 0.10
# Episode: 461/500, Score: 165.0, Epsilon: 0.10
# Episode: 462/500, Score: 186.0, Epsilon: 0.10
# Episode: 463/500, Score: 159.0, Epsilon: 0.10
# Episode: 464/500, Score: 171.0, Epsilon: 0.10
# Episode: 465/500, Score: 170.0, Epsilon: 0.10
# Episode: 466/500, Score: 181.0, Epsilon: 0.10
# Episode: 467/500, Score: 167.0, Epsilon: 0.10
# Episode: 468/500, Score: 180.0, Epsilon: 0.10
# Episode: 469/500, Score: 159.0, Epsilon: 0.10
# Episode: 470/500, Score: 208.0, Epsilon: 0.10
# Episode: 471/500, Score: 168.0, Epsilon: 0.09
# Episode: 472/500, Score: 168.0, Epsilon: 0.09
# Episode: 473/500, Score: 186.0, Epsilon: 0.09
# Episode: 474/500, Score: 172.0, Epsilon: 0.09
# Episode: 475/500, Score: 170.0, Epsilon: 0.09
# Episode: 476/500, Score: 148.0, Epsilon: 0.09
# Episode: 477/500, Score: 146.0, Epsilon: 0.09
# Episode: 478/500, Score: 145.0, Epsilon: 0.09
# Episode: 479/500, Score: 159.0, Epsilon: 0.09
# Episode: 480/500, Score: 166.0, Epsilon: 0.09
# Episode: 481/500, Score: 118.0, Epsilon: 0.09
# Episode: 482/500, Score: 157.0, Epsilon: 0.09
# Episode: 483/500, Score: 163.0, Epsilon: 0.09
# Episode: 484/500, Score: 183.0, Epsilon: 0.09
# Episode: 485/500, Score: 186.0, Epsilon: 0.09
# Episode: 486/500, Score: 151.0, Epsilon: 0.09
# Episode: 487/500, Score: 140.0, Epsilon: 0.09
# Episode: 488/500, Score: 141.0, Epsilon: 0.09
# Episode: 489/500, Score: 178.0, Epsilon: 0.09
# Episode: 490/500, Score: 153.0, Epsilon: 0.09
# Episode: 491/500, Score: 13.0, Epsilon: 0.09
# Episode: 492/500, Score: 158.0, Epsilon: 0.09
# Episode: 493/500, Score: 160.0, Epsilon: 0.08
# Episode: 494/500, Score: 161.0, Epsilon: 0.08
# Episode: 495/500, Score: 183.0, Epsilon: 0.08
# Episode: 496/500, Score: 197.0, Epsilon: 0.08
# Episode: 497/500, Score: 176.0, Epsilon: 0.08
# Episode: 498/500, Score: 156.0, Epsilon: 0.08
# Episode: 499/500, Score: 160.0, Epsilon: 0.08
# Episode: 500/500, Score: 142.0, Epsilon: 0.08

# %%
"""
   In this cell we calculate if the Challenge can be considered as solved
   Solved conditions are : in 100 episodes the average reward per episode over 195
"""

episodes = 100
threshold = 195
total_rewards = []

env = gym.make('CartPole-v1', render_mode='rgb_array')


for _ in range(episodes):
    state, _ = env.reset()
    done = False
    episode_reward = 0
        
    while not done:
       state_v = np.reshape(state, [1, state_size])
       q_values = model.predict(state_v, verbose=0)
       action = np.argmax(q_values[0])
            
       next_state, reward, terminated, truncated, _ = env.step(action)

       episode_reward += reward
            
       state = next_state
       
       if terminated or truncated:
           done = True
        
    total_rewards.append(episode_reward)
    
average_reward = np.mean(total_rewards)
solved = average_reward >= threshold
if solved:
    text = "solved"
else:
    text = "unsolved"
print ('The Challenge has been', text, 'with an average of', average_reward, 
       'avg/reward per episode after 100 episodes')
# Out:
# The Challenge has been unsolved with an average of 18.76 avg/reward per episode after 100 episodes

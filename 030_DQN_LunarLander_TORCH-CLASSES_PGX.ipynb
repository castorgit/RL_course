# %% [markdown]
# ### **Lunar Lander DQN TORCH using Clases**
#
# This is a naive version of the Lunar Lander DQN algorithm using an Agent Class<br>
# <br>
# In this version the agent has been created as a class making the code more compact <br>
# This DQN Class can be used with other environments <br>
#  <br>
# Try to make it faster by doing some hyperparameter optimization  <br>
# Try to explore less. Does it accelerates convergence?  <br>
# Increasing the ```ROLLING_WINDOW``` value will gnerate slower agent convergence but the Agent behavior will be more consistent <br>
#
# An issue you may find is a lander that hovers forever. This happens because it has been programmed with infinite fuel. You can see it in this execution in the lines that are marked as ```Terminated=False```. This confuses the training because it does not reach the objective or termination. Without modifying the environment, there are a couple of things that can be done to ameliorate this behavior <br>
#
# 1. **Limit number of steps** In this case we are limiting the number of steps to 1200, if you don't limit it sometimes it goes up to thousands of steps, and this is a waste of time
# 2. **Increase gravity** The default gravity in this environment is -10.0, you can increase it up to -12.0, increasing it you'll have a faster descent and hovering becomes more difficult ```env = gym.make("LunarLander-v3", gravity=11.0)```

# %%
import os
import random
import gymnasium as gym
import time
import numpy as np
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from PIL import Image
import time

import sys
sys.stderr = open('err.txt', 'w')

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version (built):", torch.version.cuda)
print("Device count:", torch.cuda.device_count())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"  GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"    Compute capability: {torch.cuda.get_device_capability(i)}")
        print(f"    Memory: {torch.cuda.get_device_properties(i).total_memory / 1e9:.1f} GB")

    # Quick sanity check: actually run something on the GPU
    x = torch.randn(1000, 1000, device="cuda")
    y = x @ x
    print("Matmul on GPU OK, result shape:", y.shape)
else:
    print("No GPU visible to PyTorch.")
# Out:
# PyTorch version: 2.11.0+cu130
# CUDA available: True
# CUDA version (built): 13.0
# Device count: 1
#   GPU 0: NVIDIA GB10
#     Compute capability: (12, 1)
#     Memory: 130.6 GB
# Matmul on GPU OK, result shape: torch.Size([1000, 1000])

# %% [markdown]
# #### **Hyperparameters**

# %%
MAX_EPISODES = 2000
ROLLING_WINDOW = 40
MEMORY_SIZE = 100000
MAX_STEPS = 1200

gamma = 0.99                         # discount rate
epsilon = 1.0                        # exploration rate
epsilon_min = 0.01
epsilon_decay = 0.99
learning_rate = 0.0001
batch_size = 64
solved_threshold = 200

verb = 0                             # to see traces (verbosity)

# %%
# Environment setup
env = gym.make('LunarLander-v3')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class Q_Network(nn.Module):
    def __init__(self, state_size, action_size):
        super().__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.out = nn.Linear(32, action_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        return self.out(x)


class Agent_DQN():
    def __init__(self, states, actions, alpha, gamma, epsilon):
        self.nS = states
        self.nA = actions
        self.replay_buffer = deque([], maxlen=MEMORY_SIZE)
        self.alpha = alpha
        self.gamma = gamma
        #Explore/Exploit
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.model = self.build_NN()
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()
        self.loss = []

    def build_NN(self):
        model = Q_Network(state_size, action_size).to(device)
        print(model)
        return model

    def action(self, state):
        state_tensor = torch.as_tensor(state, dtype=torch.float32, device=device)
        self.model.eval()
        with torch.no_grad():
            action_vals = self.model(state_tensor)
        self.model.train()
        return torch.argmax(action_vals[0]).item()
    
    def random_action(self):
        return random.randrange(self.nA) #Explore
    
    def sample_experiences(self, batch_size):
        indices = np.random.choice(len(self.replay_buffer), batch_size, replace=False)
        batch = [self.replay_buffer[i] for i in indices]
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            np.vstack(states),
            np.array(actions),
            np.array(rewards),
            np.vstack(next_states),
            np.array(dones, dtype=np.float32)
            )
    def store_experience(self, state, action, reward, next_state, done):             # memorize
        self.replay_buffer.append((state, action, reward, next_state, done))
    
    def experience_replay(self, batch_size, epsilon):
        if len(self.replay_buffer) < batch_size:
            return
        minibatch = random.sample(self.replay_buffer, batch_size)
        states, actions, rewards, next_states, dones = self.sample_experiences(batch_size)

        states_tensor = torch.as_tensor(states, dtype=torch.float32, device=device)
        actions_tensor = torch.as_tensor(actions, dtype=torch.long, device=device)
        rewards_tensor = torch.as_tensor(rewards, dtype=torch.float32, device=device)
        next_states_tensor = torch.as_tensor(next_states, dtype=torch.float32, device=device)
        dones_tensor = torch.as_tensor(dones, dtype=torch.float32, device=device)

        q_values = self.model(states_tensor)
        with torch.no_grad():
            next_qs = self.model(next_states_tensor)
            target_qs = q_values.detach().clone()
            target_qs[torch.arange(batch_size, device=device), actions_tensor] = (
                rewards_tensor + self.gamma * torch.max(next_qs, dim=1).values * (1 - dones_tensor)
            )

        loss = self.loss_fn(q_values, target_qs)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.loss.append(loss.item())
        return

# %%
# Support function
def select_action_greedy(state, agent_DQN):                                    
    if np.random.rand() <= epsilon:
        return agent_DQN.random_action()
    return agent_DQN.action(state)

# %% [markdown]
# #### **Support Functions**

# %%
env = gym.make('LunarLander-v3')
state_size = int(env.observation_space.shape[0])
action_size = int(env.action_space.n)

agent = Agent_DQN(state_size, action_size, learning_rate, gamma, epsilon)
# Out:
# Q_Network(
#   (fc1): Linear(in_features=8, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (out): Linear(in_features=32, out_features=4, bias=True)
#   (relu): ReLU()
# )

# %%
rewards_per_episode= []
start_time = time.time()

done = False
rolling_avg = 0
rolling_avg_rewards = []



for e in range(MAX_EPISODES):                           # Should be While True, however we limit number of eps
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    for step in range(MAX_STEPS):
            
        action = select_action_greedy(state, agent)
        next_state, reward, done, truncated , _ = env.step(action)
                    
        next_state = np.reshape(next_state, [1, state_size])
        agent.store_experience(state, action, reward, next_state, done)
        state = next_state
        total_reward = total_reward + reward
        if done:
            break
            
        
        agent.experience_replay(batch_size, epsilon)
            
    epsilon = max(epsilon_min, epsilon * epsilon_decay)            # decay epsilon
    
    rewards_per_episode.append(total_reward)
    rolling_avg = np.mean(rewards_per_episode[-ROLLING_WINDOW:])   # append rewards
    rolling_avg_rewards.append(rolling_avg)
    print(f"Episode: {e+1:3}/{MAX_EPISODES}, Reward: {total_reward:+7.2f}, "
          f"Epsilon: {epsilon:.2f}, Rolling Avg: {rolling_avg:7.2f}, Steps: {step:4} Terminated: {done} ")

            
    # Check if environment is solved
    if rolling_avg >= solved_threshold:
        print(f"Environment solved in {e+1} episodes!")
        break

end_time = time.time()
print(f"Training completed in {(end_time - start_time)/60:.2f} minutes")
# Out:
# Episode:   1/2000, Reward: -223.59, Epsilon: 0.99, Rolling Avg: -223.59, Steps:   60 Terminated: True
# Episode:   2/2000, Reward: -246.60, Epsilon: 0.98, Rolling Avg: -235.09, Steps:  112 Terminated: True
# Episode:   3/2000, Reward: -224.70, Epsilon: 0.97, Rolling Avg: -231.63, Steps:  101 Terminated: True
# Episode:   4/2000, Reward: -101.47, Epsilon: 0.96, Rolling Avg: -199.09, Steps:  124 Terminated: True
# Episode:   5/2000, Reward:  -78.89, Epsilon: 0.95, Rolling Avg: -175.05, Steps:   72 Terminated: True
# Episode:   6/2000, Reward: -150.92, Epsilon: 0.94, Rolling Avg: -171.03, Steps:   92 Terminated: True
# Episode:   7/2000, Reward: -106.01, Epsilon: 0.93, Rolling Avg: -161.74, Steps:   91 Terminated: True
# Episode:   8/2000, Reward: -314.46, Epsilon: 0.92, Rolling Avg: -180.83, Steps:   80 Terminated: True
# Episode:   9/2000, Reward: -363.39, Epsilon: 0.91, Rolling Avg: -201.11, Steps:   93 Terminated: True
# Episode:  10/2000, Reward: -142.59, Epsilon: 0.90, Rolling Avg: -195.26, Steps:  135 Terminated: True
# Episode:  11/2000, Reward: -111.83, Epsilon: 0.90, Rolling Avg: -187.68, Steps:   92 Terminated: True
# Episode:  12/2000, Reward: -266.13, Epsilon: 0.89, Rolling Avg: -194.22, Steps:   91 Terminated: True
# Episode:  13/2000, Reward: -141.21, Epsilon: 0.88, Rolling Avg: -190.14, Steps:   74 Terminated: True
# Episode:  14/2000, Reward: -123.70, Epsilon: 0.87, Rolling Avg: -185.39, Steps:  124 Terminated: True
# Episode:  15/2000, Reward:  -70.89, Epsilon: 0.86, Rolling Avg: -177.76, Steps:   89 Terminated: True
# Episode:  16/2000, Reward: -110.79, Epsilon: 0.85, Rolling Avg: -173.57, Steps:   73 Terminated: True
# Episode:  17/2000, Reward: -333.91, Epsilon: 0.84, Rolling Avg: -183.00, Steps:  111 Terminated: True
# Episode:  18/2000, Reward:  -73.29, Epsilon: 0.83, Rolling Avg: -176.91, Steps:   95 Terminated: True
# Episode:  19/2000, Reward: -203.23, Epsilon: 0.83, Rolling Avg: -178.29, Steps:  121 Terminated: True
# Episode:  20/2000, Reward: -289.52, Epsilon: 0.82, Rolling Avg: -183.86, Steps:  121 Terminated: True
# Episode:  21/2000, Reward: -356.05, Epsilon: 0.81, Rolling Avg: -192.06, Steps:  106 Terminated: True
# Episode:  22/2000, Reward: -373.08, Epsilon: 0.80, Rolling Avg: -200.28, Steps:   85 Terminated: True
# Episode:  23/2000, Reward: -303.46, Epsilon: 0.79, Rolling Avg: -204.77, Steps:   91 Terminated: True
# Episode:  24/2000, Reward: -198.22, Epsilon: 0.79, Rolling Avg: -204.50, Steps:  122 Terminated: True
# Episode:  25/2000, Reward:  -36.24, Epsilon: 0.78, Rolling Avg: -197.77, Steps:   59 Terminated: True
# Episode:  26/2000, Reward:  -86.48, Epsilon: 0.77, Rolling Avg: -193.49, Steps:   71 Terminated: True
# Episode:  27/2000, Reward: -238.96, Epsilon: 0.76, Rolling Avg: -195.17, Steps:   77 Terminated: True
# Episode:  28/2000, Reward: -376.08, Epsilon: 0.75, Rolling Avg: -201.63, Steps:   74 Terminated: True
# Episode:  29/2000, Reward: -371.17, Epsilon: 0.75, Rolling Avg: -207.48, Steps:   77 Terminated: True
# Episode:  30/2000, Reward: -268.99, Epsilon: 0.74, Rolling Avg: -209.53, Steps:   88 Terminated: True
# Episode:  31/2000, Reward:  -85.73, Epsilon: 0.73, Rolling Avg: -205.53, Steps:  103 Terminated: True
# Episode:  32/2000, Reward: -132.90, Epsilon: 0.72, Rolling Avg: -203.26, Steps:   67 Terminated: True
# Episode:  33/2000, Reward: -268.89, Epsilon: 0.72, Rolling Avg: -205.25, Steps:   86 Terminated: True
# Episode:  34/2000, Reward:  -91.51, Epsilon: 0.71, Rolling Avg: -201.91, Steps:   63 Terminated: True
# Episode:  35/2000, Reward: -314.09, Epsilon: 0.70, Rolling Avg: -205.11, Steps:   84 Terminated: True
# Episode:  36/2000, Reward:  -59.27, Epsilon: 0.70, Rolling Avg: -201.06, Steps:   95 Terminated: True
# Episode:  37/2000, Reward: -127.54, Epsilon: 0.69, Rolling Avg: -199.07, Steps:  101 Terminated: True
# Episode:  38/2000, Reward:  -47.99, Epsilon: 0.68, Rolling Avg: -195.10, Steps:  115 Terminated: True
# Episode:  39/2000, Reward: -233.09, Epsilon: 0.68, Rolling Avg: -196.07, Steps:  143 Terminated: True
# Episode:  40/2000, Reward:  -84.27, Epsilon: 0.67, Rolling Avg: -193.28, Steps:  140 Terminated: True
# Episode:  41/2000, Reward: -247.52, Epsilon: 0.66, Rolling Avg: -193.88, Steps:  146 Terminated: True
# Episode:  42/2000, Reward:  -41.70, Epsilon: 0.66, Rolling Avg: -188.75, Steps:   99 Terminated: True
# Episode:  43/2000, Reward: -143.01, Epsilon: 0.65, Rolling Avg: -186.71, Steps:  104 Terminated: True
# Episode:  44/2000, Reward: -146.08, Epsilon: 0.64, Rolling Avg: -187.83, Steps:  201 Terminated: True
# Episode:  45/2000, Reward: -267.84, Epsilon: 0.64, Rolling Avg: -192.55, Steps:  201 Terminated: True
# Episode:  46/2000, Reward:  -95.46, Epsilon: 0.63, Rolling Avg: -191.16, Steps:  130 Terminated: True
# Episode:  47/2000, Reward: -153.89, Epsilon: 0.62, Rolling Avg: -192.36, Steps:  210 Terminated: True
# Episode:  48/2000, Reward: -202.21, Epsilon: 0.62, Rolling Avg: -189.55, Steps:  132 Terminated: True
# Episode:  49/2000, Reward: -217.56, Epsilon: 0.61, Rolling Avg: -185.91, Steps:  166 Terminated: True
# Episode:  50/2000, Reward: -254.36, Epsilon: 0.61, Rolling Avg: -188.70, Steps:  345 Terminated: True
# Episode:  51/2000, Reward:  -96.84, Epsilon: 0.60, Rolling Avg: -188.33, Steps:   84 Terminated: True
# Episode:  52/2000, Reward:  -71.77, Epsilon: 0.59, Rolling Avg: -183.47, Steps:   82 Terminated: True
# Episode:  53/2000, Reward: -133.81, Epsilon: 0.59, Rolling Avg: -183.28, Steps:  222 Terminated: True
# Episode:  54/2000, Reward: -182.74, Epsilon: 0.58, Rolling Avg: -184.76, Steps:  158 Terminated: True
# Episode:  55/2000, Reward: -314.85, Epsilon: 0.58, Rolling Avg: -190.86, Steps:  172 Terminated: True
# Episode:  56/2000, Reward: -168.55, Epsilon: 0.57, Rolling Avg: -192.30, Steps:  240 Terminated: True
# Episode:  57/2000, Reward: -174.86, Epsilon: 0.56, Rolling Avg: -188.33, Steps:  191 Terminated: True
# Episode:  58/2000, Reward: -291.86, Epsilon: 0.56, Rolling Avg: -193.79, Steps:  400 Terminated: True
# Episode:  59/2000, Reward: -232.17, Epsilon: 0.55, Rolling Avg: -194.51, Steps:  221 Terminated: True
# Episode:  60/2000, Reward: -119.95, Epsilon: 0.55, Rolling Avg: -190.28, Steps:  169 Terminated: True
# Episode:  61/2000, Reward: -116.07, Epsilon: 0.54, Rolling Avg: -184.28, Steps:  105 Terminated: True
# Episode:  62/2000, Reward:  -44.05, Epsilon: 0.54, Rolling Avg: -176.05, Steps:  174 Terminated: True
# Episode:  63/2000, Reward: -164.37, Epsilon: 0.53, Rolling Avg: -172.57, Steps:  249 Terminated: True
# Episode:  64/2000, Reward: -114.60, Epsilon: 0.53, Rolling Avg: -170.48, Steps:  193 Terminated: True
# Episode:  65/2000, Reward: -105.96, Epsilon: 0.52, Rolling Avg: -172.23, Steps:   80 Terminated: True
# Episode:  66/2000, Reward:  -86.26, Epsilon: 0.52, Rolling Avg: -172.22, Steps:  121 Terminated: True
# Episode:  67/2000, Reward:  -84.29, Epsilon: 0.51, Rolling Avg: -168.35, Steps:  104 Terminated: True
# Episode:  68/2000, Reward: -194.99, Epsilon: 0.50, Rolling Avg: -163.83, Steps:  229 Terminated: True
# Episode:  69/2000, Reward: -168.56, Epsilon: 0.50, Rolling Avg: -158.76, Steps:  142 Terminated: True
# Episode:  70/2000, Reward: -176.22, Epsilon: 0.49, Rolling Avg: -156.44, Steps:  116 Terminated: True
# Episode:  71/2000, Reward:  -66.81, Epsilon: 0.49, Rolling Avg: -155.97, Steps:   69 Terminated: True
# Episode:  72/2000, Reward: -132.16, Epsilon: 0.48, Rolling Avg: -155.95, Steps:  341 Terminated: True
# Episode:  73/2000, Reward:  -83.21, Epsilon: 0.48, Rolling Avg: -151.31, Steps:   92 Terminated: True
# Episode:  74/2000, Reward:  -56.64, Epsilon: 0.48, Rolling Avg: -150.44, Steps:  169 Terminated: True
# Episode:  75/2000, Reward: -120.29, Epsilon: 0.47, Rolling Avg: -145.59, Steps:  136 Terminated: True
# Episode:  76/2000, Reward:  -97.47, Epsilon: 0.47, Rolling Avg: -146.55, Steps:   95 Terminated: True
# Episode:  77/2000, Reward: -231.72, Epsilon: 0.46, Rolling Avg: -149.15, Steps:  264 Terminated: True
# Episode:  78/2000, Reward:   -6.82, Epsilon: 0.46, Rolling Avg: -148.12, Steps: 1199 Terminated: False
# Episode:  79/2000, Reward: -108.41, Epsilon: 0.45, Rolling Avg: -145.00, Steps:  230 Terminated: True
# Episode:  80/2000, Reward: -109.70, Epsilon: 0.45, Rolling Avg: -145.64, Steps:  391 Terminated: True
# Episode:  81/2000, Reward:  -14.57, Epsilon: 0.44, Rolling Avg: -139.82, Steps:  232 Terminated: True
# Episode:  82/2000, Reward:  -53.04, Epsilon: 0.44, Rolling Avg: -140.10, Steps:   96 Terminated: True
# Episode:  83/2000, Reward:  -30.56, Epsilon: 0.43, Rolling Avg: -137.29, Steps:  207 Terminated: True
# Episode:  84/2000, Reward: -144.24, Epsilon: 0.43, Rolling Avg: -137.24, Steps:  148 Terminated: True
# Episode:  85/2000, Reward:  -77.70, Epsilon: 0.43, Rolling Avg: -132.49, Steps:  107 Terminated: True
# Episode:  86/2000, Reward:  -96.83, Epsilon: 0.42, Rolling Avg: -132.52, Steps:  105 Terminated: True
# Episode:  87/2000, Reward:  -62.00, Epsilon: 0.42, Rolling Avg: -130.23, Steps:  295 Terminated: True
# Episode:  88/2000, Reward:  -63.29, Epsilon: 0.41, Rolling Avg: -126.75, Steps:  178 Terminated: True
# Episode:  89/2000, Reward:  -38.03, Epsilon: 0.41, Rolling Avg: -122.27, Steps:  152 Terminated: True
# Episode:  90/2000, Reward:  -41.47, Epsilon: 0.40, Rolling Avg: -116.94, Steps:  160 Terminated: True
# Episode:  91/2000, Reward:  -71.87, Epsilon: 0.40, Rolling Avg: -116.32, Steps:  390 Terminated: True
# Episode:  92/2000, Reward: -143.64, Epsilon: 0.40, Rolling Avg: -118.12, Steps:  150 Terminated: True
# Episode:  93/2000, Reward:  -79.14, Epsilon: 0.39, Rolling Avg: -116.75, Steps:  176 Terminated: True
# Episode:  94/2000, Reward:  -66.83, Epsilon: 0.39, Rolling Avg: -113.85, Steps:  278 Terminated: True
# Episode:  95/2000, Reward:  +59.28, Epsilon: 0.38, Rolling Avg: -104.50, Steps: 1199 Terminated: False
# Episode:  96/2000, Reward:  +67.42, Epsilon: 0.38, Rolling Avg:  -98.60, Steps:  198 Terminated: True
# Episode:  97/2000, Reward:  -70.32, Epsilon: 0.38, Rolling Avg:  -95.99, Steps:  155 Terminated: True
# Episode:  98/2000, Reward:  -67.58, Epsilon: 0.37, Rolling Avg:  -90.38, Steps:  190 Terminated: True
# Episode:  99/2000, Reward:  -60.85, Epsilon: 0.37, Rolling Avg:  -86.10, Steps:  190 Terminated: True
# Episode: 100/2000, Reward:  -41.12, Epsilon: 0.37, Rolling Avg:  -84.12, Steps:   99 Terminated: True
# Episode: 101/2000, Reward:  -42.31, Epsilon: 0.36, Rolling Avg:  -82.28, Steps:  475 Terminated: True
# Episode: 102/2000, Reward:  -98.58, Epsilon: 0.36, Rolling Avg:  -83.64, Steps:  293 Terminated: True
# Episode: 103/2000, Reward:  -15.12, Epsilon: 0.36, Rolling Avg:  -79.91, Steps: 1199 Terminated: False
# Episode: 104/2000, Reward:  -32.54, Epsilon: 0.35, Rolling Avg:  -77.86, Steps:  137 Terminated: True
# Episode: 105/2000, Reward:  +52.14, Epsilon: 0.35, Rolling Avg:  -73.91, Steps: 1199 Terminated: False
# Episode: 106/2000, Reward:  +12.28, Epsilon: 0.34, Rolling Avg:  -71.45, Steps:  128 Terminated: True
# Episode: 107/2000, Reward: -200.56, Epsilon: 0.34, Rolling Avg:  -74.35, Steps: 1199 Terminated: False
# Episode: 108/2000, Reward:  -70.89, Epsilon: 0.34, Rolling Avg:  -71.25, Steps: 1199 Terminated: False
# Episode: 109/2000, Reward: -110.07, Epsilon: 0.33, Rolling Avg:  -69.79, Steps: 1199 Terminated: False
# Episode: 110/2000, Reward:  -52.94, Epsilon: 0.33, Rolling Avg:  -66.71, Steps: 1199 Terminated: False
# Episode: 111/2000, Reward:   +0.14, Epsilon: 0.33, Rolling Avg:  -65.03, Steps: 1199 Terminated: False
# Episode: 112/2000, Reward:  -89.75, Epsilon: 0.32, Rolling Avg:  -63.97, Steps: 1199 Terminated: False
# Episode: 113/2000, Reward: -160.95, Epsilon: 0.32, Rolling Avg:  -65.91, Steps: 1199 Terminated: False
# Episode: 114/2000, Reward:   +6.44, Epsilon: 0.32, Rolling Avg:  -64.34, Steps: 1199 Terminated: False
# Episode: 115/2000, Reward:  -11.93, Epsilon: 0.31, Rolling Avg:  -61.63, Steps: 1199 Terminated: False
# Episode: 116/2000, Reward:  -46.40, Epsilon: 0.31, Rolling Avg:  -60.35, Steps:  841 Terminated: True
# Episode: 117/2000, Reward:  -93.37, Epsilon: 0.31, Rolling Avg:  -56.89, Steps: 1199 Terminated: False
# Episode: 118/2000, Reward: -120.08, Epsilon: 0.31, Rolling Avg:  -59.72, Steps: 1199 Terminated: False
# Episode: 119/2000, Reward: -112.11, Epsilon: 0.30, Rolling Avg:  -59.82, Steps: 1199 Terminated: False
# Episode: 120/2000, Reward: -121.13, Epsilon: 0.30, Rolling Avg:  -60.10, Steps: 1199 Terminated: False
# Episode: 121/2000, Reward:  -17.62, Epsilon: 0.30, Rolling Avg:  -60.18, Steps: 1199 Terminated: False
# Episode: 122/2000, Reward: -119.71, Epsilon: 0.29, Rolling Avg:  -61.85, Steps: 1199 Terminated: False
# Episode: 123/2000, Reward:  -89.24, Epsilon: 0.29, Rolling Avg:  -63.31, Steps: 1199 Terminated: False
# Episode: 124/2000, Reward: -101.81, Epsilon: 0.29, Rolling Avg:  -62.25, Steps: 1199 Terminated: False
# Episode: 125/2000, Reward:  -33.83, Epsilon: 0.28, Rolling Avg:  -61.15, Steps: 1199 Terminated: False
# Episode: 126/2000, Reward:  -27.64, Epsilon: 0.28, Rolling Avg:  -59.42, Steps: 1199 Terminated: False
# Episode: 127/2000, Reward:   -3.63, Epsilon: 0.28, Rolling Avg:  -57.97, Steps: 1199 Terminated: False
# Episode: 128/2000, Reward:  -16.59, Epsilon: 0.28, Rolling Avg:  -56.80, Steps: 1199 Terminated: False
# Episode: 129/2000, Reward:   +8.44, Epsilon: 0.27, Rolling Avg:  -55.64, Steps: 1199 Terminated: False
# Episode: 130/2000, Reward:  +36.26, Epsilon: 0.27, Rolling Avg:  -53.69, Steps: 1199 Terminated: False
# Episode: 131/2000, Reward:  +36.99, Epsilon: 0.27, Rolling Avg:  -50.97, Steps: 1199 Terminated: False
# Episode: 132/2000, Reward:  +50.88, Epsilon: 0.27, Rolling Avg:  -46.11, Steps: 1199 Terminated: False
# Episode: 133/2000, Reward: +124.22, Epsilon: 0.26, Rolling Avg:  -41.02, Steps: 1199 Terminated: False
# Episode: 134/2000, Reward: +159.70, Epsilon: 0.26, Rolling Avg:  -35.36, Steps:  968 Terminated: True
# Episode: 135/2000, Reward:  -11.87, Epsilon: 0.26, Rolling Avg:  -37.14, Steps:  684 Terminated: True
# Episode: 136/2000, Reward:  +98.21, Epsilon: 0.25, Rolling Avg:  -36.37, Steps: 1199 Terminated: False
# Episode: 137/2000, Reward:   +0.95, Epsilon: 0.25, Rolling Avg:  -34.59, Steps:  308 Terminated: True

# %% [markdown]
# #### **Learning Plot and Episode Rewards**

# %%
# Plot rewards with rolling average

plt.figure(figsize=(10, 6))
plt.plot(rewards_per_episode, label='Rewards', color='blue')
plt.plot(rolling_avg_rewards, label='Rolling Avg (Last '+str(ROLLING_WINDOW) +' Episodes)', color='orange')
plt.axhline(y=solved_threshold, color='red', linestyle='--', label='Solved Threshold')
plt.title('DQN Training Performance LUNARLANDER')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### **Simulation - Testing 10 episodes with the DQN Network**

# %%
# Testing for 10 episodes
start_time = time.time()

for e_test in range(10):  # Run 10 test episodes
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    steps = 0
    while True:
        # Use the trained model for testing
        action = agent.action(state)  # Estimate action values


        next_state, reward, done, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward
        state = next_state
        steps = steps + 1
        if done or truncated:
            print(f"Test Episode: {e_test + 1:2}/10, Reward: {total_reward:.2f}, Steps: {steps:3}")
            break

end_time = time.time()
testing_duration = (end_time - start_time) / 60  # Convert to minutes
print(f"Testing completed in {testing_duration:.2f} minutes")

# %% [markdown]
# #### **Rendering 1 episode**

# %%
# Test the trained agent with video rendering
# This code is useful if you are using colab otherwise use render_mode='human'
env = gym.make(('LunarLander-v3'), render_mode='rgb_array')  # Enable RGB rendering
frames = []  # Store frames for visualization

# Render a single test episode
state, _ = env.reset()
state = np.reshape(state, [1, state_size])
tot_rewards = 0

while True:
    # Use the trained model for action
    action = agent.action(state)            # Estimate action value

    next_state, reward, done, truncated, _ = env.step(action)
    frames.append(env.render())                  # Save frame for rendering later
    next_state = np.reshape(next_state, [1, state_size])
    tot_rewards += reward
    state = next_state

    if done or truncated:
        print(f"Rendered Test Episode Reward: {tot_rewards:.2f}")
        break

env.close()

# Save the rendered episode as a GIF
def save_frames_as_gif(frames, path='./', filename='LUNARLANDER_Agent_DQN.gif'):
    images = [Image.fromarray(frame) for frame in frames]
    gif_path = os.path.join(path, filename)
    images[0].save(gif_path, save_all=True, append_images=images[1:], duration=50, loop=0)
    print(f"Saved GIF to: {gif_path}")

save_frames_as_gif(frames, filename='LUNARLANDER_Agent_DQN.gif')

# %%
import session_info
session_info.show(html=False)

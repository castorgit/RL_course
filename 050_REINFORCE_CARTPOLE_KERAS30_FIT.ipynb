# %% [markdown]
# ## REINFORCE CARTPOLE KERAS using FIT
#
# https://github.com/rlcode/reinforcement-learning/blob/master/2-cartpole/3-reinforce/cartpole_reinforce.py
#
#
# REINFORCE is an on-policy, Monte Carlo policy gradient algorithm used to directly optimize the parameters of a stochastic policy.
#
# Instead of learning a value function (like Q-learning), REINFORCE learns the parameters of the policy function to maximize expected reward.

# %%
import sys
import gymnasium as gym
import pylab
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.losses import CategoricalCrossentropy, SparseCategoricalCrossentropy
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from PIL import Image
import os
import time

import sys
sys.stderr = open('err.txt', 'w')

import tensorflow as tf
tf.keras.backend.set_floatx('float32')

# %%
from tensorflow.python.client import device_lib
devices = device_lib.list_local_devices()
gpu_devices = [device for device in devices if device.device_type == 'GPU']
for gpu in gpu_devices:
    print('Using', gpu.physical_device_desc)
# Out:
# Using device: 0, name: NVIDIA T600 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
EPISODES = 2000
learning_rate = 0.0001
ROLLING_WINDOW = 20
solved_threshold = 195
MAX_EPISODES = 2000

# %%
# This is Policy Gradient agent for the Cartpole
# In this example, we use REINFORCE algorithm which uses monte-carlo update rule

class REINFORCEAgent:
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = False
        self.load_model = False
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # These are hyper parameters for the Policy Gradient
        self.discount_factor = 0.98
        self.learning_rate = 0.0001
        self.hidden1, self.hidden2 = 48, 48

        # create model for policy network
        self.model = self.build_model()

        # lists for the states, actions and rewards
        self.states, self.actions, self.rewards = [], [], []

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_reinforce.h5")

    # approximate policy using Neural Network
    # state is input and probability of each action is output of network
    
    def build_model(self):
        
        custom_opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, 
                          amsgrad=True, clipnorm=1.0)
        
        model = Sequential()
        model.add(Dense(self.hidden1, input_dim=self.state_size, activation='relu',dtype='float32'))
        model.add(Dense(self.hidden2, activation='relu',dtype='float32'))
        model.add(Dense(self.action_size, activation='softmax',dtype='float32'))
        model.summary()
        
        # Using categorical crossentropy as a loss is a trick to easily
        # implement the policy gradient. Categorical cross entropy is defined
        # H(p, q) = sum(p_i * log(q_i)). For the action taken, a, you set 
        # p_a = advantage. q_a is the output of the policy network, which is
        # the probability of taking the action a, i.e. policy(s, a). 
        # All other p_i are zero, thus we have H(p, q) = A * log(policy(s, a))
        
        model.compile(loss='sparse_categorical_crossentropy', optimizer=custom_opt)
        return model

    # using the output of policy network, pick action stochastically
    def get_action(self, state):
        
        policy = self.model.predict(state, batch_size=1, verbose=0).flatten()
        policy /= np.sum(policy)  # Prevents issues if softmax is slightly off
        
        # Add small epsilon to prevent issues with zero probabilities
        policy = np.clip(policy, 1e-8, 1.0)
        policy = policy / np.sum(policy)
        
        action = np.random.choice(self.action_size, 1, p=policy)[0]

        return action

    # In Policy Gradient, Q function is not available.
    # Instead agent uses sample returns for evaluating policy
    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, len(rewards))):
            running_add = running_add * self.discount_factor + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    # save <s, a ,r> of each step
    def append_sample(self, state, action, reward):
        self.states.append(state)
        self.rewards.append(reward)
        self.actions.append(action)

    # update policy network every episode
    def train_model(self):
        """Training using sparse categorical crossentropy with sample weights"""
        if len(self.states) == 0:
            return
            
        episode_length = len(self.states)
        
        # Compute and normalize discounted rewards
        discounted_rewards = self.discount_rewards(self.rewards)
        discounted_rewards -= np.mean(discounted_rewards)
        if np.std(discounted_rewards) > 0:
            discounted_rewards /= np.std(discounted_rewards)
        
        # Prepare data
        states = np.array(self.states, dtype=np.float32)
        actions = np.array(self.actions, dtype=np.int32)
        
        # Use sample weights to weight the loss by advantages
        # For policy gradients, we want to increase probability of good actions
        # and decrease probability of bad actions
        sample_weights = discounted_rewards.astype(np.float32)
        
        states = states.squeeze(axis=1)
        # Train using fit with sample weights
        self.model.fit(states, actions, 
                      sample_weight=sample_weights,
                      epochs=1, verbose=0)
        
        # Clear episode memory
        self.states, self.actions, self.rewards = [], [], []

# %%
# In case of CartPole-v1, you can play until 500 time step

env = gym.make('CartPole-v1')
    # get size of state and action from environment
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

    # make REINFORCE agent
agent = REINFORCEAgent(state_size, action_size)

scores, episodes, rolling_avg_rewards = [], [], []

for e in range(EPISODES):
    done = False
    score, step = 0, 0
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])

    while not done:
        step = step + 1
        if agent.render:
            env.render()

        # get action for the current state and go one step in environment
        action = agent.get_action(state)
        next_state, reward, done, _, info = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        reward = reward if not done or score == 499 else -100

        # save the sample <s, a, r> to the memory
        agent.append_sample(state, action, reward)

        score = score + reward
        state = next_state

        if done:
            break

    # every episode, agent learns from sample returns
    agent.train_model()

    score = score if score == 500 else score + 100
    scores.append(score)
    total_reward = score
    rolling_avg = np.mean(scores[-ROLLING_WINDOW:])   # append rewards
    rolling_avg_rewards.append(rolling_avg)
    print(f"Episode: {e+1:3}/{MAX_EPISODES}, Reward: {total_reward:+7.2f}, "
              f"Rolling Avg: {rolling_avg:6.2f}, Steps: {step:3} Terminated: {done} ")

    # break if score reaches threshold
    avg_score = np.mean(scores[-ROLLING_WINDOW:])
    if avg_score > solved_threshold:
        break           

env.close()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 48)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 48)             │         2,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            98 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,690 (10.51 KB)
#  Trainable params: 2,690 (10.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Episode:   1/2000, Reward:  +45.00, Rolling Avg:  45.00, Steps:  46 Terminated: True
# Episode:   2/2000, Reward:   +8.00, Rolling Avg:  26.50, Steps:   9 Terminated: True
# Episode:   3/2000, Reward:   +8.00, Rolling Avg:  20.33, Steps:   9 Terminated: True
# Episode:   4/2000, Reward:  +32.00, Rolling Avg:  23.25, Steps:  33 Terminated: True
# Episode:   5/2000, Reward:  +28.00, Rolling Avg:  24.20, Steps:  29 Terminated: True
# Episode:   6/2000, Reward:  +11.00, Rolling Avg:  22.00, Steps:  12 Terminated: True
# Episode:   7/2000, Reward:  +28.00, Rolling Avg:  22.86, Steps:  29 Terminated: True
# Episode:   8/2000, Reward:  +21.00, Rolling Avg:  22.62, Steps:  22 Terminated: True
# Episode:   9/2000, Reward:  +20.00, Rolling Avg:  22.33, Steps:  21 Terminated: True
# Episode:  10/2000, Reward:  +25.00, Rolling Avg:  22.60, Steps:  26 Terminated: True
# Episode:  11/2000, Reward:  +18.00, Rolling Avg:  22.18, Steps:  19 Terminated: True
# Episode:  12/2000, Reward:  +19.00, Rolling Avg:  21.92, Steps:  20 Terminated: True
# Episode:  13/2000, Reward:  +15.00, Rolling Avg:  21.38, Steps:  16 Terminated: True
# Episode:  14/2000, Reward:  +16.00, Rolling Avg:  21.00, Steps:  17 Terminated: True
# Episode:  15/2000, Reward:  +13.00, Rolling Avg:  20.47, Steps:  14 Terminated: True
# Episode:  16/2000, Reward:  +24.00, Rolling Avg:  20.69, Steps:  25 Terminated: True
# Episode:  17/2000, Reward:  +30.00, Rolling Avg:  21.24, Steps:  31 Terminated: True
# Episode:  18/2000, Reward:  +19.00, Rolling Avg:  21.11, Steps:  20 Terminated: True
# Episode:  19/2000, Reward:  +13.00, Rolling Avg:  20.68, Steps:  14 Terminated: True
# Episode:  20/2000, Reward:   +9.00, Rolling Avg:  20.10, Steps:  10 Terminated: True
# Episode:  21/2000, Reward:  +16.00, Rolling Avg:  18.65, Steps:  17 Terminated: True
# Episode:  22/2000, Reward:  +11.00, Rolling Avg:  18.80, Steps:  12 Terminated: True
# Episode:  23/2000, Reward:  +17.00, Rolling Avg:  19.25, Steps:  18 Terminated: True
# Episode:  24/2000, Reward:  +41.00, Rolling Avg:  19.70, Steps:  42 Terminated: True
# Episode:  25/2000, Reward:  +20.00, Rolling Avg:  19.30, Steps:  21 Terminated: True
# Episode:  26/2000, Reward:  +15.00, Rolling Avg:  19.50, Steps:  16 Terminated: True
# Episode:  27/2000, Reward:  +35.00, Rolling Avg:  19.85, Steps:  36 Terminated: True
# Episode:  28/2000, Reward:  +17.00, Rolling Avg:  19.65, Steps:  18 Terminated: True
# Episode:  29/2000, Reward:  +12.00, Rolling Avg:  19.25, Steps:  13 Terminated: True
# Episode:  30/2000, Reward:  +11.00, Rolling Avg:  18.55, Steps:  12 Terminated: True
# Episode:  31/2000, Reward:  +40.00, Rolling Avg:  19.65, Steps:  41 Terminated: True
# Episode:  32/2000, Reward:  +36.00, Rolling Avg:  20.50, Steps:  37 Terminated: True
# Episode:  33/2000, Reward:  +21.00, Rolling Avg:  20.80, Steps:  22 Terminated: True
# Episode:  34/2000, Reward:  +20.00, Rolling Avg:  21.00, Steps:  21 Terminated: True
# Episode:  35/2000, Reward:  +10.00, Rolling Avg:  20.85, Steps:  11 Terminated: True
# Episode:  36/2000, Reward:   +9.00, Rolling Avg:  20.10, Steps:  10 Terminated: True
# Episode:  37/2000, Reward:  +27.00, Rolling Avg:  19.95, Steps:  28 Terminated: True
# Episode:  38/2000, Reward:  +18.00, Rolling Avg:  19.90, Steps:  19 Terminated: True
# Episode:  39/2000, Reward:  +10.00, Rolling Avg:  19.75, Steps:  11 Terminated: True
# Episode:  40/2000, Reward:  +11.00, Rolling Avg:  19.85, Steps:  12 Terminated: True
# Episode:  41/2000, Reward:  +16.00, Rolling Avg:  19.85, Steps:  17 Terminated: True
# Episode:  42/2000, Reward:  +14.00, Rolling Avg:  20.00, Steps:  15 Terminated: True
# Episode:  43/2000, Reward:  +18.00, Rolling Avg:  20.05, Steps:  19 Terminated: True
# Episode:  44/2000, Reward:  +22.00, Rolling Avg:  19.10, Steps:  23 Terminated: True
# Episode:  45/2000, Reward:  +10.00, Rolling Avg:  18.60, Steps:  11 Terminated: True
# Episode:  46/2000, Reward:  +63.00, Rolling Avg:  21.00, Steps:  64 Terminated: True
# Episode:  47/2000, Reward:  +10.00, Rolling Avg:  19.75, Steps:  11 Terminated: True
# Episode:  48/2000, Reward:  +28.00, Rolling Avg:  20.30, Steps:  29 Terminated: True
# Episode:  49/2000, Reward:   +8.00, Rolling Avg:  20.10, Steps:   9 Terminated: True
# Episode:  50/2000, Reward:  +28.00, Rolling Avg:  20.95, Steps:  29 Terminated: True
# Episode:  51/2000, Reward:  +28.00, Rolling Avg:  20.35, Steps:  29 Terminated: True
# Episode:  52/2000, Reward:  +19.00, Rolling Avg:  19.50, Steps:  20 Terminated: True
# Episode:  53/2000, Reward:  +26.00, Rolling Avg:  19.75, Steps:  27 Terminated: True
# Episode:  54/2000, Reward:  +23.00, Rolling Avg:  19.90, Steps:  24 Terminated: True
# Episode:  55/2000, Reward:  +42.00, Rolling Avg:  21.50, Steps:  43 Terminated: True
# Episode:  56/2000, Reward:  +17.00, Rolling Avg:  21.90, Steps:  18 Terminated: True
# Episode:  57/2000, Reward:  +16.00, Rolling Avg:  21.35, Steps:  17 Terminated: True
# Episode:  58/2000, Reward:  +25.00, Rolling Avg:  21.70, Steps:  26 Terminated: True
# Episode:  59/2000, Reward:  +37.00, Rolling Avg:  23.05, Steps:  38 Terminated: True
# Episode:  60/2000, Reward:  +23.00, Rolling Avg:  23.65, Steps:  24 Terminated: True
# Episode:  61/2000, Reward:  +24.00, Rolling Avg:  24.05, Steps:  25 Terminated: True
# Episode:  62/2000, Reward:  +32.00, Rolling Avg:  24.95, Steps:  33 Terminated: True
# Episode:  63/2000, Reward:  +16.00, Rolling Avg:  24.85, Steps:  17 Terminated: True
# Episode:  64/2000, Reward:  +20.00, Rolling Avg:  24.75, Steps:  21 Terminated: True
# Episode:  65/2000, Reward:  +29.00, Rolling Avg:  25.70, Steps:  30 Terminated: True
# Episode:  66/2000, Reward:  +39.00, Rolling Avg:  24.50, Steps:  40 Terminated: True
# Episode:  67/2000, Reward:  +28.00, Rolling Avg:  25.40, Steps:  29 Terminated: True
# Episode:  68/2000, Reward:  +31.00, Rolling Avg:  25.55, Steps:  32 Terminated: True
# Episode:  69/2000, Reward:  +27.00, Rolling Avg:  26.50, Steps:  28 Terminated: True
# Episode:  70/2000, Reward:   +8.00, Rolling Avg:  25.50, Steps:   9 Terminated: True
# Episode:  71/2000, Reward:  +30.00, Rolling Avg:  25.60, Steps:  31 Terminated: True
# Episode:  72/2000, Reward:  +15.00, Rolling Avg:  25.40, Steps:  16 Terminated: True
# Episode:  73/2000, Reward:  +13.00, Rolling Avg:  24.75, Steps:  14 Terminated: True
# Episode:  74/2000, Reward:  +15.00, Rolling Avg:  24.35, Steps:  16 Terminated: True
# Episode:  75/2000, Reward:  +29.00, Rolling Avg:  23.70, Steps:  30 Terminated: True
# Episode:  76/2000, Reward:  +73.00, Rolling Avg:  26.50, Steps:  74 Terminated: True
# Episode:  77/2000, Reward:  +11.00, Rolling Avg:  26.25, Steps:  12 Terminated: True
# Episode:  78/2000, Reward:  +16.00, Rolling Avg:  25.80, Steps:  17 Terminated: True
# Episode:  79/2000, Reward:  +16.00, Rolling Avg:  24.75, Steps:  17 Terminated: True
# Episode:  80/2000, Reward:  +25.00, Rolling Avg:  24.85, Steps:  26 Terminated: True
# Episode:  81/2000, Reward:  +22.00, Rolling Avg:  24.75, Steps:  23 Terminated: True
# Episode:  82/2000, Reward:  +23.00, Rolling Avg:  24.30, Steps:  24 Terminated: True
# Episode:  83/2000, Reward:  +22.00, Rolling Avg:  24.60, Steps:  23 Terminated: True
# Episode:  84/2000, Reward:  +33.00, Rolling Avg:  25.25, Steps:  34 Terminated: True
# Episode:  85/2000, Reward:  +27.00, Rolling Avg:  25.15, Steps:  28 Terminated: True
# Episode:  86/2000, Reward:   +9.00, Rolling Avg:  23.65, Steps:  10 Terminated: True
# Episode:  87/2000, Reward:  +21.00, Rolling Avg:  23.30, Steps:  22 Terminated: True
# Episode:  88/2000, Reward:  +26.00, Rolling Avg:  23.05, Steps:  27 Terminated: True
# Episode:  89/2000, Reward:  +21.00, Rolling Avg:  22.75, Steps:  22 Terminated: True
# Episode:  90/2000, Reward:  +28.00, Rolling Avg:  23.75, Steps:  29 Terminated: True
# Episode:  91/2000, Reward:  +19.00, Rolling Avg:  23.20, Steps:  20 Terminated: True
# Episode:  92/2000, Reward:  +46.00, Rolling Avg:  24.75, Steps:  47 Terminated: True
# Episode:  93/2000, Reward:  +16.00, Rolling Avg:  24.90, Steps:  17 Terminated: True
# Episode:  94/2000, Reward:  +18.00, Rolling Avg:  25.05, Steps:  19 Terminated: True
# Episode:  95/2000, Reward:  +21.00, Rolling Avg:  24.65, Steps:  22 Terminated: True
# Episode:  96/2000, Reward:  +22.00, Rolling Avg:  22.10, Steps:  23 Terminated: True
# Episode:  97/2000, Reward:  +20.00, Rolling Avg:  22.55, Steps:  21 Terminated: True
# Episode:  98/2000, Reward:  +24.00, Rolling Avg:  22.95, Steps:  25 Terminated: True
# Episode:  99/2000, Reward:  +11.00, Rolling Avg:  22.70, Steps:  12 Terminated: True
# Episode: 100/2000, Reward:  +20.00, Rolling Avg:  22.45, Steps:  21 Terminated: True
# Episode: 101/2000, Reward:  +21.00, Rolling Avg:  22.40, Steps:  22 Terminated: True
# Episode: 102/2000, Reward:  +15.00, Rolling Avg:  22.00, Steps:  16 Terminated: True
# Episode: 103/2000, Reward:  +14.00, Rolling Avg:  21.60, Steps:  15 Terminated: True
# Episode: 104/2000, Reward:  +43.00, Rolling Avg:  22.10, Steps:  44 Terminated: True
# Episode: 105/2000, Reward:  +49.00, Rolling Avg:  23.20, Steps:  50 Terminated: True
# Episode: 106/2000, Reward:  +34.00, Rolling Avg:  24.45, Steps:  35 Terminated: True
# Episode: 107/2000, Reward:   +8.00, Rolling Avg:  23.80, Steps:   9 Terminated: True
# Episode: 108/2000, Reward:  +16.00, Rolling Avg:  23.30, Steps:  17 Terminated: True
# Episode: 109/2000, Reward:  +72.00, Rolling Avg:  25.85, Steps:  73 Terminated: True
# Episode: 110/2000, Reward:  +36.00, Rolling Avg:  26.25, Steps:  37 Terminated: True
# Episode: 111/2000, Reward:  +24.00, Rolling Avg:  26.50, Steps:  25 Terminated: True
# Episode: 112/2000, Reward:   +8.00, Rolling Avg:  24.60, Steps:   9 Terminated: True
# Episode: 113/2000, Reward:  +41.00, Rolling Avg:  25.85, Steps:  42 Terminated: True
# Episode: 114/2000, Reward:  +13.00, Rolling Avg:  25.60, Steps:  14 Terminated: True
# Episode: 115/2000, Reward:  +50.00, Rolling Avg:  27.05, Steps:  51 Terminated: True
# Episode: 116/2000, Reward:  +18.00, Rolling Avg:  26.85, Steps:  19 Terminated: True
# Episode: 117/2000, Reward:  +25.00, Rolling Avg:  27.10, Steps:  26 Terminated: True
# Episode: 118/2000, Reward:  +34.00, Rolling Avg:  27.60, Steps:  35 Terminated: True
# Episode: 119/2000, Reward:  +85.00, Rolling Avg:  31.30, Steps:  86 Terminated: True
# Episode: 120/2000, Reward:  +14.00, Rolling Avg:  31.00, Steps:  15 Terminated: True
# Episode: 121/2000, Reward:  +34.00, Rolling Avg:  31.65, Steps:  35 Terminated: True
# Episode: 122/2000, Reward:  +33.00, Rolling Avg:  32.55, Steps:  34 Terminated: True
# Episode: 123/2000, Reward:  +48.00, Rolling Avg:  34.25, Steps:  49 Terminated: True
# Episode: 124/2000, Reward:  +57.00, Rolling Avg:  34.95, Steps:  58 Terminated: True
# Episode: 125/2000, Reward:  +27.00, Rolling Avg:  33.85, Steps:  28 Terminated: True
# Episode: 126/2000, Reward:  +60.00, Rolling Avg:  35.15, Steps:  61 Terminated: True
# Episode: 127/2000, Reward:  +14.00, Rolling Avg:  35.45, Steps:  15 Terminated: True
# Episode: 128/2000, Reward:  +37.00, Rolling Avg:  36.50, Steps:  38 Terminated: True
# Episode: 129/2000, Reward:  +54.00, Rolling Avg:  35.60, Steps:  55 Terminated: True
# Episode: 130/2000, Reward:  +63.00, Rolling Avg:  36.95, Steps:  64 Terminated: True
# Episode: 131/2000, Reward:  +64.00, Rolling Avg:  38.95, Steps:  65 Terminated: True
# Episode: 132/2000, Reward:  +35.00, Rolling Avg:  40.30, Steps:  36 Terminated: True
# Episode: 133/2000, Reward:  +15.00, Rolling Avg:  39.00, Steps:  16 Terminated: True
# Episode: 134/2000, Reward:  +16.00, Rolling Avg:  39.15, Steps:  17 Terminated: True
# Episode: 135/2000, Reward:  +45.00, Rolling Avg:  38.90, Steps:  46 Terminated: True
# Episode: 136/2000, Reward:  +18.00, Rolling Avg:  38.90, Steps:  19 Terminated: True
# Episode: 137/2000, Reward:  +31.00, Rolling Avg:  39.20, Steps:  32 Terminated: True
# Episode: 138/2000, Reward:  +14.00, Rolling Avg:  38.20, Steps:  15 Terminated: True
# Episode: 139/2000, Reward:  +21.00, Rolling Avg:  35.00, Steps:  22 Terminated: True
# Episode: 140/2000, Reward:  +44.00, Rolling Avg:  36.50, Steps:  45 Terminated: True
# Episode: 141/2000, Reward:  +29.00, Rolling Avg:  36.25, Steps:  30 Terminated: True
# Episode: 142/2000, Reward:  +26.00, Rolling Avg:  35.90, Steps:  27 Terminated: True
# Episode: 143/2000, Reward:  +39.00, Rolling Avg:  35.45, Steps:  40 Terminated: True
# Episode: 144/2000, Reward:  +45.00, Rolling Avg:  34.85, Steps:  46 Terminated: True
# Episode: 145/2000, Reward:  +17.00, Rolling Avg:  34.35, Steps:  18 Terminated: True
# Episode: 146/2000, Reward:  +63.00, Rolling Avg:  34.50, Steps:  64 Terminated: True
# Episode: 147/2000, Reward:  +14.00, Rolling Avg:  34.50, Steps:  15 Terminated: True
# Episode: 148/2000, Reward:  +88.00, Rolling Avg:  37.05, Steps:  89 Terminated: True
# Episode: 149/2000, Reward:  +25.00, Rolling Avg:  35.60, Steps:  26 Terminated: True
# Episode: 150/2000, Reward:  +31.00, Rolling Avg:  34.00, Steps:  32 Terminated: True
# Episode: 151/2000, Reward:  +22.00, Rolling Avg:  31.90, Steps:  23 Terminated: True
# Episode: 152/2000, Reward:  +20.00, Rolling Avg:  31.15, Steps:  21 Terminated: True
# Episode: 153/2000, Reward:  +21.00, Rolling Avg:  31.45, Steps:  22 Terminated: True
# Episode: 154/2000, Reward:  +21.00, Rolling Avg:  31.70, Steps:  22 Terminated: True
# Episode: 155/2000, Reward:  +51.00, Rolling Avg:  32.00, Steps:  52 Terminated: True
# Episode: 156/2000, Reward:  +16.00, Rolling Avg:  31.90, Steps:  17 Terminated: True
# Episode: 157/2000, Reward:  +36.00, Rolling Avg:  32.15, Steps:  37 Terminated: True
# Episode: 158/2000, Reward:  +26.00, Rolling Avg:  32.75, Steps:  27 Terminated: True
# Episode: 159/2000, Reward:  +31.00, Rolling Avg:  33.25, Steps:  32 Terminated: True
# Episode: 160/2000, Reward:  +62.00, Rolling Avg:  34.15, Steps:  63 Terminated: True
# Episode: 161/2000, Reward:  +48.00, Rolling Avg:  35.10, Steps:  49 Terminated: True
# Episode: 162/2000, Reward: +119.00, Rolling Avg:  39.75, Steps: 120 Terminated: True
# Episode: 163/2000, Reward:  +98.00, Rolling Avg:  42.70, Steps:  99 Terminated: True
# Episode: 164/2000, Reward:  +31.00, Rolling Avg:  42.00, Steps:  32 Terminated: True
# Episode: 165/2000, Reward:  +90.00, Rolling Avg:  45.65, Steps:  91 Terminated: True
# Episode: 166/2000, Reward:  +31.00, Rolling Avg:  44.05, Steps:  32 Terminated: True
# Episode: 167/2000, Reward:  +36.00, Rolling Avg:  45.15, Steps:  37 Terminated: True
# Episode: 168/2000, Reward:  +26.00, Rolling Avg:  42.05, Steps:  27 Terminated: True
# Episode: 169/2000, Reward:  +19.00, Rolling Avg:  41.75, Steps:  20 Terminated: True
# Episode: 170/2000, Reward:  +54.00, Rolling Avg:  42.90, Steps:  55 Terminated: True
# Episode: 171/2000, Reward:  +52.00, Rolling Avg:  44.40, Steps:  53 Terminated: True
# Episode: 172/2000, Reward:  +33.00, Rolling Avg:  45.05, Steps:  34 Terminated: True
# Episode: 173/2000, Reward:  +60.00, Rolling Avg:  47.00, Steps:  61 Terminated: True
# Episode: 174/2000, Reward:  +30.00, Rolling Avg:  47.45, Steps:  31 Terminated: True
# Episode: 175/2000, Reward:  +80.00, Rolling Avg:  48.90, Steps:  81 Terminated: True
# Episode: 176/2000, Reward:  +20.00, Rolling Avg:  49.10, Steps:  21 Terminated: True
# Episode: 177/2000, Reward:  +51.00, Rolling Avg:  49.85, Steps:  52 Terminated: True
# Episode: 178/2000, Reward:  +40.00, Rolling Avg:  50.55, Steps:  41 Terminated: True
# Episode: 179/2000, Reward:  +32.00, Rolling Avg:  50.60, Steps:  33 Terminated: True
# Episode: 180/2000, Reward:  +50.00, Rolling Avg:  50.00, Steps:  51 Terminated: True
# Episode: 181/2000, Reward:  +85.00, Rolling Avg:  51.85, Steps:  86 Terminated: True
# Episode: 182/2000, Reward:  +56.00, Rolling Avg:  48.70, Steps:  57 Terminated: True
# Episode: 183/2000, Reward:  +40.00, Rolling Avg:  45.80, Steps:  41 Terminated: True
# Episode: 184/2000, Reward:  +36.00, Rolling Avg:  46.05, Steps:  37 Terminated: True
# Episode: 185/2000, Reward:  +50.00, Rolling Avg:  44.05, Steps:  51 Terminated: True
# Episode: 186/2000, Reward:  +25.00, Rolling Avg:  43.75, Steps:  26 Terminated: True
# Episode: 187/2000, Reward:  +21.00, Rolling Avg:  43.00, Steps:  22 Terminated: True
# Episode: 188/2000, Reward:  +37.00, Rolling Avg:  43.55, Steps:  38 Terminated: True
# Episode: 189/2000, Reward:  +29.00, Rolling Avg:  44.05, Steps:  30 Terminated: True
# Episode: 190/2000, Reward:  +42.00, Rolling Avg:  43.45, Steps:  43 Terminated: True
# Episode: 191/2000, Reward:  +23.00, Rolling Avg:  42.00, Steps:  24 Terminated: True
# Episode: 192/2000, Reward:  +67.00, Rolling Avg:  43.70, Steps:  68 Terminated: True
# Episode: 193/2000, Reward:  +15.00, Rolling Avg:  41.45, Steps:  16 Terminated: True
# Episode: 194/2000, Reward:  +66.00, Rolling Avg:  43.25, Steps:  67 Terminated: True
# Episode: 195/2000, Reward:  +99.00, Rolling Avg:  44.20, Steps: 100 Terminated: True
# Episode: 196/2000, Reward: +113.00, Rolling Avg:  48.85, Steps: 114 Terminated: True
# Episode: 197/2000, Reward:  +94.00, Rolling Avg:  51.00, Steps:  95 Terminated: True
# Episode: 198/2000, Reward:  +43.00, Rolling Avg:  51.15, Steps:  44 Terminated: True
# Episode: 199/2000, Reward:  +43.00, Rolling Avg:  51.70, Steps:  44 Terminated: True
# Episode: 200/2000, Reward:  +26.00, Rolling Avg:  50.50, Steps:  27 Terminated: True
# Episode: 201/2000, Reward:  +97.00, Rolling Avg:  51.10, Steps:  98 Terminated: True
# Episode: 202/2000, Reward:  +54.00, Rolling Avg:  51.00, Steps:  55 Terminated: True
# Episode: 203/2000, Reward:  +69.00, Rolling Avg:  52.45, Steps:  70 Terminated: True
# Episode: 204/2000, Reward:  +67.00, Rolling Avg:  54.00, Steps:  68 Terminated: True
# Episode: 205/2000, Reward:  +13.00, Rolling Avg:  52.15, Steps:  14 Terminated: True
# Episode: 206/2000, Reward:  +29.00, Rolling Avg:  52.35, Steps:  30 Terminated: True
# Episode: 207/2000, Reward:  +86.00, Rolling Avg:  55.60, Steps:  87 Terminated: True
# Episode: 208/2000, Reward:  +55.00, Rolling Avg:  56.50, Steps:  56 Terminated: True
# Episode: 209/2000, Reward:  +65.00, Rolling Avg:  58.30, Steps:  66 Terminated: True
# Episode: 210/2000, Reward:  +38.00, Rolling Avg:  58.10, Steps:  39 Terminated: True
# Episode: 211/2000, Reward:  +29.00, Rolling Avg:  58.40, Steps:  30 Terminated: True
# Episode: 212/2000, Reward: +127.00, Rolling Avg:  61.40, Steps: 128 Terminated: True
# Episode: 213/2000, Reward:  +62.00, Rolling Avg:  63.75, Steps:  63 Terminated: True
# Episode: 214/2000, Reward:  +53.00, Rolling Avg:  63.10, Steps:  54 Terminated: True
# Episode: 215/2000, Reward:  +40.00, Rolling Avg:  60.15, Steps:  41 Terminated: True
# Episode: 216/2000, Reward: +113.00, Rolling Avg:  60.15, Steps: 114 Terminated: True
# Episode: 217/2000, Reward:  +69.00, Rolling Avg:  58.90, Steps:  70 Terminated: True
# Episode: 218/2000, Reward:  +67.00, Rolling Avg:  60.10, Steps:  68 Terminated: True
# Episode: 219/2000, Reward: +115.00, Rolling Avg:  63.70, Steps: 116 Terminated: True
# Episode: 220/2000, Reward: +153.00, Rolling Avg:  70.05, Steps: 154 Terminated: True
# Episode: 221/2000, Reward:  +59.00, Rolling Avg:  68.15, Steps:  60 Terminated: True
# Episode: 222/2000, Reward:  +70.00, Rolling Avg:  68.95, Steps:  71 Terminated: True
# Episode: 223/2000, Reward:  +67.00, Rolling Avg:  68.85, Steps:  68 Terminated: True
# Episode: 224/2000, Reward:  +45.00, Rolling Avg:  67.75, Steps:  46 Terminated: True
# Episode: 225/2000, Reward:  +63.00, Rolling Avg:  70.25, Steps:  64 Terminated: True
# Episode: 226/2000, Reward: +118.00, Rolling Avg:  74.70, Steps: 119 Terminated: True
# Episode: 227/2000, Reward:  +84.00, Rolling Avg:  74.60, Steps:  85 Terminated: True
# Episode: 228/2000, Reward:  +93.00, Rolling Avg:  76.50, Steps:  94 Terminated: True
# Episode: 229/2000, Reward:  +49.00, Rolling Avg:  75.70, Steps:  50 Terminated: True
# Episode: 230/2000, Reward:  +48.00, Rolling Avg:  76.20, Steps:  49 Terminated: True
# Episode: 231/2000, Reward:  +36.00, Rolling Avg:  76.55, Steps:  37 Terminated: True
# Episode: 232/2000, Reward:  +38.00, Rolling Avg:  72.10, Steps:  39 Terminated: True
# Episode: 233/2000, Reward: +136.00, Rolling Avg:  75.80, Steps: 137 Terminated: True
# Episode: 234/2000, Reward: +148.00, Rolling Avg:  80.55, Steps: 149 Terminated: True
# Episode: 235/2000, Reward:  +96.00, Rolling Avg:  83.35, Steps:  97 Terminated: True
# Episode: 236/2000, Reward: +175.00, Rolling Avg:  86.45, Steps: 176 Terminated: True
# Episode: 237/2000, Reward: +111.00, Rolling Avg:  88.55, Steps: 112 Terminated: True
# Episode: 238/2000, Reward: +222.00, Rolling Avg:  96.30, Steps: 223 Terminated: True
# Episode: 239/2000, Reward: +204.00, Rolling Avg: 100.75, Steps: 205 Terminated: True
# Episode: 240/2000, Reward:  +94.00, Rolling Avg:  97.80, Steps:  95 Terminated: True
# Episode: 241/2000, Reward: +161.00, Rolling Avg: 102.90, Steps: 162 Terminated: True
# Episode: 242/2000, Reward: +101.00, Rolling Avg: 104.45, Steps: 102 Terminated: True
# Episode: 243/2000, Reward: +155.00, Rolling Avg: 108.85, Steps: 156 Terminated: True
# Episode: 244/2000, Reward: +251.00, Rolling Avg: 119.15, Steps: 252 Terminated: True
# Episode: 245/2000, Reward: +105.00, Rolling Avg: 121.25, Steps: 106 Terminated: True
# Episode: 246/2000, Reward: +242.00, Rolling Avg: 127.45, Steps: 243 Terminated: True
# Episode: 247/2000, Reward: +118.00, Rolling Avg: 129.15, Steps: 119 Terminated: True
# Episode: 248/2000, Reward: +650.00, Rolling Avg: 157.00, Steps: 651 Terminated: True
# Episode: 249/2000, Reward: +101.00, Rolling Avg: 159.60, Steps: 102 Terminated: True
# Episode: 250/2000, Reward: +153.00, Rolling Avg: 164.85, Steps: 154 Terminated: True
# Episode: 251/2000, Reward: +146.00, Rolling Avg: 170.35, Steps: 147 Terminated: True
# Episode: 252/2000, Reward: +110.00, Rolling Avg: 173.95, Steps: 111 Terminated: True
# Episode: 253/2000, Reward:  +75.00, Rolling Avg: 170.90, Steps:  76 Terminated: True
# Episode: 254/2000, Reward: +126.00, Rolling Avg: 169.80, Steps: 127 Terminated: True
# Episode: 255/2000, Reward: +153.00, Rolling Avg: 172.65, Steps: 154 Terminated: True
# Episode: 256/2000, Reward: +232.00, Rolling Avg: 175.50, Steps: 233 Terminated: True
# Episode: 257/2000, Reward: +413.00, Rolling Avg: 190.60, Steps: 414 Terminated: True
# Episode: 258/2000, Reward: +303.00, Rolling Avg: 194.65, Steps: 304 Terminated: True
# Episode: 259/2000, Reward: +162.00, Rolling Avg: 192.55, Steps: 163 Terminated: True
# Episode: 260/2000, Reward:  +58.00, Rolling Avg: 190.75, Steps:  59 Terminated: True
# Episode: 261/2000, Reward: +296.00, Rolling Avg: 197.50, Steps: 297 Terminated: True

# %%
# Plot rewards with rolling average
plt.figure(figsize=(10, 6))
plt.plot(scores, label='Rewards', color='blue')
plt.plot(rolling_avg_rewards, label='Rolling Avg (Last '+str(ROLLING_WINDOW)+' Episodes)', color='orange')
plt.axhline(y=solved_threshold, color='red', linestyle='--', label='Solved Threshold')
plt.title('REINFORCE Training Performance')
plt.xlabel('Episodes')
plt.ylabel('Rewards')
plt.legend()
plt.grid()
plt.show()

# %%
# Using Policy to select next action

# Testing for 10 episodes
start_time = time.time()
max_steps = 500

for e_test in range(10):  # Run 10 test episodes
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    
    steps = 0
    for s in range(max_steps):                            # we limit because sometimes it goes ad-aeternum
        # Use the trained model for testing
        
        action = agent.get_action(state)                  

        next_state, reward, done, _, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        total_reward += reward
        state = next_state
        steps = steps + 1

        if done or (steps == max_steps):
            print(f"Test Episode: {e_test + 1}/10, Reward: {total_reward:.2f}, Steps: {steps:3}")
            break

end_time = time.time()
testing_duration = (end_time - start_time) / 60  # Convert to minutes
print(f"Testing completed in {testing_duration:.2f} minutes")
# Out:
# Test Episode: 1/10, Reward: 278.00, Steps: 278
# Test Episode: 2/10, Reward: 116.00, Steps: 116
# Test Episode: 3/10, Reward: 220.00, Steps: 220
# Test Episode: 4/10, Reward: 154.00, Steps: 154
# Test Episode: 5/10, Reward: 181.00, Steps: 181
# Test Episode: 6/10, Reward: 240.00, Steps: 240
# Test Episode: 7/10, Reward: 200.00, Steps: 200
# Test Episode: 8/10, Reward: 201.00, Steps: 201
# Test Episode: 9/10, Reward: 223.00, Steps: 223
# Test Episode: 10/10, Reward: 161.00, Steps: 161
# Testing completed in 1.26 minutes

# %%
# Test the trained agent with video rendering
# This code is useful if you are using colab otherwise use render_mode='human'
env = gym.make(("CartPole-v1"), render_mode='rgb_array')  # Enable RGB rendering
frames = []  # Store frames for visualization

# Render a single test episode
state, _ = env.reset()
state = np.reshape(state, [1, state_size])
tot_rewards = 0

while True:
    # Use the trained model for action
    
    action = agent.get_action(state)                  # We use the policy to get the next action

    next_state, reward, done, truncated, _ = env.step(action)
    frames.append(env.render())                  # Save frame for rendering later
    next_state = np.reshape(next_state, [1, state_size])
    tot_rewards += reward
    state = next_state

    if done or truncated:
        print(f"Rendered Test Episode Reward: {tot_rewards:.2f}")
        break

env.close()

# Save the rendered episode as a GIF
def save_frames_as_gif(frames, path='./', filename='CARTPOLE_REINFORCE_FIT.gif'):
    images = [Image.fromarray(frame) for frame in frames]
    gif_path = os.path.join(path, filename)
    images[0].save(gif_path, save_all=True, append_images=images[1:], duration=50, loop=0)
    print(f"Saved GIF to: {gif_path}")

save_frames_as_gif(frames, filename='CARTPOLE_REINFORCE_FIT.gif')
# Out:
# Rendered Test Episode Reward: 247.00
# Saved GIF to: ./CARTPOLE_REINFORCE_FIT.gif

# %%
import session_info
session_info.show(html=False)
# Out:
# -----
# PIL                 10.4.0
# gymnasium           1.0.0
# keras               3.6.0
# matplotlib          3.9.2
# numpy               1.26.4
# pylab               NA
# session_info        1.0.0
# tensorflow          2.19.0
# -----
# IPython             8.28.0
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# -----
# Python 3.12.3 (main, Feb  4 2025, 14:48:35) [GCC 13.3.0]
# Linux-6.6.87.1-microsoft-standard-WSL2-x86_64-with-glibc2.39
# -----
# Session information updated at 2025-06-10 13:06
